# %% [markdown]
# # Modeling Current Price using Fundamentals
# A central task which fundamental analysts concern themselves is modeling the intrinsic value of securities using fundamental financial data related to a company. Value investors, such as Warren Buffet, then compare the current trading price to their estimate of intrinsic value in order to identify securities which are currently over or under valued, and create trading strategies which assume that the market price will eventually move toward their estimate of intrinsic value. A "Margin of Safety" represents the size of the gap between market price and intrinsic value, and a larger margin of safety should indicate a safer directional bet.
#
# The success of this technique depends upon the quality of the analyst's method of intrinsic value estimation. Much research and numerous techniques have been developed in this pursuit. The classic approach of asset valuation comes in the form of the Capital Asset Pricing Model (CAPM), which is a (in today's world) rather rudamentary model for pricing assets based on their risk premium, taking into account the expected market return versus the risk-free-rate of return which an investor could get by simply investing into risk-free treasury bonds. This method has proven successful for value investors in the past, but the widespread use of this technique, the introduction of many more traders into the market, as well as automated trading systems, has obfuscated the way that securities can be valuated, and more modern techniques of asset price estimation have been sought after.
#
# I will now attempt to create asset pricing models using Machine Learning, trained using the fundamental financial data for each company in the S&P 500 scraped from TD Ameritrade's website on May 8th, 2020, with the log closing price of that same day as the target variable. The predictions of the model can then be used as intrinsic value estimates, then margins of safety can be reflected in the residuals of this model, which could be used to develop a trading strategy for a 6 month period. It will then be useful to see use the actual returns of these securities since this date to see how successful this trading strategy would have been. It will be interesting to see if there is a linear relationship between margin of safety (residuals) and returns.
#
# The reason for modeling the prices of the assets rather than the actual returns is that all of the data needed for this technique would have been known on the day that the fundamentals data was acquired. Later, I will be training ML models using the actual returns to see what features are the most relevant in predicting actual returns, but these analyses will be done using data that were not known at the time of the scrape, and therefore will be most useful as analysis of feature importances and possible feature engineering techniques, with some possibility of future deployability.

# %% [markdown]
# ### Importing Libraries and Data

# %%
import bot_functions as bf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import yfinance as yf

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.model_selection import train_test_split

# %%
plt.style.use('seaborn-darkgrid')

# %%
from matplotlib import rcParams
rcParams['figure.figsize'] = 11, 7

# %%
# First, let's get the list of tickers used in the scrape to get target variables for
sp500_tickers = pd.read_csv('sp500.csv', usecols=[1])
sp500_tickers.head()
# Out:
#   Symbol
# 0      A
# 1    AAL
# 2    AAP
# 3   AAPL
# 4   ABBV

# %%
sp500_tickers.tail()
# Out:
#     Symbol
# 498    YUM
# 499    ZBH
# 500   ZBRA
# 501   ZION
# 502    ZTS

# %%
print(len(sp500_tickers))
# Out:
# 503

# %%
# Finding odd entries in tickers list, these tickers do not have data from the scrape and do not
# work with yfinance
bad_tickers = []
for ticker in sp500_tickers.Symbol:
    if '.' in ticker:
        print(ticker)
        bad_tickers.append(ticker)
# Out:
# BF.B
# BRK.B

# %%
sp500_tickers = sp500_tickers[~sp500_tickers.Symbol.isin(bad_tickers)]['Symbol']
print(len(sp500_tickers))
# Out:
# 501

# %% [markdown]
# Now that we have our tickers, we can set about getting pricing information with yfinance. We will only need to concern ourselves with closing prices for our purposes.

# %%
# Setting start and end dates. The web scrape was done on Friday, 2020-05-08, the end date to be
# used for this project is Friday, 2020-10-30
start_date = '2020-05-08'
end_date = '2020-10-30'
# yfinance likes the tickers formatted as a list
ticks = yf.Tickers(list(sp500_tickers))
sp500_close = ticks.history(start=start_date, end=end_date).Close
sp500_close.tail()
# Out:
# [*********************100%***********************]  501 of 501 completed
#
# 1 Failed download:
# - AGN: No data found, symbol may be delisted
#                      A    AAL         AAP        AAPL       ABBV        ABC  \
# Date
# 2020-10-26  104.629997  11.80  151.210007  115.050003  83.919998  98.370003
# 2020-10-27  106.040001  11.23  150.410004  116.599998  82.709999  97.650002
# 2020-10-28  101.660004  10.95  146.380005  111.199997  80.489998  95.699997
# 2020-10-29  102.019997  11.16  146.000000  115.320000  80.669998  94.589996
# 2020-10-30         NaN    NaN         NaN         NaN        NaN        NaN
#
#                   ABMD         ABT         ACN        ADBE  ...        XLNX  \
# Date                                                        ...
# 2020-10-26  288.320007  109.000000  219.229996  475.200012  ...  114.550003
# 2020-10-27  290.510010  108.580002  220.660004  478.559998  ...  124.349998
# 2020-10-28  283.000000  106.419998  213.940002  456.970001  ...  119.760002
# 2020-10-29  254.610001  105.000000  216.440002  461.109985  ...  122.900002
# 2020-10-30         NaN         NaN         NaN         NaN  ...         NaN
#
#                   XOM       XRAY    XRX        XYL        YUM         ZBH  \
# Date
# 2020-10-26  33.349998  47.610001  18.92  90.070000  99.199997  139.509995
# 2020-10-27  32.820000  47.540001  18.52  89.059998  97.989998  138.600006
# 2020-10-28  31.570000  44.840000  17.23  87.349998  95.059998  133.369995
# 2020-10-29  32.970001  44.799999  17.65  86.860001  94.940002  133.839996
# 2020-10-30        NaN        NaN    NaN        NaN        NaN         NaN
#
#                   ZBRA       ZION         ZTS
# Date
# 2020-10-26  295.100006  32.459999  160.479996
# 2020-10-27  289.279999  31.080000  162.470001
# 2020-10-28  285.200012  30.600000  158.690002
# 2020-10-29  291.970001  31.559999  161.190002
# 2020-10-30         NaN        NaN         NaN
#
# [5 rows x 501 columns]

# %%
# AGN was not found, it appears as though it has been acquired by ABBV since the data was
# originally scraped. I will make adjustments accordingly.

# %%
# We can see that yfinance has still not posted closing prices for Friday, which is part of why
# yfinance is so lame. However, it is an eas-to-access market data retrieval package so I will
# just drop friday for now so we can get moving with some analysis.

# %%
sp500_close = sp500_close.iloc[:-1]
sp500_close.tail()
# Out:
#                      A    AAL         AAP        AAPL       ABBV        ABC  \
# Date
# 2020-10-23  106.169998  12.60  154.720001  115.040001  84.339996  99.379997
# 2020-10-26  104.629997  11.80  151.210007  115.050003  83.919998  98.370003
# 2020-10-27  106.040001  11.23  150.410004  116.599998  82.709999  97.650002
# 2020-10-28  101.660004  10.95  146.380005  111.199997  80.489998  95.699997
# 2020-10-29  102.019997  11.16  146.000000  115.320000  80.669998  94.589996
#
#                   ABMD         ABT         ACN        ADBE  ...        XLNX  \
# Date                                                        ...
# 2020-10-23  281.420013  107.790001  229.699997  488.500000  ...  116.820000
# 2020-10-26  288.320007  109.000000  219.229996  475.200012  ...  114.550003
# 2020-10-27  290.510010  108.580002  220.660004  478.559998  ...  124.349998
# 2020-10-28  283.000000  106.419998  213.940002  456.970001  ...  119.760002
# 2020-10-29  254.610001  105.000000  216.440002  461.109985  ...  122.900002
#
#                   XOM       XRAY    XRX        XYL         YUM         ZBH  \
# Date
# 2020-10-23  34.160000  49.150002  19.73  91.589996  101.279999  142.710007
# 2020-10-26  33.349998  47.610001  18.92  90.070000   99.199997  139.509995
# 2020-10-27  32.820000  47.540001  18.52  89.059998   97.989998  138.600006
# 2020-10-28  31.570000  44.840000  17.23  87.349998   95.059998  133.369995
# 2020-10-29  32.970001  44.799999  17.65  86.860001   94.940002  133.839996
#
#                   ZBRA       ZION         ZTS
# Date
# 2020-10-23  303.720001  33.200001  163.490005
# 2020-10-26  295.100006  32.459999  160.479996
# 2020-10-27  289.279999  31.080000  162.470001
# 2020-10-28  285.200012  30.600000  158.690002
# 2020-10-29  291.970001  31.559999  161.190002
#
# [5 rows x 501 columns]

# %%
sp500_close['AGN']
# Out:
# Date
# 2020-05-08   NaN
# 2020-05-11   NaN
# 2020-05-12   NaN
# 2020-05-13   NaN
# 2020-05-14   NaN
#               ..
# 2020-10-23   NaN
# 2020-10-26   NaN
# 2020-10-27   NaN
# 2020-10-28   NaN
# 2020-10-29   NaN
# Name: AGN, Length: 122, dtype: float64

# %%
sp500_close.drop(columns=['AGN'], inplace=True)

# %%
# Checking tickers with NaN values
for col in sp500_close:
    if sp500_close[col].isna().sum() > 0:
        print(col)
# Out:
# ARNC
# ETFC
# VIAC

# %%
sp500_close[['ARNC', 'ETFC', 'VIAC']]
# Out:
#                  ARNC       ETFC       VIAC
# Date
# 2020-05-08   9.120000  40.961483  17.931803
# 2020-05-11   8.780000  40.732868  17.892132
# 2020-05-12   8.520000  39.276699  18.100410
# 2020-05-13   8.300000  37.790607  16.711885
# 2020-05-14   8.330000  38.698219  17.019344
# ...               ...        ...        ...
# 2020-10-23  23.889999        NaN  29.280001
# 2020-10-26  23.440001        NaN  28.750000
# 2020-10-27  23.070000        NaN  28.209999
# 2020-10-28  21.190001        NaN  27.799999
# 2020-10-29  21.910000        NaN  28.129999
#
# [122 rows x 3 columns]

# %%
# Explaining the dropout of ETFC, which is ETrade Financial Corp, it appears that Morgan
# Stanley (MS) has acquired it. Since we still have a price for the date of the data scrape,
# it can still be useful for building an asset price model, but it will not be useful for 
# modeling returns.
# Need to look now for the rows with missing values for the other two
sp500_close[sp500_close['ARNC'].isna()]['ARNC']
# Out:
# Date
# 2020-10-01   NaN
# 2020-10-02   NaN
# Name: ARNC, dtype: float64

# %%
# Just a couple of missing values there, that won't affect our calculations
sp500_close[sp500_close['VIAC'].isna()]['VIAC']
# Out:
# Date
# 2020-06-05   NaN
# 2020-06-08   NaN
# 2020-06-09   NaN
# 2020-06-10   NaN
# 2020-06-11   NaN
# 2020-06-12   NaN
# 2020-06-15   NaN
# 2020-06-16   NaN
# 2020-06-17   NaN
# 2020-06-18   NaN
# 2020-06-19   NaN
# 2020-06-22   NaN
# Name: VIAC, dtype: float64

# %%
# Quite a few missing values there, probably through some issue with the yfinance method.
# Still, these missing values are not important for our purposes here.

# %%
# Get log prices, and drop ETFC which has pricing dropout
log_close = np.log(sp500_close).drop(columns=['ETFC'])
# Create a new dataframe to store our log returns
log_returns = pd.DataFrame(index=log_close.columns, columns=['log_return'])
# Populate new dataframe with log returns for each security
for col in log_close.columns:
    log_return = log_close[col].iloc[-1] - log_close[col].iloc[0]
    log_returns.loc[col, 'log_return'] = log_return
    
log_returns.head()
# Out:
#      log_return
# A      0.250673
# AAL   0.0958479
# AAP    0.161577
# AAPL   0.398815
# ABBV -0.0143164

# %%
# Looking at log_close df
log_close.head()
# Out:
#                    A       AAL       AAP      AAPL      ABBV       ABC  \
# Date
# 2020-05-08  4.374496  2.316488  4.822029  4.348896  4.404683  4.469251
# 2020-05-11  4.393878  2.312535  4.830722  4.364509  4.450542  4.497788
# 2020-05-12  4.376251  2.266958  4.819222  4.353015  4.479250  4.474799
# 2020-05-13  4.380126  2.209373  4.776055  4.340867  4.461517  4.423493
# 2020-05-14  4.398420  2.213754  4.791781  4.346992  4.473485  4.422066
#
#                 ABMD       ABT       ACN      ADBE  ...      XLNX       XOM  \
# Date                                                ...
# 2020-05-08  5.231483  4.532896  5.231851  5.906751  ...  4.456253  3.793807
# 2020-05-11  5.270998  4.557875  5.227546  5.917334  ...  4.451522  3.784234
# 2020-05-12  5.253791  4.533963  5.216675  5.900171  ...  4.426940  3.767377
# 2020-05-13  5.223594  4.516324  5.190932  5.882096  ...  4.403933  3.716466
# 2020-05-14  5.216402  4.512192  5.185336  5.873216  ...  4.432994  3.725251
#
#                 XRAY       XRX       XYL       YUM       ZBH      ZBRA  \
# Date
# 2020-05-08  3.700320  2.867282  4.135925  4.446337  4.799027  5.492732
# 2020-05-11  3.691921  2.836476  4.128436  4.448539  4.766754  5.460691
# 2020-05-12  3.605698  2.797027  4.071513  4.420715  4.728749  5.438948
# 2020-05-13  3.615386  2.702131  4.056847  4.377410  4.706315  5.407530
# 2020-05-14  3.629744  2.703432  4.069480  4.412227  4.715545  5.401641
#
#                 ZION       ZTS
# Date
# 2020-05-08  3.415260  4.829415
# 2020-05-11  3.364857  4.836721
# 2020-05-12  3.316461  4.817711
# 2020-05-13  3.260295  4.809777
# 2020-05-14  3.305986  4.833869
#
# [5 rows x 499 columns]

# %%
log_returns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 499 entries, A to ZTS
# Data columns (total 1 columns):
# log_return    499 non-null object
# dtypes: object(1)
# memory usage: 27.8+ KB

# %%
sns.distplot(log_returns.log_return)
plt.title('Distribution of Log Returns for SP500 since May 8, 2020')
# Out:
# Text(0.5, 1.0, 'Distribution of Log Returns for SP500 since May 8, 2020')

# %%
# We can see above that the distribution of log returns for the past 6 months of the SP500 is
# mostly normal, and that the mean return is greater than zero. This is important to take note
# of when we try and do some classification tests later, as it may be more useful to classify
# securities based on whether they outperformed/underperformed the market, rather than whether
# they were above/below zero. This is because the analysis of such classifications would be
# more robust to varying market conditions, ie when the market as a whole moved up or down,
# since the time period in question was an overall period of growth for the market, and future
# periods of consideration may be neutral, or negative overall, and it would be better to use
# the fundamental financial data to try to find securities which would under or overperform the
# market.

# %%
# First, let's look at the distribution of log prices for the date that the fundamentals data
# was scraped.
sns.distplot(log_close.iloc[0])
plt.title('Distribution of log prices for the date of the scrape');

# %%
# We can see that this target variable is mostly normal, which is conducive to modeling.
# Before we can make any models, we need to get our fundamentals data imported. There is a 
# function in the bot_functions file to help us do just that.
df = bf.build_big_df(sp500_tickers, 'data/sp500_close_05-08-2020')
df.head()
# Out:
#       % Above Low  % Below High  % Held by Institutions          52-Wk Range  \
# A             NaN        0.1206                  0.8499    ['61.13 - 90.64']
# AAL        0.1155           NaN                  0.8162     ['9.09 - 34.99']
# AAP           NaN        0.2717                  1.0080   ['71.33 - 171.43']
# AAPL          NaN        0.0540                  0.5986  ['170.27 - 327.85']
# ABBV          NaN        0.1420                  0.7329    ['62.55 - 97.86']
#
#       5yr Avg Return  5yr High  5yr Low  Annual Dividend $  Annual Dividend %  \
# A           0.127567     90.64    33.12               0.72             0.0092
# AAL        -0.171550     59.08     9.09                NaN                NaN
# AAP         0.019850    201.24    71.33               1.00             0.0084
# AAPL        0.214367    327.85    89.47               3.28             0.0108
# ABBV        0.064350    125.86    45.45               4.72             0.0560
#
#       Annual Dividend Yield  ...  marketEdge  marketEdge opinion  \
# A                    0.0092  ...         1.0    neutralfromavoid
# AAL                     NaN  ...         2.0    neutralfromavoid
# AAP                  0.0084  ...         1.0    neutralfromavoid
# AAPL                 0.0108  ...         3.0    neutralfromavoid
# ABBV                 0.0560  ...        -1.0     neutralfromlong
#
#       marketEdge opinion since  marketEdge since newConstructs  \
# A                   2020-05-01        2020-05-01           3.0
# AAL                 2020-05-01        2020-05-01           4.0
# AAP                 2020-05-01        2020-05-01           1.0
# AAPL                2020-05-01        2020-05-01           3.0
# ABBV                2020-05-01        2020-05-01           1.0
#
#       newConstructs since  researchTeam  researchTeam since  theStreet  \
# A              2020-05-08        reduce          2020-05-01        buy
# AAL            2020-05-08        reduce          2020-05-01       sell
# AAP            2020-05-08        reduce          2020-05-01       hold
# AAPL           2020-05-08          hold          2020-04-20        buy
# ABBV           2020-05-08          hold          2018-09-19       hold
#
#      theStreet since
# A         2016-03-28
# AAL       2020-05-01
# AAP       2020-03-17
# AAPL      2009-04-13
# ABBV      2019-08-27
#
# [5 rows x 106 columns]

# %% [markdown]
# ## Data Exploration

# %%
df.info(max_cols=200)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 501 entries, A to ZTS
# Data columns (total 106 columns):
# % Above Low                                          274 non-null float64
# % Below High                                         227 non-null float64
# % Held by Institutions                               495 non-null float64
# 52-Wk Range                                          501 non-null object
# 5yr Avg Return                                       501 non-null float64
# 5yr High                                             501 non-null float64
# 5yr Low                                              501 non-null float64
# Annual Dividend $                                    394 non-null float64
# Annual Dividend %                                    394 non-null float64
# Annual Dividend Yield                                389 non-null float64
# Ask                                                  494 non-null float64
# Ask Size                                             492 non-null float64
# Ask close                                            22 non-null float64
# B/A Ratio                                            492 non-null float64
# B/A Size                                             501 non-null object
# Beta                                                 488 non-null float64
# Bid                                                  499 non-null float64
# Bid Size                                             492 non-null float64
# Bid close                                            22 non-null float64
# Change Since Close                                   112 non-null object
# Change in Debt/Total Capital Quarter over Quarter    473 non-null float64
# Closing Price                                        500 non-null float64
# Day Change $                                         501 non-null float64
# Day Change %                                         501 non-null float64
# Day High                                             501 non-null float64
# Day Low                                              501 non-null float64
# Days to Cover                                        495 non-null float64
# Dividend Change %                                    405 non-null float64
# Dividend Growth 5yr                                  354 non-null float64
# Dividend Growth Rate, 3 Years                        392 non-null float64
# Dividend Pay Date                                    501 non-null object
# EPS (TTM, GAAP)                                      490 non-null float64
# EPS Growth (MRQ)                                     487 non-null float64
# EPS Growth (TTM)                                     489 non-null float64
# EPS Growth 5yr                                       438 non-null float64
# Ex-dividend                                          394 non-null object
# Ex-dividend Date                                     501 non-null object
# FCF Growth 5yr                                       485 non-null float64
# Float                                                495 non-null float64
# Gross Profit Margin (TTM)                            422 non-null float64
# Growth 1yr Consensus Est                             475 non-null float64
# Growth 1yr High Est                                  475 non-null float64
# Growth 1yr Low Est                                   475 non-null float64
# Growth 2yr Consensus Est                             497 non-null float64
# Growth 2yr High Est                                  497 non-null float64
# Growth 2yr Low Est                                   497 non-null float64
# Growth 3yr Historic                                  497 non-null float64
# Growth 5yr Actual/Est                                497 non-null float64
# Growth 5yr Consensus Est                             497 non-null float64
# Growth 5yr High Est                                  497 non-null float64
# Growth 5yr Low Est                                   497 non-null float64
# Growth Analysts                                      497 non-null float64
# Historical Volatility                                501 non-null float64
# Institutions Holding Shares                          495 non-null float64
# Interest Coverage (MRQ)                              389 non-null float64
# Last (size)                                          501 non-null float64
# Last (time)                                          501 non-null object
# Last Trade                                           112 non-null float64
# Market Cap                                           501 non-null object
# Market Edge Opinion:                                 485 non-null object
# Net Profit Margin (TTM)                              489 non-null float64
# Next Earnings Announcement                           489 non-null object
# Operating Profit Margin (TTM)                        489 non-null float64
# P/E Ratio (TTM, GAAP)                                451 non-null object
# PEG Ratio (TTM, GAAP)                                329 non-null float64
# Prev Close                                           501 non-null float64
# Price                                                1 non-null float64
# Price/Book (MRQ)                                     455 non-null float64
# Price/Cash Flow (TTM)                                468 non-null float64
# Price/Earnings (TTM)                                 448 non-null float64
# Price/Earnings (TTM, GAAP)                           448 non-null float64
# Price/Sales (TTM)                                    490 non-null float64
# Quick Ratio (MRQ)                                    323 non-null float64
# Return On Assets (TTM)                               479 non-null float64
# Return On Equity (TTM)                               453 non-null float64
# Return On Investment (TTM)                           437 non-null float64
# Revenue Growth (MRQ)                                 487 non-null float64
# Revenue Growth (TTM)                                 489 non-null float64
# Revenue Growth 5yr                                   490 non-null float64
# Revenue Per Employee (TTM)                           459 non-null float64
# Shares Outstanding                                   495 non-null float64
# Short Int Current Month                              495 non-null float64
# Short Int Pct of Float                               495 non-null float64
# Short Int Prev Month                                 495 non-null float64
# Short Interest                                       495 non-null float64
# Today's Open                                         501 non-null float64
# Total Debt/Total Capital (MRQ)                       460 non-null float64
# Volume                                               500 non-null float64
# Volume 10-day Avg                                    500 non-null float64
# Volume Past Day                                      501 non-null object
# cfra                                                 479 non-null float64
# cfra since                                           479 non-null datetime64[ns]
# creditSuisse                                         337 non-null object
# creditSuisse since                                   337 non-null datetime64[ns]
# ford                                                 493 non-null float64
# ford since                                           493 non-null datetime64[ns]
# marketEdge                                           484 non-null float64
# marketEdge opinion                                   484 non-null object
# marketEdge opinion since                             484 non-null datetime64[ns]
# marketEdge since                                     484 non-null datetime64[ns]
# newConstructs                                        494 non-null float64
# newConstructs since                                  494 non-null datetime64[ns]
# researchTeam                                         495 non-null object
# researchTeam since                                   495 non-null datetime64[ns]
# theStreet                                            496 non-null object
# theStreet since                                      496 non-null datetime64[ns]
# dtypes: datetime64[ns](8), float64(82), object(16)
# memory usage: 418.8+ KB

# %%
# Our raw df of the data has some columns with a lot of missing data, and some columns which
# don't qualify as fundamental data, or aren't useful.
# We will not want to include any columns that are directly related to the price of the security,
# since it is the price that we are trying to model, and these columns will be cheating.
# Our goal here is to use strictly fundamental data to try and predict the trading price of
# the security, in order to find securities which are under or over valued according to this 
# model. I will make a list by hand of columns which should not be used for this.
to_drop = ['% Above Low',
           '% Below High',
           '52-Wk Range', # Price related
           '5yr High', # Price related
           '5yr Low', # Price related
           'Annual Dividend $', # Leave this out because % is more generalized
           'Ask', # Price related
           'Ask Size', # Not fundamental
           'Ask close', # Price related
           'B/A Ratio', # Not fundamental
           'B/A Size',
           'Bid', # Price related
           'Bid Size',
           'Bid close', # Price related
           'Change Since Close', # Price related
           'Closing Price', # Price related
           'Day Change $', # Price related
           'Day Change %',
           'Day High',
           'Day Low',
           'Dividend Pay Date',
           'Ex-dividend',
           'Ex-dividend Date',
           'Last (size)',
           'Last (time)',
           'Last Trade',
           'Next Earnings Announcement',
           'Prev Close',
           'Price',
           "Today's Open",
           'Volume',
           'Volume Past Day',
           'cfra since',
           'creditSuisse since',
           'ford since',
           'marketEdge opinion since',
           'marketEdge since',
           'newConstructs since',
           'researchTeam since',
           'theStreet since'
          ]

X = df.drop(columns=to_drop)
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 501 entries, A to ZTS
# Data columns (total 66 columns):
# % Held by Institutions                               495 non-null float64
# 5yr Avg Return                                       501 non-null float64
# Annual Dividend %                                    394 non-null float64
# Annual Dividend Yield                                389 non-null float64
# Beta                                                 488 non-null float64
# Change in Debt/Total Capital Quarter over Quarter    473 non-null float64
# Days to Cover                                        495 non-null float64
# Dividend Change %                                    405 non-null float64
# Dividend Growth 5yr                                  354 non-null float64
# Dividend Growth Rate, 3 Years                        392 non-null float64
# EPS (TTM, GAAP)                                      490 non-null float64
# EPS Growth (MRQ)                                     487 non-null float64
# EPS Growth (TTM)                                     489 non-null float64
# EPS Growth 5yr                                       438 non-null float64
# FCF Growth 5yr                                       485 non-null float64
# Float                                                495 non-null float64
# Gross Profit Margin (TTM)                            422 non-null float64
# Growth 1yr Consensus Est                             475 non-null float64
# Growth 1yr High Est                                  475 non-null float64
# Growth 1yr Low Est                                   475 non-null float64
# Growth 2yr Consensus Est                             497 non-null float64
# Growth 2yr High Est                                  497 non-null float64
# Growth 2yr Low Est                                   497 non-null float64
# Growth 3yr Historic                                  497 non-null float64
# Growth 5yr Actual/Est                                497 non-null float64
# Growth 5yr Consensus Est                             497 non-null float64
# Growth 5yr High Est                                  497 non-null float64
# Growth 5yr Low Est                                   497 non-null float64
# Growth Analysts                                      497 non-null float64
# Historical Volatility                                501 non-null float64
# Institutions Holding Shares                          495 non-null float64
# Interest Coverage (MRQ)                              389 non-null float64
# Market Cap                                           501 non-null object
# Market Edge Opinion:                                 485 non-null object
# Net Profit Margin (TTM)                              489 non-null float64
# Operating Profit Margin (TTM)                        489 non-null float64
# P/E Ratio (TTM, GAAP)                                451 non-null object
# PEG Ratio (TTM, GAAP)                                329 non-null float64
# Price/Book (MRQ)                                     455 non-null float64
# Price/Cash Flow (TTM)                                468 non-null float64
# Price/Earnings (TTM)                                 448 non-null float64
# Price/Earnings (TTM, GAAP)                           448 non-null float64
# Price/Sales (TTM)                                    490 non-null float64
# Quick Ratio (MRQ)                                    323 non-null float64
# Return On Assets (TTM)                               479 non-null float64
# Return On Equity (TTM)                               453 non-null float64
# Return On Investment (TTM)                           437 non-null float64
# Revenue Growth (MRQ)                                 487 non-null float64
# Revenue Growth (TTM)                                 489 non-null float64
# Revenue Growth 5yr                                   490 non-null float64
# Revenue Per Employee (TTM)                           459 non-null float64
# Shares Outstanding                                   495 non-null float64
# Short Int Current Month                              495 non-null float64
# Short Int Pct of Float                               495 non-null float64
# Short Int Prev Month                                 495 non-null float64
# Short Interest                                       495 non-null float64
# Total Debt/Total Capital (MRQ)                       460 non-null float64
# Volume 10-day Avg                                    500 non-null float64
# cfra                                                 479 non-null float64
# creditSuisse                                         337 non-null object
# ford                                                 493 non-null float64
# marketEdge                                           484 non-null float64
# marketEdge opinion                                   484 non-null object
# newConstructs                                        494 non-null float64
# researchTeam                                         495 non-null object
# theStreet                                            496 non-null object
# dtypes: float64(59), object(7)
# memory usage: 262.2+ KB

# %%
# Comparing dividend related columns
X[['Annual Dividend %', 'Annual Dividend Yield']]
# Out:
#       Annual Dividend %  Annual Dividend Yield
# A                0.0092                 0.0092
# AAL                 NaN                    NaN
# AAP              0.0084                 0.0084
# AAPL             0.0108                 0.0108
# ABBV             0.0560                 0.0560
# ...                 ...                    ...
# YUM              0.0222                 0.0218
# ZBH              0.0080                 0.0079
# ZBRA                NaN                    NaN
# ZION             0.0460                 0.0443
# ZTS              0.0064                 0.0064
#
# [501 rows x 2 columns]

# %%
# We can see that these two columns are mostly the same, so the one with less missing values 
# should be dropped.
X = X.drop(columns='Annual Dividend Yield')

# %%
# We still have a somewhat disappointing number of missing values to deal with. To get a sense
# of how they are distributed among the securites, let's see what we have left over if we 
# drop them all.
X.dropna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 77 entries, AAP to ZTS
# Data columns (total 65 columns):
# % Held by Institutions                               77 non-null float64
# 5yr Avg Return                                       77 non-null float64
# Annual Dividend %                                    77 non-null float64
# Beta                                                 77 non-null float64
# Change in Debt/Total Capital Quarter over Quarter    77 non-null float64
# Days to Cover                                        77 non-null float64
# Dividend Change %                                    77 non-null float64
# Dividend Growth 5yr                                  77 non-null float64
# Dividend Growth Rate, 3 Years                        77 non-null float64
# EPS (TTM, GAAP)                                      77 non-null float64
# EPS Growth (MRQ)                                     77 non-null float64
# EPS Growth (TTM)                                     77 non-null float64
# EPS Growth 5yr                                       77 non-null float64
# FCF Growth 5yr                                       77 non-null float64
# Float                                                77 non-null float64
# Gross Profit Margin (TTM)                            77 non-null float64
# Growth 1yr Consensus Est                             77 non-null float64
# Growth 1yr High Est                                  77 non-null float64
# Growth 1yr Low Est                                   77 non-null float64
# Growth 2yr Consensus Est                             77 non-null float64
# Growth 2yr High Est                                  77 non-null float64
# Growth 2yr Low Est                                   77 non-null float64
# Growth 3yr Historic                                  77 non-null float64
# Growth 5yr Actual/Est                                77 non-null float64
# Growth 5yr Consensus Est                             77 non-null float64
# Growth 5yr High Est                                  77 non-null float64
# Growth 5yr Low Est                                   77 non-null float64
# Growth Analysts                                      77 non-null float64
# Historical Volatility                                77 non-null float64
# Institutions Holding Shares                          77 non-null float64
# Interest Coverage (MRQ)                              77 non-null float64
# Market Cap                                           77 non-null object
# Market Edge Opinion:                                 77 non-null object
# Net Profit Margin (TTM)                              77 non-null float64
# Operating Profit Margin (TTM)                        77 non-null float64
# P/E Ratio (TTM, GAAP)                                77 non-null object
# PEG Ratio (TTM, GAAP)                                77 non-null float64
# Price/Book (MRQ)                                     77 non-null float64
# Price/Cash Flow (TTM)                                77 non-null float64
# Price/Earnings (TTM)                                 77 non-null float64
# Price/Earnings (TTM, GAAP)                           77 non-null float64
# Price/Sales (TTM)                                    77 non-null float64
# Quick Ratio (MRQ)                                    77 non-null float64
# Return On Assets (TTM)                               77 non-null float64
# Return On Equity (TTM)                               77 non-null float64
# Return On Investment (TTM)                           77 non-null float64
# Revenue Growth (MRQ)                                 77 non-null float64
# Revenue Growth (TTM)                                 77 non-null float64
# Revenue Growth 5yr                                   77 non-null float64
# Revenue Per Employee (TTM)                           77 non-null float64
# Shares Outstanding                                   77 non-null float64
# Short Int Current Month                              77 non-null float64
# Short Int Pct of Float                               77 non-null float64
# Short Int Prev Month                                 77 non-null float64
# Short Interest                                       77 non-null float64
# Total Debt/Total Capital (MRQ)                       77 non-null float64
# Volume 10-day Avg                                    77 non-null float64
# cfra                                                 77 non-null float64
# creditSuisse                                         77 non-null object
# ford                                                 77 non-null float64
# marketEdge                                           77 non-null float64
# marketEdge opinion                                   77 non-null object
# newConstructs                                        77 non-null float64
# researchTeam                                         77 non-null object
# theStreet                                            77 non-null object
# dtypes: float64(58), object(7)
# memory usage: 39.7+ KB

# %%
# This is not very good news. There are only 77 securities for which we have data in all
# columns. We must address this issue

# %%
import missingno as msno

# %%
# A good way to investigate data sparsity is missingno
msno.matrix(X, labels=True)

# %%
# My first step is going to be to remove all analyst rating columns, like cfra and ford
# These are not really fundamentals information, though more investigation into them might be
# interesting to do some other time, to evaluate the quality of the ratings in terms of returns
# for certain investment horizons.
analysts = ['cfra', 
            'creditSuisse', 
            'ford', 
            'marketEdge', 
            'Market Edge Opinion:', 
            'marketEdge opinion'
            'newConstructs',
            'researchTeam',
            'theStreet'
           ]
X = X.drop(columns=analysts)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 501 entries, A to ZTS
# Data columns (total 57 columns):
# % Held by Institutions                               495 non-null float64
# 5yr Avg Return                                       501 non-null float64
# Annual Dividend %                                    394 non-null float64
# Beta                                                 488 non-null float64
# Change in Debt/Total Capital Quarter over Quarter    473 non-null float64
# Days to Cover                                        495 non-null float64
# Dividend Change %                                    405 non-null float64
# Dividend Growth 5yr                                  354 non-null float64
# Dividend Growth Rate, 3 Years                        392 non-null float64
# EPS (TTM, GAAP)                                      490 non-null float64
# EPS Growth (MRQ)                                     487 non-null float64
# EPS Growth (TTM)                                     489 non-null float64
# EPS Growth 5yr                                       438 non-null float64
# FCF Growth 5yr                                       485 non-null float64
# Float                                                495 non-null float64
# Gross Profit Margin (TTM)                            422 non-null float64
# Growth 1yr Consensus Est                             475 non-null float64
# Growth 1yr High Est                                  475 non-null float64
# Growth 1yr Low Est                                   475 non-null float64
# Growth 2yr Consensus Est                             497 non-null float64
# Growth 2yr High Est                                  497 non-null float64
# Growth 2yr Low Est                                   497 non-null float64
# Growth 3yr Historic                                  497 non-null float64
# Growth 5yr Actual/Est                                497 non-null float64
# Growth 5yr Consensus Est                             497 non-null float64
# Growth 5yr High Est                                  497 non-null float64
# Growth 5yr Low Est                                   497 non-null float64
# Growth Analysts                                      497 non-null float64
# Historical Volatility                                501 non-null float64
# Institutions Holding Shares                          495 non-null float64
# Interest Coverage (MRQ)                              389 non-null float64
# Market Cap                                           501 non-null object
# Net Profit Margin (TTM)                              489 non-null float64
# Operating Profit Margin (TTM)                        489 non-null float64
# P/E Ratio (TTM, GAAP)                                451 non-null object
# PEG Ratio (TTM, GAAP)                                329 non-null float64
# Price/Book (MRQ)                                     455 non-null float64
# Price/Cash Flow (TTM)                                468 non-null float64
# Price/Earnings (TTM)                                 448 non-null float64
# Price/Earnings (TTM, GAAP)                           448 non-null float64
# Price/Sales (TTM)                                    490 non-null float64
# Quick Ratio (MRQ)                                    323 non-null float64
# Return On Assets (TTM)                               479 non-null float64
# Return On Equity (TTM)                               453 non-null float64
# Return On Investment (TTM)                           437 non-null float64
# Revenue Growth (MRQ)                                 487 non-null float64
# Revenue Growth (TTM)                                 489 non-null float64
# Revenue Growth 5yr                                   490 non-null float64
# Revenue Per Employee (TTM)                           459 non-null float64
# Shares Outstanding                                   495 non-null float64
# Short Int Current Month                              495 non-null float64
# Short Int Pct of Float                               495 non-null float64
# Short Int Prev Month                                 495 non-null float64
# Short Interest                                       495 non-null float64
# Total Debt/Total Capital (MRQ)                       460 non-null float64
# Volume 10-day Avg                                    500 non-null float64
# marketEdge opinion                                   484 non-null object
# dtypes: float64(54), object(3)
# memory usage: 247.0+ KB

# %%
# Some more columns to address are dividend related.
# We can see that the Dividend %, which represents change in dividend amount over a 12 month
# period, has the least missing values, with 3 yr growth rate next, and with 5 yr growth rate
# having the most missing values. This pattern is likely resulting from the fact that some of 
# these companies don't have dividend data going back as far as others, either because they are
# a new company or because the ticker has changed in some way.
# Additionally, not all companies pay dividends to their stock holders. This is a category in
# and of itself, so it may be most useful to turn all dividend related columns into binned
# categorical variables, since the missing data actually contains information about the company,
# as well as the fact that the relationships between these columns may also provide insight.

# The same can be seen with EPS related info, and historical change of EPS.
# Some companies do not actually earn, and are currently operating at a loss, this would
# make them have no data, but since this is a useful category, these columns should be binned
# in the same way as the Dividend related columns.

# Gross Profit Margin may also be missing values because some companies are not reporting
# profits, we will bin this as well.

# The Growth related columns seen grouped together above all have to deal with what analysists
# have predicted vs what the actual growth rates were. It appears that only the 1yr column
# is missing a significant number of values, which is strange, so I may either bin this or drop
# it, since the 2yr column can be somewhat of a substitute. The only drawback to the latter is
# that analyst ratings on a 1 or 2 year period can be wildly different as a result of reporting
# periods and forseen problems that won't affect a company in the coming year, but will the
# following year.

# Interest coverage divides the available earnings of a company by it's interest obligations,
# so companies not making profits may not have info here. Can be binned into categories.

# %%
# Important to address is the ratios which involve price. Since price is part of how these
# ratios are calculated, and we are trying to regress price, we cannot include these columns
# as they are. What we can do is extract the other value from the ratio by factoring price
# back into the ratio. For instance, P/E ratio is Price/EPS, so Price/PE Ratio is EPS, and so on.

# P/E ratio is duplicated above as both P/E Ratio and Price/Earnings, with both GAAP and
# non-GAAP varieties. non-GAAP earnings is adjusted to exclude large non-recurring, one-off
# purchases or expenditures that a company made during the reporting period, to reduce 
# distortion of forecasts that the impact of these non-recurring events might cause. This means
# that for our purposes, we will most likely want to use non-GAAP numbers because this will 
# avoid taking into consideration large, nonrecurring expeditures made around the time of the 
# data scrape, which could distort projections about the companie's future performance.

# The PEG ratio is derivative of the PE Ratio, dividing this by the company's growth. Since
# this column is missing values and we already have information on earnings and growth, I
# will drop this column entirely.

to_drop = ['P/E Ratio (TTM, GAAP)',
            'PEG Ratio (TTM, GAAP)',
            'Price/Earnings (TTM, GAAP)',
           ]
X = X.drop(columns=to_drop)

# %%
# I'd like to see what the distribution of Gross Profit Margin is, to see if it can be negative
sns.distplot(X['Gross Profit Margin (TTM)'].dropna())

# %%
X['Gross Profit Margin (TTM)'].describe()
# Out:
# count    422.000000
# mean       0.477298
# std        0.214428
# min        0.027000
# 25%        0.320150
# 50%        0.454150
# 75%        0.641725
# max        0.956300
# Name: Gross Profit Margin (TTM), dtype: float64

# %%
# As we can see, there are no negative values for Gross Profit Margin, meaning that companies
# that are missing values in this field are probably operating at a loss. This column should
# be binned.

# %%
sns.distplot(X['Change in Debt/Total Capital Quarter over Quarter'].dropna())

# %%
# Let's look at FCF growth for binnability
sns.distplot(X['FCF Growth 5yr'].dropna())

# %%
# And at interest coverage
sns.distplot(X['Interest Coverage (MRQ)'].dropna());

# %%
sns.distplot(X['Net Profit Margin (TTM)'].dropna());

# %%
# We can see that net profit margin does go negative, and that the missing values are
# not present for some other reason. It may be better to drop these.
sns.distplot(X['Operating Profit Margin (TTM)'].dropna());

# %%
# The same is true for operating profit margin, except these columns are missing the same
# number of values so perhaps binning is the best move forward. There are not that many missing
# values, however, so first I will try dropping
# Checking another feature
sns.distplot(X['Total Debt/Total Capital (MRQ)'].dropna());

# %%
# Let's make a list of variables to bin just for the record:
to_bin = ['Annual Dividend %',
          'Dividend Change %',
          'Dividend Growth 5yr',
          'Dividend Growth Rate, 3 Years',
          'EPS (TTM, GAAP)',
          'EPS Growth (MRQ)',
          'EPS Growth (TTM)',
          'EPS Growth 5yr',
          #'FCF Growth 5yr',
          'Gross Profit Margin (TTM)',
          'Interest Coverage (MRQ)'
         ]

# %%
sns.distplot(X['Annual Dividend %'].dropna())

# %%
# testing cut with missing values:
test = pd.cut(X['Annual Dividend %'], 10)
test
# Out:
# A       (2.63e-05, 0.0176]
# AAL                    NaN
# AAP     (2.63e-05, 0.0176]
# AAPL    (2.63e-05, 0.0176]
# ABBV      (0.0523, 0.0697]
#                ...
# YUM       (0.0176, 0.0349]
# ZBH     (2.63e-05, 0.0176]
# ZBRA                   NaN
# ZION      (0.0349, 0.0523]
# ZTS     (2.63e-05, 0.0176]
# Name: Annual Dividend %, Length: 501, dtype: category
# Categories (10, interval[float64]): [(2.63e-05, 0.0176] < (0.0176, 0.0349] < (0.0349, 0.0523] < (0.0523, 0.0697] ... (0.104, 0.122] < (0.122, 0.139] < (0.139, 0.157] < (0.157, 0.174]]

# %%
pd.Series(np.where(test.isnull(), 'missing', test)).astype('category')
# Out:
# 0      (2.63e-05, 0.0176]
# 1                 missing
# 2      (2.63e-05, 0.0176]
# 3      (2.63e-05, 0.0176]
# 4        (0.0523, 0.0697]
#               ...
# 496      (0.0176, 0.0349]
# 497    (2.63e-05, 0.0176]
# 498               missing
# 499      (0.0349, 0.0523]
# 500    (2.63e-05, 0.0176]
# Length: 501, dtype: category
# Categories (11, object): [(2.63e-05, 0.0176], (0.0176, 0.0349], (0.0349, 0.0523], (0.0523, 0.0697], ..., (0.122, 0.139], (0.139, 0.157], (0.157, 0.174], missing]

# %%
# Now that we have a system of creating categorical variables to deal with columns which had
# missing values that would actually provide information, we can create them iteratively.
X2 = X.copy()
for col in to_bin:
    binned = pd.cut(X2[col], 10)
    X2[col + ' Cats'] = pd.Series(np.where(binned.isnull(), 'missing', binned), index=X2.index).astype('category')

X2 = X2.drop(columns=to_bin)

# %%
X2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 501 entries, A to ZTS
# Data columns (total 54 columns):
# % Held by Institutions                               495 non-null float64
# 5yr Avg Return                                       501 non-null float64
# Beta                                                 488 non-null float64
# Change in Debt/Total Capital Quarter over Quarter    473 non-null float64
# Days to Cover                                        495 non-null float64
# FCF Growth 5yr                                       485 non-null float64
# Float                                                495 non-null float64
# Growth 1yr Consensus Est                             475 non-null float64
# Growth 1yr High Est                                  475 non-null float64
# Growth 1yr Low Est                                   475 non-null float64
# Growth 2yr Consensus Est                             497 non-null float64
# Growth 2yr High Est                                  497 non-null float64
# Growth 2yr Low Est                                   497 non-null float64
# Growth 3yr Historic                                  497 non-null float64
# Growth 5yr Actual/Est                                497 non-null float64
# Growth 5yr Consensus Est                             497 non-null float64
# Growth 5yr High Est                                  497 non-null float64
# Growth 5yr Low Est                                   497 non-null float64
# Growth Analysts                                      497 non-null float64
# Historical Volatility                                501 non-null float64
# Institutions Holding Shares                          495 non-null float64
# Market Cap                                           501 non-null object
# Net Profit Margin (TTM)                              489 non-null float64
# Operating Profit Margin (TTM)                        489 non-null float64
# Price/Book (MRQ)                                     455 non-null float64
# Price/Cash Flow (TTM)                                468 non-null float64
# Price/Earnings (TTM)                                 448 non-null float64
# Price/Sales (TTM)                                    490 non-null float64
# Quick Ratio (MRQ)                                    323 non-null float64
# Return On Assets (TTM)                               479 non-null float64
# Return On Equity (TTM)                               453 non-null float64
# Return On Investment (TTM)                           437 non-null float64
# Revenue Growth (MRQ)                                 487 non-null float64
# Revenue Growth (TTM)                                 489 non-null float64
# Revenue Growth 5yr                                   490 non-null float64
# Revenue Per Employee (TTM)                           459 non-null float64
# Shares Outstanding                                   495 non-null float64
# Short Int Current Month                              495 non-null float64
# Short Int Pct of Float                               495 non-null float64
# Short Int Prev Month                                 495 non-null float64
# Short Interest                                       495 non-null float64
# Total Debt/Total Capital (MRQ)                       460 non-null float64
# Volume 10-day Avg                                    500 non-null float64
# marketEdge opinion                                   484 non-null object
# Annual Dividend % Cats                               501 non-null category
# Dividend Change % Cats                               501 non-null category
# Dividend Growth 5yr Cats                             501 non-null category
# Dividend Growth Rate, 3 Years Cats                   501 non-null category
# EPS (TTM, GAAP) Cats                                 501 non-null category
# EPS Growth (MRQ) Cats                                501 non-null category
# EPS Growth (TTM) Cats                                501 non-null category
# EPS Growth 5yr Cats                                  501 non-null category
# Gross Profit Margin (TTM) Cats                       501 non-null category
# Interest Coverage (MRQ) Cats                         501 non-null category
# dtypes: category(10), float64(42), object(2)
# memory usage: 184.9+ KB

# %%
# Now we need to deal with the Price ratios
to_fix = ['Price/Book (MRQ)',
          'Price/Cash Flow (TTM)',
          'Price/Earnings (TTM)',
          'Price/Sales (TTM)'
         ]

# %%
[ticker for ticker in X2.index if ticker not in sp500_close.columns]
# Out:
# ['AGN']

# %%
# Need to drop 'AGN' from our tickers
X2 = X2.drop('AGN', axis=0)

# %%
for col in to_fix:
    X2[col.replace('Price/','')] = sp500_close.iloc[0].T.loc[X2.index] / X2[col]

X3 = X2.copy().drop(columns=to_fix)
X3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500 entries, A to ZTS
# Data columns (total 54 columns):
# % Held by Institutions                               494 non-null float64
# 5yr Avg Return                                       500 non-null float64
# Beta                                                 487 non-null float64
# Change in Debt/Total Capital Quarter over Quarter    472 non-null float64
# Days to Cover                                        494 non-null float64
# FCF Growth 5yr                                       484 non-null float64
# Float                                                494 non-null float64
# Growth 1yr Consensus Est                             474 non-null float64
# Growth 1yr High Est                                  474 non-null float64
# Growth 1yr Low Est                                   474 non-null float64
# Growth 2yr Consensus Est                             496 non-null float64
# Growth 2yr High Est                                  496 non-null float64
# Growth 2yr Low Est                                   496 non-null float64
# Growth 3yr Historic                                  496 non-null float64
# Growth 5yr Actual/Est                                496 non-null float64
# Growth 5yr Consensus Est                             496 non-null float64
# Growth 5yr High Est                                  496 non-null float64
# Growth 5yr Low Est                                   496 non-null float64
# Growth Analysts                                      496 non-null float64
# Historical Volatility                                500 non-null float64
# Institutions Holding Shares                          494 non-null float64
# Market Cap                                           500 non-null object
# Net Profit Margin (TTM)                              488 non-null float64
# Operating Profit Margin (TTM)                        488 non-null float64
# Quick Ratio (MRQ)                                    322 non-null float64
# Return On Assets (TTM)                               478 non-null float64
# Return On Equity (TTM)                               452 non-null float64
# Return On Investment (TTM)                           436 non-null float64
# Revenue Growth (MRQ)                                 486 non-null float64
# Revenue Growth (TTM)                                 488 non-null float64
# Revenue Growth 5yr                                   489 non-null float64
# Revenue Per Employee (TTM)                           458 non-null float64
# Shares Outstanding                                   494 non-null float64
# Short Int Current Month                              494 non-null float64
# Short Int Pct of Float                               494 non-null float64
# Short Int Prev Month                                 494 non-null float64
# Short Interest                                       494 non-null float64
# Total Debt/Total Capital (MRQ)                       459 non-null float64
# Volume 10-day Avg                                    499 non-null float64
# marketEdge opinion                                   483 non-null object
# Annual Dividend % Cats                               500 non-null category
# Dividend Change % Cats                               500 non-null category
# Dividend Growth 5yr Cats                             500 non-null category
# Dividend Growth Rate, 3 Years Cats                   500 non-null category
# EPS (TTM, GAAP) Cats                                 500 non-null category
# EPS Growth (MRQ) Cats                                500 non-null category
# EPS Growth (TTM) Cats                                500 non-null category
# EPS Growth 5yr Cats                                  500 non-null category
# Gross Profit Margin (TTM) Cats                       500 non-null category
# Interest Coverage (MRQ) Cats                         500 non-null category
# Book (MRQ)                                           454 non-null float64
# Cash Flow (TTM)                                      467 non-null float64
# Earnings (TTM)                                       448 non-null float64
# Sales (TTM)                                          489 non-null float64
# dtypes: category(10), float64(42), object(2)
# memory usage: 184.5+ KB

# %%
X2['Earnings (TTM)'].hist()

# %%
X['EPS (TTM, GAAP)'].hist()

# %%
# Interestingly, these are quite different. Let's look at another feature just calculated
X2['Book (MRQ)'].hist()

# %%
X3.dropna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 235 entries, A to ZTS
# Data columns (total 54 columns):
# % Held by Institutions                               235 non-null float64
# 5yr Avg Return                                       235 non-null float64
# Beta                                                 235 non-null float64
# Change in Debt/Total Capital Quarter over Quarter    235 non-null float64
# Days to Cover                                        235 non-null float64
# FCF Growth 5yr                                       235 non-null float64
# Float                                                235 non-null float64
# Growth 1yr Consensus Est                             235 non-null float64
# Growth 1yr High Est                                  235 non-null float64
# Growth 1yr Low Est                                   235 non-null float64
# Growth 2yr Consensus Est                             235 non-null float64
# Growth 2yr High Est                                  235 non-null float64
# Growth 2yr Low Est                                   235 non-null float64
# Growth 3yr Historic                                  235 non-null float64
# Growth 5yr Actual/Est                                235 non-null float64
# Growth 5yr Consensus Est                             235 non-null float64
# Growth 5yr High Est                                  235 non-null float64
# Growth 5yr Low Est                                   235 non-null float64
# Growth Analysts                                      235 non-null float64
# Historical Volatility                                235 non-null float64
# Institutions Holding Shares                          235 non-null float64
# Market Cap                                           235 non-null object
# Net Profit Margin (TTM)                              235 non-null float64
# Operating Profit Margin (TTM)                        235 non-null float64
# Quick Ratio (MRQ)                                    235 non-null float64
# Return On Assets (TTM)                               235 non-null float64
# Return On Equity (TTM)                               235 non-null float64
# Return On Investment (TTM)                           235 non-null float64
# Revenue Growth (MRQ)                                 235 non-null float64
# Revenue Growth (TTM)                                 235 non-null float64
# Revenue Growth 5yr                                   235 non-null float64
# Revenue Per Employee (TTM)                           235 non-null float64
# Shares Outstanding                                   235 non-null float64
# Short Int Current Month                              235 non-null float64
# Short Int Pct of Float                               235 non-null float64
# Short Int Prev Month                                 235 non-null float64
# Short Interest                                       235 non-null float64
# Total Debt/Total Capital (MRQ)                       235 non-null float64
# Volume 10-day Avg                                    235 non-null float64
# marketEdge opinion                                   235 non-null object
# Annual Dividend % Cats                               235 non-null category
# Dividend Change % Cats                               235 non-null category
# Dividend Growth 5yr Cats                             235 non-null category
# Dividend Growth Rate, 3 Years Cats                   235 non-null category
# EPS (TTM, GAAP) Cats                                 235 non-null category
# EPS Growth (MRQ) Cats                                235 non-null category
# EPS Growth (TTM) Cats                                235 non-null category
# EPS Growth 5yr Cats                                  235 non-null category
# Gross Profit Margin (TTM) Cats                       235 non-null category
# Interest Coverage (MRQ) Cats                         235 non-null category
# Book (MRQ)                                           235 non-null float64
# Cash Flow (TTM)                                      235 non-null float64
# Earnings (TTM)                                       235 non-null float64
# Sales (TTM)                                          235 non-null float64
# dtypes: category(10), float64(42), object(2)
# memory usage: 88.8+ KB

# %%
X3[X3.columns[X3.isnull().any()]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500 entries, A to ZTS
# Data columns (total 41 columns):
# % Held by Institutions                               494 non-null float64
# Beta                                                 487 non-null float64
# Change in Debt/Total Capital Quarter over Quarter    472 non-null float64
# Days to Cover                                        494 non-null float64
# FCF Growth 5yr                                       484 non-null float64
# Float                                                494 non-null float64
# Growth 1yr Consensus Est                             474 non-null float64
# Growth 1yr High Est                                  474 non-null float64
# Growth 1yr Low Est                                   474 non-null float64
# Growth 2yr Consensus Est                             496 non-null float64
# Growth 2yr High Est                                  496 non-null float64
# Growth 2yr Low Est                                   496 non-null float64
# Growth 3yr Historic                                  496 non-null float64
# Growth 5yr Actual/Est                                496 non-null float64
# Growth 5yr Consensus Est                             496 non-null float64
# Growth 5yr High Est                                  496 non-null float64
# Growth 5yr Low Est                                   496 non-null float64
# Growth Analysts                                      496 non-null float64
# Institutions Holding Shares                          494 non-null float64
# Net Profit Margin (TTM)                              488 non-null float64
# Operating Profit Margin (TTM)                        488 non-null float64
# Quick Ratio (MRQ)                                    322 non-null float64
# Return On Assets (TTM)                               478 non-null float64
# Return On Equity (TTM)                               452 non-null float64
# Return On Investment (TTM)                           436 non-null float64
# Revenue Growth (MRQ)                                 486 non-null float64
# Revenue Growth (TTM)                                 488 non-null float64
# Revenue Growth 5yr                                   489 non-null float64
# Revenue Per Employee (TTM)                           458 non-null float64
# Shares Outstanding                                   494 non-null float64
# Short Int Current Month                              494 non-null float64
# Short Int Pct of Float                               494 non-null float64
# Short Int Prev Month                                 494 non-null float64
# Short Interest                                       494 non-null float64
# Total Debt/Total Capital (MRQ)                       459 non-null float64
# Volume 10-day Avg                                    499 non-null float64
# marketEdge opinion                                   483 non-null object
# Book (MRQ)                                           454 non-null float64
# Cash Flow (TTM)                                      467 non-null float64
# Earnings (TTM)                                       448 non-null float64
# Sales (TTM)                                          489 non-null float64
# dtypes: float64(40), object(1)
# memory usage: 184.1+ KB

# %%
# We have improved our situation, but not by enough. Let's look again at the sparsity of data
msno.matrix(X3[X3.columns[X3.isnull().any()]].copy())

# %%
# Quick Ratio has a lot of missing values
sns.distplot(X3['Quick Ratio (MRQ)'].dropna())

# %%
len(X3.columns)
# Out:
# 54

# %%
# Number of columns not missing values
len(X3.columns) - len(X3[X3.columns[X3.isnull().any()]].columns)
# Out:
# 13

# %%
X3.isnull().sum(axis=1).sort_values(ascending=False)[:15]
# Out:
# FOX      39
# NWS      37
# ARNC     26
# DISCK    25
# UA       25
# BIIB     25
# GOOG     25
# L        16
# RE       13
# PRU      13
# NUE      11
# FCX      11
# CTVA      9
# MET       8
# SBAC      7
# dtype: int64

# %%
to_bin = ['Quick Ratio (MRQ)',
          'Growth 1yr Consensus Est',
          'Change in Debt/Total Capital Quarter over Quarter',
          'Return On Assets (TTM)',
          'Return On Equity (TTM)',
          'Return On Investment (TTM)',
          'Revenue Per Employee (TTM)',
          'Total Debt/Total Capital (MRQ)',
          'Book (MRQ)',
          'Cash Flow (TTM)',
          'Earnings (TTM)',
         ]

X4 = X3.copy()
for col in to_bin:
    binned = pd.cut(X2[col], 10)
    X4[col + ' Cats'] = pd.Series(np.where(binned.isnull(), 'missing', binned), index=X2.index).astype('category')

X4 = X4.drop(columns=to_bin)
X4 = X4.drop(columns=['Growth 1yr High Est',
                      'Growth 1yr Low Est'
                     ])
X4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500 entries, A to ZTS
# Data columns (total 52 columns):
# % Held by Institutions                                    494 non-null float64
# 5yr Avg Return                                            500 non-null float64
# Beta                                                      487 non-null float64
# Days to Cover                                             494 non-null float64
# FCF Growth 5yr                                            484 non-null float64
# Float                                                     494 non-null float64
# Growth 2yr Consensus Est                                  496 non-null float64
# Growth 2yr High Est                                       496 non-null float64
# Growth 2yr Low Est                                        496 non-null float64
# Growth 3yr Historic                                       496 non-null float64
# Growth 5yr Actual/Est                                     496 non-null float64
# Growth 5yr Consensus Est                                  496 non-null float64
# Growth 5yr High Est                                       496 non-null float64
# Growth 5yr Low Est                                        496 non-null float64
# Growth Analysts                                           496 non-null float64
# Historical Volatility                                     500 non-null float64
# Institutions Holding Shares                               494 non-null float64
# Market Cap                                                500 non-null object
# Net Profit Margin (TTM)                                   488 non-null float64
# Operating Profit Margin (TTM)                             488 non-null float64
# Revenue Growth (MRQ)                                      486 non-null float64
# Revenue Growth (TTM)                                      488 non-null float64
# Revenue Growth 5yr                                        489 non-null float64
# Shares Outstanding                                        494 non-null float64
# Short Int Current Month                                   494 non-null float64
# Short Int Pct of Float                                    494 non-null float64
# Short Int Prev Month                                      494 non-null float64
# Short Interest                                            494 non-null float64
# Volume 10-day Avg                                         499 non-null float64
# marketEdge opinion                                        483 non-null object
# Annual Dividend % Cats                                    500 non-null category
# Dividend Change % Cats                                    500 non-null category
# Dividend Growth 5yr Cats                                  500 non-null category
# Dividend Growth Rate, 3 Years Cats                        500 non-null category
# EPS (TTM, GAAP) Cats                                      500 non-null category
# EPS Growth (MRQ) Cats                                     500 non-null category
# EPS Growth (TTM) Cats                                     500 non-null category
# EPS Growth 5yr Cats                                       500 non-null category
# Gross Profit Margin (TTM) Cats                            500 non-null category
# Interest Coverage (MRQ) Cats                              500 non-null category
# Sales (TTM)                                               489 non-null float64
# Quick Ratio (MRQ) Cats                                    500 non-null category
# Growth 1yr Consensus Est Cats                             500 non-null category
# Change in Debt/Total Capital Quarter over Quarter Cats    500 non-null category
# Return On Assets (TTM) Cats                               500 non-null category
# Return On Equity (TTM) Cats                               500 non-null category
# Return On Investment (TTM) Cats                           500 non-null category
# Revenue Per Employee (TTM) Cats                           500 non-null category
# Total Debt/Total Capital (MRQ) Cats                       500 non-null category
# Book (MRQ) Cats                                           500 non-null category
# Cash Flow (TTM) Cats                                      500 non-null category
# Earnings (TTM) Cats                                       500 non-null category
# dtypes: category(21), float64(29), object(2)
# memory usage: 143.1+ KB

# %%
X4.dropna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 448 entries, A to ZTS
# Data columns (total 52 columns):
# % Held by Institutions                                    448 non-null float64
# 5yr Avg Return                                            448 non-null float64
# Beta                                                      448 non-null float64
# Days to Cover                                             448 non-null float64
# FCF Growth 5yr                                            448 non-null float64
# Float                                                     448 non-null float64
# Growth 2yr Consensus Est                                  448 non-null float64
# Growth 2yr High Est                                       448 non-null float64
# Growth 2yr Low Est                                        448 non-null float64
# Growth 3yr Historic                                       448 non-null float64
# Growth 5yr Actual/Est                                     448 non-null float64
# Growth 5yr Consensus Est                                  448 non-null float64
# Growth 5yr High Est                                       448 non-null float64
# Growth 5yr Low Est                                        448 non-null float64
# Growth Analysts                                           448 non-null float64
# Historical Volatility                                     448 non-null float64
# Institutions Holding Shares                               448 non-null float64
# Market Cap                                                448 non-null object
# Net Profit Margin (TTM)                                   448 non-null float64
# Operating Profit Margin (TTM)                             448 non-null float64
# Revenue Growth (MRQ)                                      448 non-null float64
# Revenue Growth (TTM)                                      448 non-null float64
# Revenue Growth 5yr                                        448 non-null float64
# Shares Outstanding                                        448 non-null float64
# Short Int Current Month                                   448 non-null float64
# Short Int Pct of Float                                    448 non-null float64
# Short Int Prev Month                                      448 non-null float64
# Short Interest                                            448 non-null float64
# Volume 10-day Avg                                         448 non-null float64
# marketEdge opinion                                        448 non-null object
# Annual Dividend % Cats                                    448 non-null category
# Dividend Change % Cats                                    448 non-null category
# Dividend Growth 5yr Cats                                  448 non-null category
# Dividend Growth Rate, 3 Years Cats                        448 non-null category
# EPS (TTM, GAAP) Cats                                      448 non-null category
# EPS Growth (MRQ) Cats                                     448 non-null category
# EPS Growth (TTM) Cats                                     448 non-null category
# EPS Growth 5yr Cats                                       448 non-null category
# Gross Profit Margin (TTM) Cats                            448 non-null category
# Interest Coverage (MRQ) Cats                              448 non-null category
# Sales (TTM)                                               448 non-null float64
# Quick Ratio (MRQ) Cats                                    448 non-null category
# Growth 1yr Consensus Est Cats                             448 non-null category
# Change in Debt/Total Capital Quarter over Quarter Cats    448 non-null category
# Return On Assets (TTM) Cats                               448 non-null category
# Return On Equity (TTM) Cats                               448 non-null category
# Return On Investment (TTM) Cats                           448 non-null category
# Revenue Per Employee (TTM) Cats                           448 non-null category
# Total Debt/Total Capital (MRQ) Cats                       448 non-null category
# Book (MRQ) Cats                                           448 non-null category
# Cash Flow (TTM) Cats                                      448 non-null category
# Earnings (TTM) Cats                                       448 non-null category
# dtypes: category(21), float64(29), object(2)
# memory usage: 129.0+ KB

# %%
# This is looking much better than before, but not exactly ideal either. Let's take one more
# look at the missingno matrix
msno.matrix(X4, labels=True)

# %%
# Let's see what we can do with the data so far, without binning further
X5 = X4.dropna()

# %%
data = X5.merge(log_close.iloc[0].T, left_index=True, right_index=True)

# %%
# Renaming the target column
colname = data.columns[-1]
data.rename(columns={colname:'log_price'}, inplace=True)
data.head()
# Out:
#       % Held by Institutions  5yr Avg Return  Beta  Days to Cover  \
# A                     0.8499        0.127567   1.1        2.41083
# AAL                   0.8162       -0.171550   1.8        1.04128
# AAP                   1.0080        0.019850   1.3        1.42372
# AAPL                  0.5986        0.214367   1.2        0.90492
# ABBV                  0.7329        0.064350   0.8        9.11522
#
#       FCF Growth 5yr       Float  Growth 2yr Consensus Est  \
# A          -0.029725   308.50890                  0.087999
# AAL         0.970824   417.91770                 -2.671850
# AAP         0.176037    68.85382                  0.088077
# AAPL       -0.021708  4321.13500                  0.117766
# ABBV        0.145794  1475.02300                  0.084456
#
#       Growth 2yr High Est  Growth 2yr Low Est  Growth 3yr Historic  ...  \
# A                0.133081            0.042917             0.074225  ...
# AAL             -2.008852           -3.334849             0.002325  ...
# AAP              0.143638            0.032517             0.119104  ...
# AAPL             0.193309            0.042223             0.072870  ...
# ABBV             0.106217            0.062695             0.135679  ...
#
#       Change in Debt/Total Capital Quarter over Quarter Cats  \
# A                                    (0.00179, 0.00572]
# AAL                                 (-0.00214, 0.00179]
# AAP                                (-0.00607, -0.00214]
# AAPL                                (-0.00214, 0.00179]
# ABBV                                (-0.00214, 0.00179]
#
#       Return On Assets (TTM) Cats  Return On Equity (TTM) Cats  \
# A                 (0.0424, 0.156]              (-2.845, 3.606]
# AAL             (-0.0712, 0.0424]                      missing
# AAP               (0.0424, 0.156]              (-2.845, 3.606]
# AAPL                (0.156, 0.27]              (-2.845, 3.606]
# ABBV              (0.0424, 0.156]                      missing
#
#       Return On Investment (TTM) Cats  Revenue Per Employee (TTM) Cats  \
# A                    (-0.0153, 0.134]           (11769.848, 3621323.2]
# AAL                 (-0.165, -0.0153]           (11769.848, 3621323.2]
# AAP                  (-0.0153, 0.134]           (11769.848, 3621323.2]
# AAPL                   (0.134, 0.284]           (11769.848, 3621323.2]
# ABBV                   (0.134, 0.284]           (11769.848, 3621323.2]
#
#       Total Debt/Total Capital (MRQ) Cats  Book (MRQ) Cats  \
# A                       (-0.00472, 0.472]  (0.558, 69.531]
# AAL                        (0.943, 1.415]          missing
# AAP                     (-0.00472, 0.472]  (0.558, 69.531]
# AAPL                       (0.472, 0.943]  (0.558, 69.531]
# ABBV                       (0.943, 1.415]          missing
#
#      Cash Flow (TTM) Cats  Earnings (TTM) Cats  log_price
# A      (0.000833, 25.325]      (-0.195, 22.77]   4.374496
# AAL    (0.000833, 25.325]              missing   2.316488
# AAP    (0.000833, 25.325]      (-0.195, 22.77]   4.822029
# AAPL   (0.000833, 25.325]      (-0.195, 22.77]   4.348896
# ABBV   (0.000833, 25.325]      (-0.195, 22.77]   4.404683
#
# [5 rows x 53 columns]

# %%
import my_functions as mf

# %%
# Must remove all spaces from column names
colnames = [col.replace(' ','_') for col in data.columns]
data.columns = colnames

# %%
data.columns
# Out:
# Index(['%_Held_by_Institutions', '5yr_Avg_Return', 'Beta', 'Days_to_Cover',
#        'FCF_Growth_5yr', 'Float', 'Growth_2yr_Consensus_Est',
#        'Growth_2yr_High_Est', 'Growth_2yr_Low_Est', 'Growth_3yr_Historic',
#        'Growth_5yr_Actual/Est', 'Growth_5yr_Consensus_Est',
#        'Growth_5yr_High_Est', 'Growth_5yr_Low_Est', 'Growth_Analysts',
#        'Historical_Volatility', 'Institutions_Holding_Shares', 'Market_Cap',
#        'Net_Profit_Margin_(TTM)', 'Operating_Profit_Margin_(TTM)',
#        'Revenue_Growth_(MRQ)', 'Revenue_Growth_(TTM)', 'Revenue_Growth_5yr',
#        'Shares_Outstanding', 'Short_Int_Current_Month',
#        'Short_Int_Pct_of_Float', 'Short_Int_Prev_Month', 'Short_Interest',
#        'Volume_10-day_Avg', 'marketEdge_opinion', 'Annual_Dividend_%_Cats',
#        'Dividend_Change_%_Cats', 'Dividend_Growth_5yr_Cats',
#        'Dividend_Growth_Rate,_3_Years_Cats', 'EPS_(TTM,_GAAP)_Cats',
#        'EPS_Growth_(MRQ)_Cats', 'EPS_Growth_(TTM)_Cats', 'EPS_Growth_5yr_Cats',
#        'Gross_Profit_Margin_(TTM)_Cats', 'Interest_Coverage_(MRQ)_Cats',
#        'Sales_(TTM)', 'Quick_Ratio_(MRQ)_Cats',
#        'Growth_1yr_Consensus_Est_Cats',
#        'Change_in_Debt/Total_Capital_Quarter_over_Quarter_Cats',
#        'Return_On_Assets_(TTM)_Cats', 'Return_On_Equity_(TTM)_Cats',
#        'Return_On_Investment_(TTM)_Cats', 'Revenue_Per_Employee_(TTM)_Cats',
#        'Total_Debt/Total_Capital_(MRQ)_Cats', 'Book_(MRQ)_Cats',
#        'Cash_Flow_(TTM)_Cats', 'Earnings_(TTM)_Cats', 'log_price'],
#       dtype='object')

# %%
data.rename(columns={'%_Held_by_Institutions':'Pct_Held_by_Institutions',
                     '5yr_Avg_Return':'Avg_Return_5yr'
                    }, inplace=True)

# %%
# Must remove all spaces from column names
colnames = [col.replace('(','')\
            .replace(')','')\
            .replace('/','_')\
            .replace(',','')\
            .replace('%','Pct')\
            .replace('-','_') for col in data.columns]
data.columns = colnames

# %%
data.columns
# Out:
# Index(['Pct_Held_by_Institutions', 'Avg_Return_5yr', 'Beta', 'Days_to_Cover',
#        'FCF_Growth_5yr', 'Float', 'Growth_2yr_Consensus_Est',
#        'Growth_2yr_High_Est', 'Growth_2yr_Low_Est', 'Growth_3yr_Historic',
#        'Growth_5yr_Actual_Est', 'Growth_5yr_Consensus_Est',
#        'Growth_5yr_High_Est', 'Growth_5yr_Low_Est', 'Growth_Analysts',
#        'Historical_Volatility', 'Institutions_Holding_Shares', 'Market_Cap',
#        'Net_Profit_Margin_TTM', 'Operating_Profit_Margin_TTM',
#        'Revenue_Growth_MRQ', 'Revenue_Growth_TTM', 'Revenue_Growth_5yr',
#        'Shares_Outstanding', 'Short_Int_Current_Month',
#        'Short_Int_Pct_of_Float', 'Short_Int_Prev_Month', 'Short_Interest',
#        'Volume_10_day_Avg', 'marketEdge_opinion', 'Annual_Dividend_Pct_Cats',
#        'Dividend_Change_Pct_Cats', 'Dividend_Growth_5yr_Cats',
#        'Dividend_Growth_Rate_3_Years_Cats', 'EPS_TTM_GAAP_Cats',
#        'EPS_Growth_MRQ_Cats', 'EPS_Growth_TTM_Cats', 'EPS_Growth_5yr_Cats',
#        'Gross_Profit_Margin_TTM_Cats', 'Interest_Coverage_MRQ_Cats',
#        'Sales_TTM', 'Quick_Ratio_MRQ_Cats', 'Growth_1yr_Consensus_Est_Cats',
#        'Change_in_Debt_Total_Capital_Quarter_over_Quarter_Cats',
#        'Return_On_Assets_TTM_Cats', 'Return_On_Equity_TTM_Cats',
#        'Return_On_Investment_TTM_Cats', 'Revenue_Per_Employee_TTM_Cats',
#        'Total_Debt_Total_Capital_MRQ_Cats', 'Book_MRQ_Cats',
#        'Cash_Flow_TTM_Cats', 'Earnings_TTM_Cats', 'log_price'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 447 entries, A to ZTS
# Data columns (total 53 columns):
# Pct_Held_by_Institutions                                  447 non-null float64
# Avg_Return_5yr                                            447 non-null float64
# Beta                                                      447 non-null float64
# Days_to_Cover                                             447 non-null float64
# FCF_Growth_5yr                                            447 non-null float64
# Float                                                     447 non-null float64
# Growth_2yr_Consensus_Est                                  447 non-null float64
# Growth_2yr_High_Est                                       447 non-null float64
# Growth_2yr_Low_Est                                        447 non-null float64
# Growth_3yr_Historic                                       447 non-null float64
# Growth_5yr_Actual_Est                                     447 non-null float64
# Growth_5yr_Consensus_Est                                  447 non-null float64
# Growth_5yr_High_Est                                       447 non-null float64
# Growth_5yr_Low_Est                                        447 non-null float64
# Growth_Analysts                                           447 non-null float64
# Historical_Volatility                                     447 non-null float64
# Institutions_Holding_Shares                               447 non-null float64
# Market_Cap                                                447 non-null object
# Net_Profit_Margin_TTM                                     447 non-null float64
# Operating_Profit_Margin_TTM                               447 non-null float64
# Revenue_Growth_MRQ                                        447 non-null float64
# Revenue_Growth_TTM                                        447 non-null float64
# Revenue_Growth_5yr                                        447 non-null float64
# Shares_Outstanding                                        447 non-null float64
# Short_Int_Current_Month                                   447 non-null float64
# Short_Int_Pct_of_Float                                    447 non-null float64
# Short_Int_Prev_Month                                      447 non-null float64
# Short_Interest                                            447 non-null float64
# Volume_10_day_Avg                                         447 non-null float64
# marketEdge_opinion                                        447 non-null object
# Annual_Dividend_Pct_Cats                                  447 non-null category
# Dividend_Change_Pct_Cats                                  447 non-null category
# Dividend_Growth_5yr_Cats                                  447 non-null category
# Dividend_Growth_Rate_3_Years_Cats                         447 non-null category
# EPS_TTM_GAAP_Cats                                         447 non-null category
# EPS_Growth_MRQ_Cats                                       447 non-null category
# EPS_Growth_TTM_Cats                                       447 non-null category
# EPS_Growth_5yr_Cats                                       447 non-null category
# Gross_Profit_Margin_TTM_Cats                              447 non-null category
# Interest_Coverage_MRQ_Cats                                447 non-null category
# Sales_TTM                                                 447 non-null float64
# Quick_Ratio_MRQ_Cats                                      447 non-null category
# Growth_1yr_Consensus_Est_Cats                             447 non-null category
# Change_in_Debt_Total_Capital_Quarter_over_Quarter_Cats    447 non-null category
# Return_On_Assets_TTM_Cats                                 447 non-null category
# Return_On_Equity_TTM_Cats                                 447 non-null category
# Return_On_Investment_TTM_Cats                             447 non-null category
# Revenue_Per_Employee_TTM_Cats                             447 non-null category
# Total_Debt_Total_Capital_MRQ_Cats                         447 non-null category
# Book_MRQ_Cats                                             447 non-null category
# Cash_Flow_TTM_Cats                                        447 non-null category
# Earnings_TTM_Cats                                         447 non-null category
# log_price                                                 447 non-null float64
# dtypes: category(21), float64(30), object(2)
# memory usage: 132.2+ KB

# %%
data.isna().sum()
# Out:
# Pct_Held_by_Institutions                                  0
# Avg_Return_5yr                                            0
# Beta                                                      0
# Days_to_Cover                                             0
# FCF_Growth_5yr                                            0
# Float                                                     0
# Growth_2yr_Consensus_Est                                  0
# Growth_2yr_High_Est                                       0
# Growth_2yr_Low_Est                                        0
# Growth_3yr_Historic                                       0
# Growth_5yr_Actual_Est                                     0
# Growth_5yr_Consensus_Est                                  0
# Growth_5yr_High_Est                                       0
# Growth_5yr_Low_Est                                        0
# Growth_Analysts                                           0
# Historical_Volatility                                     0
# Institutions_Holding_Shares                               0
# Market_Cap                                                0
# Net_Profit_Margin_TTM                                     0
# Operating_Profit_Margin_TTM                               0
# Revenue_Growth_MRQ                                        0
# Revenue_Growth_TTM                                        0
# Revenue_Growth_5yr                                        0
# Shares_Outstanding                                        0
# Short_Int_Current_Month                                   0
# Short_Int_Pct_of_Float                                    0
# Short_Int_Prev_Month                                      0
# Short_Interest                                            0
# Volume_10_day_Avg                                         0
# marketEdge_opinion                                        0
# Annual_Dividend_Pct_Cats                                  0
# Dividend_Change_Pct_Cats                                  0
# Dividend_Growth_5yr_Cats                                  0
# Dividend_Growth_Rate_3_Years_Cats                         0
# EPS_TTM_GAAP_Cats                                         0
# EPS_Growth_MRQ_Cats                                       0
# EPS_Growth_TTM_Cats                                       0
# EPS_Growth_5yr_Cats                                       0
# Gross_Profit_Margin_TTM_Cats                              0
# Interest_Coverage_MRQ_Cats                                0
# Sales_TTM                                                 0
# Quick_Ratio_MRQ_Cats                                      0
# Growth_1yr_Consensus_Est_Cats                             0
# Change_in_Debt_Total_Capital_Quarter_over_Quarter_Cats    0
# Return_On_Assets_TTM_Cats                                 0
# Return_On_Equity_TTM_Cats                                 0
# Return_On_Investment_TTM_Cats                             0
# Revenue_Per_Employee_TTM_Cats                             0
# Total_Debt_Total_Capital_MRQ_Cats                         0
# Book_MRQ_Cats                                             0
# Cash_Flow_TTM_Cats                                        0
# Earnings_TTM_Cats                                         0
# log_price                                                 0
# dtype: int64

# %%
# Let's see if we can get a dirty linear regression to test our dataset
xcols = data.columns[:-1]
mf.do_a_linreg(data, xcols, 'log_price')
# Out:
# Linear Regression for log_price~Pct_Held_by_Institutions+Avg_Return_5yr+Beta+Days_to_Cover+FCF_Growth_5yr+Float+Growth_2yr_Consensus_Est+Growth_2yr_High_Est+Growth_2yr_Low_Est+Growth_3yr_Historic+Growth_5yr_Actual_Est+Growth_5yr_Consensus_Est+Growth_5yr_High_Est+Growth_5yr_Low_Est+Growth_Analysts+Historical_Volatility+Institutions_Holding_Shares+Market_Cap+Net_Profit_Margin_TTM+Operating_Profit_Margin_TTM+Revenue_Growth_MRQ+Revenue_Growth_TTM+Revenue_Growth_5yr+Shares_Outstanding+Short_Int_Current_Month+Short_Int_Pct_of_Float+Short_Int_Prev_Month+Short_Interest+Volume_10_day_Avg+marketEdge_opinion+Annual_Dividend_Pct_Cats+Dividend_Change_Pct_Cats+Dividend_Growth_5yr_Cats+Dividend_Growth_Rate_3_Years_Cats+EPS_TTM_GAAP_Cats+EPS_Growth_MRQ_Cats+EPS_Growth_TTM_Cats+EPS_Growth_5yr_Cats+Gross_Profit_Margin_TTM_Cats+Interest_Coverage_MRQ_Cats+Sales_TTM+Quick_Ratio_MRQ_Cats+Growth_1yr_Consensus_Est_Cats+Change_in_Debt_Total_Capital_Quarter_over_Quarter_Cats+Return_On_Assets_TTM_Cats+Return_On_Equity_TTM_Cats+Return_On_Investment_TTM_Cats+Revenue_Per_Employee_TTM_Cats+Total_Debt_Total_Capital_MRQ_Cats+Book_MRQ_Cats+Cash_Flow_TTM_Cats+Earnings_TTM_Cats
# ---------------------------------------------------------------------------
# MissingDataError                          Traceback (most recent call last)
# <ipython-input-82-a11c526370a9> in <module>
#       1 # Let's see if we can get a dirty linear regression to test our dataset
#       2 xcols = data.columns[:-1]
# ----> 3 mf.do_a_linreg(data, xcols, 'log_price')
#
# ~\Documents\Flatiron\mod5project\my_functions.py in do_a_linreg(dataframe, features, target)
#     429
#     430     # Build statsmodels mode
# --> 431     model = ols(formula, dataframe).fit()
#     432     display(model.summary())
#     433
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\model.py in from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     193                        'formula': formula,  # attach formula for unpckling
#     194                        'design_info': design_info})
# --> 195         mod = cls(endog, exog, *args, **kwargs)
#     196         mod.formula = formula
#     197
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     871                  **kwargs):
#     872         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 873                                   hasconst=hasconst, **kwargs)
#     874         if "weights" in self._init_keys:
#     875             self._init_keys.remove("weights")
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     702             weights = weights.squeeze()
#     703         super(WLS, self).__init__(endog, exog, missing=missing,
# --> 704                                   weights=weights, hasconst=hasconst, **kwargs)
#     705         nobs = self.exog.shape[0]
#     706         weights = self.weights
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, **kwargs)
#     188     """
#     189     def __init__(self, endog, exog, **kwargs):
# --> 190         super(RegressionModel, self).__init__(endog, exog, **kwargs)
#     191         self._data_attr.extend(['pinv_wexog', 'weights'])
#     192
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\model.py in __init__(self, endog, exog, **kwargs)
#     235
#     236     def __init__(self, endog, exog=None, **kwargs):
# --> 237         super(LikelihoodModel, self).__init__(endog, exog, **kwargs)
#     238         self.initialize()
#     239
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\model.py in __init__(self, endog, exog, **kwargs)
#      76         hasconst = kwargs.pop('hasconst', None)
#      77         self.data = self._handle_data(endog, exog, missing, hasconst,
# ---> 78                                       **kwargs)
#      79         self.k_constant = self.data.k_constant
#      80         self.exog = self.data.exog
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\model.py in _handle_data(self, endog, exog, missing, hasconst, **kwargs)
#      99
#     100     def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# --> 101         data = handle_data(endog, exog, missing, hasconst, **kwargs)
#     102         # kwargs arrays could have changed, easier to just attach here
#     103         for key in kwargs:
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\data.py in handle_data(endog, exog, missing, hasconst, **kwargs)
#     671     klass = handle_data_class_factory(endog, exog)
#     672     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
# --> 673                  **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\data.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#      85         self.const_idx = None
#      86         self.k_constant = 0
# ---> 87         self._handle_constant(hasconst)
#      88         self._check_integrity()
#      89         self._cache = {}
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\data.py in _handle_constant(self, hasconst)
#     131             exog_max = np.max(self.exog, axis=0)
#     132             if not np.isfinite(exog_max).all():
# --> 133                 raise MissingDataError('exog contains inf or nans')
#     134             exog_min = np.min(self.exog, axis=0)
#     135             const_idx = np.where(exog_max == exog_min)[0].squeeze()
#
# MissingDataError: exog contains inf or nans

# %%
# Looks like we have some infs in the data that weren't noticed before
data[data == np.inf].sum()
# Out:
# Pct_Held_by_Institutions                                  0.0
# Avg_Return_5yr                                            0.0
# Beta                                                      0.0
# Days_to_Cover                                             0.0
# FCF_Growth_5yr                                            0.0
# Float                                                     0.0
# Growth_2yr_Consensus_Est                                  inf
# Growth_2yr_High_Est                                       0.0
# Growth_2yr_Low_Est                                        inf
# Growth_3yr_Historic                                       0.0
# Growth_5yr_Actual_Est                                     0.0
# Growth_5yr_Consensus_Est                                  inf
# Growth_5yr_High_Est                                       0.0
# Growth_5yr_Low_Est                                        inf
# Growth_Analysts                                           0.0
# Historical_Volatility                                     0.0
# Institutions_Holding_Shares                               0.0
# Market_Cap                                                0.0
# Net_Profit_Margin_TTM                                     0.0
# Operating_Profit_Margin_TTM                               0.0
# Revenue_Growth_MRQ                                        0.0
# Revenue_Growth_TTM                                        0.0
# Revenue_Growth_5yr                                        0.0
# Shares_Outstanding                                        0.0
# Short_Int_Current_Month                                   0.0
# Short_Int_Pct_of_Float                                    0.0
# Short_Int_Prev_Month                                      0.0
# Short_Interest                                            0.0
# Volume_10_day_Avg                                         0.0
# marketEdge_opinion                                        0.0
# Annual_Dividend_Pct_Cats                                  0.0
# Dividend_Change_Pct_Cats                                  0.0
# Dividend_Growth_5yr_Cats                                  0.0
# Dividend_Growth_Rate_3_Years_Cats                         0.0
# EPS_TTM_GAAP_Cats                                         0.0
# EPS_Growth_MRQ_Cats                                       0.0
# EPS_Growth_TTM_Cats                                       0.0
# EPS_Growth_5yr_Cats                                       0.0
# Gross_Profit_Margin_TTM_Cats                              0.0
# Interest_Coverage_MRQ_Cats                                0.0
# Sales_TTM                                                 0.0
# Quick_Ratio_MRQ_Cats                                      0.0
# Growth_1yr_Consensus_Est_Cats                             0.0
# Change_in_Debt_Total_Capital_Quarter_over_Quarter_Cats    0.0
# Return_On_Assets_TTM_Cats                                 0.0
# Return_On_Equity_TTM_Cats                                 0.0
# Return_On_Investment_TTM_Cats                             0.0
# Revenue_Per_Employee_TTM_Cats                             0.0
# Total_Debt_Total_Capital_MRQ_Cats                         0.0
# Book_MRQ_Cats                                             0.0
# Cash_Flow_TTM_Cats                                        0.0
# Earnings_TTM_Cats                                         0.0
# log_price                                                 0.0
# dtype: float64

# %%
data['Growth_2yr_Consensus_Est'].describe()
# Out:
# count    447.000000
# mean            inf
# std             NaN
# min      -53.573755
# 25%       -0.035445
# 50%        0.040078
# 75%        0.100038
# max             inf
# Name: Growth_2yr_Consensus_Est, dtype: float64

# %%
data['Growth_2yr_Consensus_Est'].sort_values(ascending=False).head()
# Out:
# AXP           inf
# APTV    14.267208
# ALGN    10.720141
# INCY     7.722339
# CMG      6.346933
# Name: Growth_2yr_Consensus_Est, dtype: float64

# %%
data['Growth_2yr_Low_Est'].sort_values(ascending=False).head()
# Out:
# AXP           inf
# APTV    28.405400
# ALGN    21.165996
# CMG     12.223359
# UDR     12.000000
# Name: Growth_2yr_Low_Est, dtype: float64

# %%
data['Growth_5yr_Low_Est'].sort_values(ascending=False).head()
# Out:
# AXP           inf
# APTV    14.210748
# ALGN    14.145788
# UDR     12.000000
# CMG      6.403743
# Name: Growth_5yr_Low_Est, dtype: float64

# %%
# It seems as though AXP is the only problem here, we will just drop it and continue
data = data.drop('AXP', axis=0)

# %%
# Let's see if we can get a dirty linear regression to test our dataset
xcols = data.columns[:-1]
mf.do_a_linreg(data, xcols, 'log_price')
# Out:
# Linear Regression for log_price~Pct_Held_by_Institutions+Avg_Return_5yr+Beta+Days_to_Cover+FCF_Growth_5yr+Float+Growth_2yr_Consensus_Est+Growth_2yr_High_Est+Growth_2yr_Low_Est+Growth_3yr_Historic+Growth_5yr_Actual_Est+Growth_5yr_Consensus_Est+Growth_5yr_High_Est+Growth_5yr_Low_Est+Growth_Analysts+Historical_Volatility+Institutions_Holding_Shares+Market_Cap+Net_Profit_Margin_TTM+Operating_Profit_Margin_TTM+Revenue_Growth_MRQ+Revenue_Growth_TTM+Revenue_Growth_5yr+Shares_Outstanding+Short_Int_Current_Month+Short_Int_Pct_of_Float+Short_Int_Prev_Month+Short_Interest+Volume_10_day_Avg+marketEdge_opinion+Annual_Dividend_Pct_Cats+Dividend_Change_Pct_Cats+Dividend_Growth_5yr_Cats+Dividend_Growth_Rate_3_Years_Cats+EPS_TTM_GAAP_Cats+EPS_Growth_MRQ_Cats+EPS_Growth_TTM_Cats+EPS_Growth_5yr_Cats+Gross_Profit_Margin_TTM_Cats+Interest_Coverage_MRQ_Cats+Sales_TTM+Quick_Ratio_MRQ_Cats+Growth_1yr_Consensus_Est_Cats+Change_in_Debt_Total_Capital_Quarter_over_Quarter_Cats+Return_On_Assets_TTM_Cats+Return_On_Equity_TTM_Cats+Return_On_Investment_TTM_Cats+Revenue_Per_Employee_TTM_Cats+Total_Debt_Total_Capital_MRQ_Cats+Book_MRQ_Cats+Cash_Flow_TTM_Cats+Earnings_TTM_Cats
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1728: RuntimeWarning: divide by zero encountered in true_divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:901: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:901: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1892: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1650: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.dot(wresid, wresid) / self.df_resid
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\model.py:1452: RuntimeWarning: invalid value encountered in multiply
#   cov_p = self.normalized_cov_params * scale
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_price   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                   -inf
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Sun, 01 Nov 2020   Prob (F-statistic):                nan
# Time:                        23:03:29   Log-Likelihood:                 6880.7
# No. Observations:                 446   AIC:                        -1.287e+04
# Df Residuals:                       0   BIC:                        -1.104e+04
# Df Model:                         445
# Covariance Type:            nonrobust
# ==========================================================================================================================================================================
#                                                                                                              coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                                                  6.2913        inf          0        nan         nan         nan
# Market_Cap[T.1.3T]                                                                                         0.4610        inf          0        nan         nan         nan
# Market_Cap[T.1.4T]                                                                                         4.0470        inf          0        nan         nan         nan
# Market_Cap[T.1.7B]                                                                                         1.3956        inf          0        nan         nan         nan
# Market_Cap[T.1.9B]                                                                                        -0.7257        inf         -0        nan         nan         nan
# Market_Cap[T.10.3B]                                                                                        0.1066        inf          0        nan         nan         nan
# Market_Cap[T.10.5B]                                                                                        0.0443        inf          0        nan         nan         nan
# Market_Cap[T.10.7B]                                                                                       -1.4977        inf         -0        nan         nan         nan
# Market_Cap[T.10.8B]                                                                                       -0.7663        inf         -0        nan         nan         nan
# Market_Cap[T.10.9B]                                                                                        0.1181        inf          0        nan         nan         nan
# Market_Cap[T.105.5B]                                                                                       1.3487        inf          0        nan         nan         nan
# Market_Cap[T.105.7B]                                                                                       1.2813        inf          0        nan         nan         nan
# Market_Cap[T.106.1B]                                                                                       0.4745        inf          0        nan         nan         nan
# Market_Cap[T.106.4B]                                                                                       0.2675        inf          0        nan         nan         nan
# Market_Cap[T.107.4B]                                                                                      -0.5738        inf         -0        nan         nan         nan
# Market_Cap[T.109.2B]                                                                                       0.3638        inf          0        nan         nan         nan
# Market_Cap[T.11.0B]                                                                                        0.3636        inf          0        nan         nan         nan
# Market_Cap[T.11.1B]                                                                                        0.8716        inf          0        nan         nan         nan
# Market_Cap[T.11.2B]                                                                                       -0.6497        inf         -0        nan         nan         nan
# Market_Cap[T.11.3B]                                                                                       -0.5260        inf         -0        nan         nan         nan
# Market_Cap[T.11.5B]                                                                                        3.0798        inf          0        nan         nan         nan
# Market_Cap[T.11.6B]                                                                                       -0.5266        inf         -0        nan         nan         nan
# Market_Cap[T.11.7B]                                                                                        0.4200        inf          0        nan         nan         nan
# Market_Cap[T.11.8B]                                                                                       -0.5172        inf         -0        nan         nan         nan
# Market_Cap[T.11.9B]                                                                                        1.5250        inf          0        nan         nan         nan
# Market_Cap[T.110.0B]                                                                                      -0.1996        inf         -0        nan         nan         nan
# Market_Cap[T.112.1B]                                                                                       0.0874        inf          0        nan         nan         nan
# Market_Cap[T.112.4B]                                                                                      -0.9488        inf         -0        nan         nan         nan
# Market_Cap[T.112.6B]                                                                                       0.8746        inf          0        nan         nan         nan
# Market_Cap[T.12.1B]                                                                                       -0.2502        inf         -0        nan         nan         nan
# Market_Cap[T.12.4B]                                                                                       -0.5695        inf         -0        nan         nan         nan
# Market_Cap[T.12.5B]                                                                                        0.3339        inf          0        nan         nan         nan
# Market_Cap[T.12.6B]                                                                                       -0.2655        inf         -0        nan         nan         nan
# Market_Cap[T.12.9B]                                                                                        1.5237        inf          0        nan         nan         nan
# Market_Cap[T.120.2B]                                                                                      -0.4826        inf         -0        nan         nan         nan
# Market_Cap[T.121.7B]                                                                                       5.5413        inf          0        nan         nan         nan
# Market_Cap[T.124.0B]                                                                                       3.0998        inf          0        nan         nan         nan
# Market_Cap[T.13.0B]                                                                                        0.0116        inf          0        nan         nan         nan
# Market_Cap[T.13.1B]                                                                                        0.3620        inf          0        nan         nan         nan
# Market_Cap[T.13.2B]                                                                                        0.3216        inf          0        nan         nan         nan
# Market_Cap[T.13.3B]                                                                                        0.3834        inf          0        nan         nan         nan
# Market_Cap[T.13.4B]                                                                                       -0.5707        inf         -0        nan         nan         nan
# Market_Cap[T.13.5B]                                                                                       -0.2013        inf         -0        nan         nan         nan
# Market_Cap[T.13.8B]                                                                                        2.7163        inf          0        nan         nan         nan
# Market_Cap[T.13.9B]                                                                                       -0.4735        inf         -0        nan         nan         nan
# Market_Cap[T.131.5B]                                                                                      -1.3338        inf         -0        nan         nan         nan
# Market_Cap[T.132.7B]                                                                                      -2.0037        inf         -0        nan         nan         nan
# Market_Cap[T.134.7B]                                                                                      -1.4581        inf         -0        nan         nan         nan
# Market_Cap[T.135.1B]                                                                                       0.3661        inf          0        nan         nan         nan
# Market_Cap[T.138.1B]                                                                                      -0.3532        inf         -0        nan         nan         nan
# Market_Cap[T.14.0B]                                                                                       -2.7276        inf         -0        nan         nan         nan
# Market_Cap[T.14.4B]                                                                                        0.3296        inf          0        nan         nan         nan
# Market_Cap[T.14.5B]                                                                                        3.8550        inf          0        nan         nan         nan
# Market_Cap[T.14.6B]                                                                                       -1.0183        inf         -0        nan         nan         nan
# Market_Cap[T.14.7B]                                                                                       -0.4298        inf         -0        nan         nan         nan
# Market_Cap[T.14.8B]                                                                                       -2.2472        inf         -0        nan         nan         nan
# Market_Cap[T.14.9B]                                                                                        1.8706        inf          0        nan         nan         nan
# Market_Cap[T.140.7B]                                                                                       1.3439        inf          0        nan         nan         nan
# Market_Cap[T.146.8B]                                                                                      -0.3733        inf         -0        nan         nan         nan
# Market_Cap[T.15.0B]                                                                                       -0.0520        inf         -0        nan         nan         nan
# Market_Cap[T.15.3B]                                                                                        0.0649        inf          0        nan         nan         nan
# Market_Cap[T.15.4B]                                                                                        1.4152        inf          0        nan         nan         nan
# Market_Cap[T.15.5B]                                                                                        0.1934        inf          0        nan         nan         nan
# Market_Cap[T.15.6B]                                                                                        1.5606        inf          0        nan         nan         nan
# Market_Cap[T.15.8B]                                                                                       -0.3844        inf         -0        nan         nan         nan
# Market_Cap[T.15.9B]                                                                                       -0.2257        inf         -0        nan         nan         nan
# Market_Cap[T.158.1B]                                                                                      -1.4730        inf         -0        nan         nan         nan
# Market_Cap[T.16.0B]                                                                                       -1.8191        inf         -0        nan         nan         nan
# Market_Cap[T.16.1B]                                                                                        0.5809        inf          0        nan         nan         nan
# Market_Cap[T.16.2B]                                                                                        0.7325        inf          0        nan         nan         nan
# Market_Cap[T.16.3B]                                                                                       -0.0295        inf         -0        nan         nan         nan
# Market_Cap[T.16.4B]                                                                                       -0.4434        inf         -0        nan         nan         nan
# Market_Cap[T.16.5B]                                                                                       -0.3616        inf         -0        nan         nan         nan
# Market_Cap[T.16.9B]                                                                                       -0.8827        inf         -0        nan         nan         nan
# Market_Cap[T.165.7B]                                                                                       0.1585        inf          0        nan         nan         nan
# Market_Cap[T.166.8B]                                                                                       0.5249        inf          0        nan         nan         nan
# Market_Cap[T.168.9B]                                                                                       2.4623        inf          0        nan         nan         nan
# Market_Cap[T.17.3B]                                                                                        1.3185        inf          0        nan         nan         nan
# Market_Cap[T.17.4B]                                                                                       -1.0955        inf         -0        nan         nan         nan
# Market_Cap[T.17.5B]                                                                                       -0.7434        inf         -0        nan         nan         nan
# Market_Cap[T.17.7B]                                                                                        0.6311        inf          0        nan         nan         nan
# Market_Cap[T.17.8B]                                                                                       -0.2276        inf         -0        nan         nan         nan
# Market_Cap[T.170.0B]                                                                                       0.2355        inf          0        nan         nan         nan
# Market_Cap[T.177.1B]                                                                                       2.9036        inf          0        nan         nan         nan
# Market_Cap[T.178.2B]                                                                                       1.0716        inf          0        nan         nan         nan
# Market_Cap[T.18.0B]                                                                                       -0.2395        inf         -0        nan         nan         nan
# Market_Cap[T.18.1B]                                                                                        0.0727        inf          0        nan         nan         nan
# Market_Cap[T.18.4B]                                                                                       -0.8275        inf         -0        nan         nan         nan
# Market_Cap[T.18.5B]                                                                                       -1.2122        inf         -0        nan         nan         nan
# Market_Cap[T.18.6B]                                                                                        0.7485        inf          0        nan         nan         nan
# Market_Cap[T.18.8B]                                                                                       -0.9399        inf         -0        nan         nan         nan
# Market_Cap[T.18.9B]                                                                                        0.8650        inf          0        nan         nan         nan
# Market_Cap[T.182.3B]                                                                                      -1.3596        inf         -0        nan         nan         nan
# Market_Cap[T.19.1B]                                                                                        0.6624        inf          0        nan         nan         nan
# Market_Cap[T.19.2B]                                                                                       -0.1808        inf         -0        nan         nan         nan
# Market_Cap[T.19.4B]                                                                                       -0.1752        inf         -0        nan         nan         nan
# Market_Cap[T.19.5B]                                                                                        0.3441        inf          0        nan         nan         nan
# Market_Cap[T.19.6B]                                                                                       -3.0921        inf         -0        nan         nan         nan
# Market_Cap[T.191.6B]                                                                                       1.0200        inf          0        nan         nan         nan
# Market_Cap[T.192.2B]                                                                                      -0.0938        inf         -0        nan         nan         nan
# Market_Cap[T.192.8B]                                                                                      -1.2401        inf         -0        nan         nan         nan
# Market_Cap[T.195.4B]                                                                                      -0.4644        inf         -0        nan         nan         nan
# Market_Cap[T.197.2B]                                                                                       0.8763        inf          0        nan         nan         nan
# Market_Cap[T.198.0B]                                                                                       0.7141        inf          0        nan         nan         nan
# Market_Cap[T.2.2B]                                                                                        -3.1231        inf         -0        nan         nan         nan
# Market_Cap[T.2.7B]                                                                                         0.4461        inf          0        nan         nan         nan
# Market_Cap[T.2.8B]                                                                                         0.7153        inf          0        nan         nan         nan
# Market_Cap[T.20.0B]                                                                                       -0.4966        inf         -0        nan         nan         nan
# Market_Cap[T.20.1B]                                                                                        0.3705        inf          0        nan         nan         nan
# Market_Cap[T.20.2B]                                                                                       -1.0829        inf         -0        nan         nan         nan
# Market_Cap[T.20.7B]                                                                                        0.4376        inf          0        nan         nan         nan
# Market_Cap[T.20.8B]                                                                                        1.5257        inf          0        nan         nan         nan
# Market_Cap[T.20.9B]                                                                                       -1.4066        inf         -0        nan         nan         nan
# Market_Cap[T.206.5B]                                                                                      -0.1820        inf         -0        nan         nan         nan
# Market_Cap[T.21.0B]                                                                                        1.5692        inf          0        nan         nan         nan
# Market_Cap[T.21.2B]                                                                                        1.2085        inf          0        nan         nan         nan
# Market_Cap[T.21.4B]                                                                                        0.1018        inf          0        nan         nan         nan
# Market_Cap[T.21.5B]                                                                                       -0.1940        inf         -0        nan         nan         nan
# Market_Cap[T.21.6B]                                                                                        2.0693        inf          0        nan         nan         nan
# Market_Cap[T.21.7B]                                                                                       -0.2552        inf         -0        nan         nan         nan
# Market_Cap[T.21.8B]                                                                                        0.3456        inf          0        nan         nan         nan
# Market_Cap[T.21.9B]                                                                                       -0.6515        inf         -0        nan         nan         nan
# Market_Cap[T.212.3B]                                                                                       1.2081        inf          0        nan         nan         nan
# Market_Cap[T.22.0B]                                                                                        0.1890        inf          0        nan         nan         nan
# Market_Cap[T.22.1B]                                                                                        1.0208        inf          0        nan         nan         nan
# Market_Cap[T.22.2B]                                                                                       -2.4110        inf         -0        nan         nan         nan
# Market_Cap[T.22.3B]                                                                                        0.7208        inf          0        nan         nan         nan
# Market_Cap[T.22.4B]                                                                                       -0.8156        inf         -0        nan         nan         nan
# Market_Cap[T.22.5B]                                                                                       -2.0849        inf         -0        nan         nan         nan
# Market_Cap[T.22.7B]                                                                                       -1.3327        inf         -0        nan         nan         nan
# Market_Cap[T.23.0B]                                                                                       -0.5351        inf         -0        nan         nan         nan
# Market_Cap[T.23.1B]                                                                                        1.2587        inf          0        nan         nan         nan
# Market_Cap[T.23.5B]                                                                                        0.3771        inf          0        nan         nan         nan
# Market_Cap[T.23.6B]                                                                                       -1.6152        inf         -0        nan         nan         nan
# Market_Cap[T.23.8B]                                                                                       -0.3748        inf         -0        nan         nan         nan
# Market_Cap[T.23.9B]                                                                                        0.4509        inf          0        nan         nan         nan
# Market_Cap[T.235.9B]                                                                                       1.4794        inf          0        nan         nan         nan
# Market_Cap[T.24.1B]                                                                                       -0.5915        inf         -0        nan         nan         nan
# Market_Cap[T.24.3B]                                                                                       -0.5966        inf         -0        nan         nan         nan
# Market_Cap[T.24.5B]                                                                                       -0.2654        inf         -0        nan         nan         nan
# Market_Cap[T.24.6B]                                                                                        0.3374        inf          0        nan         nan         nan
# Market_Cap[T.24.7B]                                                                                       -0.3749        inf         -0        nan         nan         nan
# Market_Cap[T.24.8B]                                                                                        0.7490        inf          0        nan         nan         nan
# Market_Cap[T.25.1B]                                                                                        2.8232        inf          0        nan         nan         nan
# Market_Cap[T.25.2B]                                                                                        0.1348        inf          0        nan         nan         nan
# Market_Cap[T.25.3B]                                                                                        0.2038        inf          0        nan         nan         nan
# Market_Cap[T.25.4B]                                                                                        0.6580        inf          0        nan         nan         nan
# Market_Cap[T.25.7B]                                                                                        0.9204        inf          0        nan         nan         nan
# Market_Cap[T.25.8B]                                                                                       -0.1561        inf         -0        nan         nan         nan
# Market_Cap[T.25.9B]                                                                                       -0.5545        inf         -0        nan         nan         nan
# Market_Cap[T.251.8B]                                                                                      -0.4213        inf         -0        nan         nan         nan
# Market_Cap[T.252.6B]                                                                                       1.5474        inf          0        nan         nan         nan
# Market_Cap[T.26.0B]                                                                                       -0.2723        inf         -0        nan         nan         nan
# Market_Cap[T.26.2B]                                                                                        0.0064        inf          0        nan         nan         nan
# Market_Cap[T.26.3B]                                                                                       -0.4578        inf         -0        nan         nan         nan
# Market_Cap[T.26.5B]                                                                                       -1.8937        inf         -0        nan         nan         nan
# Market_Cap[T.26.6B]                                                                                       -0.0199        inf         -0        nan         nan         nan
# Market_Cap[T.26.8B]                                                                                       -2.0548        inf         -0        nan         nan         nan
# Market_Cap[T.26.9B]                                                                                       -0.3534        inf         -0        nan         nan         nan
# Market_Cap[T.27.0B]                                                                                       -0.0792        inf         -0        nan         nan         nan
# Market_Cap[T.27.1B]                                                                                        0.7853        inf          0        nan         nan         nan
# Market_Cap[T.27.7B]                                                                                       -0.1768        inf         -0        nan         nan         nan
# Market_Cap[T.27.9B]                                                                                        3.7018        inf          0        nan         nan         nan
# Market_Cap[T.272.2B]                                                                                      -0.0836        inf         -0        nan         nan         nan
# Market_Cap[T.28.3B]                                                                                        0.8811        inf          0        nan         nan         nan
# Market_Cap[T.283.5B]                                                                                      -0.8402        inf         -0        nan         nan         nan
# Market_Cap[T.287.1B]                                                                                      -0.4009        inf         -0        nan         nan         nan
# Market_Cap[T.29.5B]                                                                                       -1.7908        inf         -0        nan         nan         nan
# Market_Cap[T.29.9B]                                                                                        0.5317        inf          0        nan         nan         nan
# Market_Cap[T.3.0B]                                                                                         1.1698        inf          0        nan         nan         nan
# Market_Cap[T.3.1B]                                                                                         0.0778        inf          0        nan         nan         nan
# Market_Cap[T.3.2B]                                                                                        -3.1709        inf         -0        nan         nan         nan
# Market_Cap[T.3.3B]                                                                                         0.5922        inf          0        nan         nan         nan
# Market_Cap[T.3.4B]                                                                                         0.9331        inf          0        nan         nan         nan
# Market_Cap[T.3.5B]                                                                                        -0.3509        inf         -0        nan         nan         nan
# Market_Cap[T.3.7B]                                                                                        -2.1812        inf         -0        nan         nan         nan
# Market_Cap[T.3.8B]                                                                                        -1.3730        inf         -0        nan         nan         nan
# Market_Cap[T.3.9B]                                                                                         0.8368        inf          0        nan         nan         nan
# Market_Cap[T.30.9B]                                                                                       -1.6606        inf         -0        nan         nan         nan
# Market_Cap[T.31.3B]                                                                                       -0.6539        inf         -0        nan         nan         nan
# Market_Cap[T.31.5B]                                                                                        1.1874        inf          0        nan         nan         nan
# Market_Cap[T.31.7B]                                                                                       -0.8071        inf         -0        nan         nan         nan
# Market_Cap[T.32.0B]                                                                                        0.9255        inf          0        nan         nan         nan
# Market_Cap[T.32.5B]                                                                                       -1.2586        inf         -0        nan         nan         nan
# Market_Cap[T.32.6B]                                                                                        0.7456        inf          0        nan         nan         nan
# Market_Cap[T.32.9B]                                                                                        0.3778        inf          0        nan         nan         nan
# Market_Cap[T.33.3B]                                                                                       -0.4260        inf         -0        nan         nan         nan
# Market_Cap[T.33.5B]                                                                                       -1.0612        inf         -0        nan         nan         nan
# Market_Cap[T.33.7B]                                                                                       -0.6550        inf         -0        nan         nan         nan
# Market_Cap[T.33.8B]                                                                                       -1.8106        inf         -0        nan         nan         nan
# Market_Cap[T.34.2B]                                                                                       -0.5496        inf         -0        nan         nan         nan
# Market_Cap[T.34.6B]                                                                                        1.1993        inf          0        nan         nan         nan
# Market_Cap[T.34.7B]                                                                                        0.2974        inf          0        nan         nan         nan
# Market_Cap[T.348.4B]                                                                                       5.5663        inf          0        nan         nan         nan
# Market_Cap[T.36.1B]                                                                                        2.5370        inf          0        nan         nan         nan
# Market_Cap[T.36.2B]                                                                                       -0.6821        inf         -0        nan         nan         nan
# Market_Cap[T.36.3B]                                                                                        0.2249        inf          0        nan         nan         nan
# Market_Cap[T.36.4B]                                                                                       -0.1829        inf         -0        nan         nan         nan
# Market_Cap[T.36.5B]                                                                                       -0.0069        inf         -0        nan         nan         nan
# Market_Cap[T.36.6B]                                                                                       -0.2381        inf         -0        nan         nan         nan
# Market_Cap[T.37.4B]                                                                                        0.0988        inf          0        nan         nan         nan
# Market_Cap[T.38.2B]                                                                                       -0.8332        inf         -0        nan         nan         nan
# Market_Cap[T.38.5B]                                                                                        1.5284        inf          0        nan         nan         nan
# Market_Cap[T.38.8B]                                                                                        0.3334        inf          0        nan         nan         nan
# Market_Cap[T.38.9B]                                                                                        1.1376        inf          0        nan         nan         nan
# Market_Cap[T.39.6B]                                                                                       -0.5335        inf         -0        nan         nan         nan
# Market_Cap[T.392.0B]                                                                                       0.3215        inf          0        nan         nan         nan
# Market_Cap[T.394.1B]                                                                                       1.1811        inf          0        nan         nan         nan
# Market_Cap[T.4.0B]                                                                                         0.4341        inf          0        nan         nan         nan
# Market_Cap[T.4.1B]                                                                                         3.6759        inf          0        nan         nan         nan
# Market_Cap[T.4.3B]                                                                                         3.1081        inf          0        nan         nan         nan
# Market_Cap[T.4.5B]                                                                                        -1.4700        inf         -0        nan         nan         nan
# Market_Cap[T.4.6B]                                                                                        -0.1447        inf         -0        nan         nan         nan
# Market_Cap[T.4.7B]                                                                                        -2.7447        inf         -0        nan         nan         nan
# Market_Cap[T.4.9B]                                                                                        -0.2029        inf         -0        nan         nan         nan
# Market_Cap[T.40.4B]                                                                                       -1.2262        inf         -0        nan         nan         nan
# Market_Cap[T.42.6B]                                                                                       -1.7815        inf         -0        nan         nan         nan
# Market_Cap[T.43.0B]                                                                                        0.2466        inf          0        nan         nan         nan
# Market_Cap[T.43.5B]                                                                                       -1.2289        inf         -0        nan         nan         nan
# Market_Cap[T.43.9B]                                                                                       -0.2390        inf         -0        nan         nan         nan
# Market_Cap[T.44.4B]                                                                                       -1.5383        inf         -0        nan         nan         nan
# Market_Cap[T.44.8B]                                                                                       -1.1316        inf         -0        nan         nan         nan
# Market_Cap[T.45.0B]                                                                                        0.2595        inf          0        nan         nan         nan
# Market_Cap[T.45.6B]                                                                                        1.7061        inf          0        nan         nan         nan
# Market_Cap[T.46.2B]                                                                                        0.2109        inf          0        nan         nan         nan
# Market_Cap[T.47.0B]                                                                                       -3.2204        inf         -0        nan         nan         nan
# Market_Cap[T.47.2B]                                                                                        0.7637        inf          0        nan         nan         nan
# Market_Cap[T.49.4B]                                                                                       -0.9012        inf         -0        nan         nan         nan
# Market_Cap[T.49.9B]                                                                                        1.2324        inf          0        nan         nan         nan
# Market_Cap[T.5.0B]                                                                                        -1.8511        inf         -0        nan         nan         nan
# Market_Cap[T.5.1B]                                                                                         0.1413        inf          0        nan         nan         nan
# Market_Cap[T.5.3B]                                                                                         0.7865        inf          0        nan         nan         nan
# Market_Cap[T.5.4B]                                                                                        -2.3204        inf         -0        nan         nan         nan
# Market_Cap[T.5.6B]                                                                                         0.8544        inf          0        nan         nan         nan
# Market_Cap[T.5.8B]                                                                                         0.0202        inf          0        nan         nan         nan
# Market_Cap[T.5.9B]                                                                                         0.5682        inf          0        nan         nan         nan
# Market_Cap[T.50.6B]                                                                                       -0.8122        inf         -0        nan         nan         nan
# Market_Cap[T.51.1B]                                                                                       -0.1425        inf         -0        nan         nan         nan
# Market_Cap[T.51.2B]                                                                                       -1.2924        inf         -0        nan         nan         nan
# Market_Cap[T.51.6B]                                                                                       -0.9133        inf         -0        nan         nan         nan
# Market_Cap[T.51.8B]                                                                                       -1.4140        inf         -0        nan         nan         nan
# Market_Cap[T.52.6B]                                                                                       -0.3123        inf         -0        nan         nan         nan
# Market_Cap[T.53.4B]                                                                                       -0.6840        inf         -0        nan         nan         nan
# Market_Cap[T.53.7B]                                                                                       -2.3254        inf         -0        nan         nan         nan
# Market_Cap[T.54.6B]                                                                                        0.8883        inf          0        nan         nan         nan
# Market_Cap[T.55.0B]                                                                                        2.3643        inf          0        nan         nan         nan
# Market_Cap[T.56.4B]                                                                                       -1.2448        inf         -0        nan         nan         nan
# Market_Cap[T.57.2B]                                                                                        0.3866        inf          0        nan         nan         nan
# Market_Cap[T.57.9B]                                                                                       -0.3971        inf         -0        nan         nan         nan
# Market_Cap[T.58.1B]                                                                                        0.4129        inf          0        nan         nan         nan
# Market_Cap[T.58.3B]                                                                                        0.4185        inf          0        nan         nan         nan
# Market_Cap[T.58.5B]                                                                                       -2.9249        inf         -0        nan         nan         nan
# Market_Cap[T.58.6B]                                                                                        0.0501        inf          0        nan         nan         nan
# Market_Cap[T.59.4B]                                                                                        1.6590        inf          0        nan         nan         nan
# Market_Cap[T.59.6B]                                                                                       -0.0926        inf         -0        nan         nan         nan
# Market_Cap[T.6.0B]                                                                                         0.0804        inf          0        nan         nan         nan
# Market_Cap[T.6.1B]                                                                                        -0.8121        inf         -0        nan         nan         nan
# Market_Cap[T.6.2B]                                                                                        -0.0408        inf         -0        nan         nan         nan
# Market_Cap[T.6.3B]                                                                                        -0.3913        inf         -0        nan         nan         nan
# ...
# Return_On_Assets_TTM_Cats[T.missing]                                                                       3.1415        inf          0        nan         nan         nan
# Return_On_Equity_TTM_Cats[T.Interval(3.606, 9.993, closed='right')]                                       -0.8445        inf         -0        nan         nan         nan
# Return_On_Equity_TTM_Cats[T.Interval(54.704, 61.091, closed='right')]                                     -0.3420        inf         -0        nan         nan         nan
# Return_On_Equity_TTM_Cats[T.missing]                                                                      -0.9804        inf         -0        nan         nan         nan
# Return_On_Investment_TTM_Cats[T.Interval(-0.464, -0.315, closed='right')]                                  2.8232        inf          0        nan         nan         nan
# Return_On_Investment_TTM_Cats[T.Interval(-0.315, -0.165, closed='right')]                                  1.6868        inf          0        nan         nan         nan
# Return_On_Investment_TTM_Cats[T.Interval(-0.165, -0.0153, closed='right')]                                 0.0172        inf          0        nan         nan         nan
# Return_On_Investment_TTM_Cats[T.Interval(-0.0153, 0.134, closed='right')]                                 -1.7651        inf         -0        nan         nan         nan
# Return_On_Investment_TTM_Cats[T.Interval(0.134, 0.284, closed='right')]                                   -1.7803        inf         -0        nan         nan         nan
# Return_On_Investment_TTM_Cats[T.Interval(0.284, 0.434, closed='right')]                                   -0.3068        inf         -0        nan         nan         nan
# Return_On_Investment_TTM_Cats[T.Interval(0.434, 0.583, closed='right')]                                    0.1527        inf          0        nan         nan         nan
# Return_On_Investment_TTM_Cats[T.Interval(0.733, 0.883, closed='right')]                                   -1.6281        inf         -0        nan         nan         nan
# Return_On_Investment_TTM_Cats[T.missing]                                                                  -1.2473        inf         -0        nan         nan         nan
# Revenue_Per_Employee_TTM_Cats[T.Interval(3621323.2, 7195138.4, closed='right')]                            0.2403        inf          0        nan         nan         nan
# Revenue_Per_Employee_TTM_Cats[T.Interval(7195138.4, 10768953.6, closed='right')]                           0.3603        inf          0        nan         nan         nan
# Revenue_Per_Employee_TTM_Cats[T.Interval(10768953.6, 14342768.8, closed='right')]                               0        nan        nan        nan         nan         nan
# Revenue_Per_Employee_TTM_Cats[T.Interval(28638029.6, 32211844.8, closed='right')]                         -0.7497        inf         -0        nan         nan         nan
# Revenue_Per_Employee_TTM_Cats[T.Interval(32211844.8, 35785660.0, closed='right')]                          0.7120        inf          0        nan         nan         nan
# Revenue_Per_Employee_TTM_Cats[T.missing]                                                                   0.3959        inf          0        nan         nan         nan
# Total_Debt_Total_Capital_MRQ_Cats[T.Interval(0.472, 0.943, closed='right')]                               -0.1485        inf         -0        nan         nan         nan
# Total_Debt_Total_Capital_MRQ_Cats[T.Interval(0.943, 1.415, closed='right')]                                0.6701        inf          0        nan         nan         nan
# Total_Debt_Total_Capital_MRQ_Cats[T.Interval(1.415, 1.887, closed='right')]                                0.3547        inf          0        nan         nan         nan
# Total_Debt_Total_Capital_MRQ_Cats[T.Interval(1.887, 2.359, closed='right')]                               -0.2008        inf         -0        nan         nan         nan
# Total_Debt_Total_Capital_MRQ_Cats[T.Interval(3.302, 3.774, closed='right')]                                2.1764        inf          0        nan         nan         nan
# Total_Debt_Total_Capital_MRQ_Cats[T.Interval(4.245, 4.717, closed='right')]                               -0.5966        inf         -0        nan         nan         nan
# Total_Debt_Total_Capital_MRQ_Cats[T.missing]                                                              -1.2952        inf         -0        nan         nan         nan
# Book_MRQ_Cats[T.Interval(69.531, 137.821, closed='right')]                                                -0.2719        inf         -0        nan         nan         nan
# Book_MRQ_Cats[T.Interval(137.821, 206.111, closed='right')]                                                0.3175        inf          0        nan         nan         nan
# Book_MRQ_Cats[T.Interval(206.111, 274.401, closed='right')]                                                0.3688        inf          0        nan         nan         nan
# Book_MRQ_Cats[T.Interval(274.401, 342.692, closed='right')]                                                0.2532        inf          0        nan         nan         nan
# Book_MRQ_Cats[T.Interval(615.852, 684.143, closed='right')]                                               -0.1354        inf         -0        nan         nan         nan
# Book_MRQ_Cats[T.missing]                                                                                   0.0038        inf          0        nan         nan         nan
# Cash_Flow_TTM_Cats[T.Interval(25.325, 50.398, closed='right')]                                            -0.0360        inf         -0        nan         nan         nan
# Cash_Flow_TTM_Cats[T.Interval(50.398, 75.471, closed='right')]                                            -0.1405        inf         -0        nan         nan         nan
# Cash_Flow_TTM_Cats[T.Interval(75.471, 100.545, closed='right')]                                            0.3374        inf          0        nan         nan         nan
# Cash_Flow_TTM_Cats[T.Interval(125.618, 150.691, closed='right')]                                           0.0501        inf          0        nan         nan         nan
# Cash_Flow_TTM_Cats[T.Interval(225.911, 250.984, closed='right')]                                          -0.1354        inf         -0        nan         nan         nan
# Cash_Flow_TTM_Cats[T.missing]                                                                             -5.2380        inf         -0        nan         nan         nan
# Earnings_TTM_Cats[T.Interval(22.77, 45.508, closed='right')]                                              -1.0905        inf         -0        nan         nan         nan
# Earnings_TTM_Cats[T.Interval(45.508, 68.246, closed='right')]                                              0.2532        inf          0        nan         nan         nan
# Earnings_TTM_Cats[T.Interval(68.246, 90.985, closed='right')]                                              0.3374        inf          0        nan         nan         nan
# Earnings_TTM_Cats[T.Interval(90.985, 113.723, closed='right')]                                             0.0501        inf          0        nan         nan         nan
# Earnings_TTM_Cats[T.Interval(204.675, 227.413, closed='right')]                                           -0.1354        inf         -0        nan         nan         nan
# Earnings_TTM_Cats[T.missing]                                                                              -0.3348        inf         -0        nan         nan         nan
# Pct_Held_by_Institutions                                                                                   0.2522        inf          0        nan         nan         nan
# Avg_Return_5yr                                                                                             1.5717        inf          0        nan         nan         nan
# Beta                                                                                                       0.7589        inf          0        nan         nan         nan
# Days_to_Cover                                                                                              0.0630        inf          0        nan         nan         nan
# FCF_Growth_5yr                                                                                            -0.0303        inf         -0        nan         nan         nan
# Float                                                                                                      0.0032        inf          0        nan         nan         nan
# Growth_2yr_Consensus_Est                                                                                  -0.0653        inf         -0        nan         nan         nan
# Growth_2yr_High_Est                                                                                       -0.3073        inf         -0        nan         nan         nan
# Growth_2yr_Low_Est                                                                                         0.1767        inf          0        nan         nan         nan
# Growth_3yr_Historic                                                                                       -0.0993        inf         -0        nan         nan         nan
# Growth_5yr_Actual_Est                                                                                      0.0333        inf          0        nan         nan         nan
# Growth_5yr_Consensus_Est                                                                                   0.2668        inf          0        nan         nan         nan
# Growth_5yr_High_Est                                                                                        0.8244        inf          0        nan         nan         nan
# Growth_5yr_Low_Est                                                                                        -0.2908        inf         -0        nan         nan         nan
# Growth_Analysts                                                                                            0.0208        inf          0        nan         nan         nan
# Historical_Volatility                                                                                     -4.5959        inf         -0        nan         nan         nan
# Institutions_Holding_Shares                                                                                0.0005        inf          0        nan         nan         nan
# Net_Profit_Margin_TTM                                                                                      0.3679        inf          0        nan         nan         nan
# Operating_Profit_Margin_TTM                                                                                0.9353        inf          0        nan         nan         nan
# Revenue_Growth_MRQ                                                                                        -0.4617        inf         -0        nan         nan         nan
# Revenue_Growth_TTM                                                                                        -2.2538        inf         -0        nan         nan         nan
# Revenue_Growth_5yr                                                                                         4.9802        inf          0        nan         nan         nan
# Shares_Outstanding                                                                                        -0.0035        inf         -0        nan         nan         nan
# Short_Int_Current_Month                                                                                  2.47e-08        inf          0        nan         nan         nan
# Short_Int_Pct_of_Float                                                                                    -0.0612        inf         -0        nan         nan         nan
# Short_Int_Prev_Month                                                                                   -4.983e-08        inf         -0        nan         nan         nan
# Short_Interest                                                                                            -0.0630        inf         -0        nan         nan         nan
# Volume_10_day_Avg                                                                                      -1.922e-08        inf         -0        nan         nan         nan
# Sales_TTM                                                                                                 -0.0008        inf         -0        nan         nan         nan
# ==============================================================================
# Omnibus:                      171.883   Durbin-Watson:                   1.884
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10314.478
# Skew:                           0.777   Prob(JB):                         0.00
# Kurtosis:                      26.508   Cond. No.                     7.21e+10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# [3] The condition number is large, 7.21e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
# Test for homoscedasticity of residuals:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:901: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:901: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1807: RuntimeWarning: invalid value encountered in greater_equal
#   cond2 = (x >= _b) & cond0
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1892: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
#                 F_statistic p_value
# Goldfeld-Quandt         NaN     NaN
# Normality Test Results for ['residuals']:
# -------------------------------------------------------------------------------------------
# <table style="display:inline" cellpadding=100><td>K-S and Shapiro-Wilk:<br/><table style="display:inline" cellpadding=100 border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>K-S</th>
#       <th>Shapiro-Wilk</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">residuals</th>
#       <th>Statistic</th>
#       <td>4.999999e-01</td>
#       <td>7.593049e-01</td>
#     </tr>
#     <tr>
#       <th>p-value</th>
#       <td>1.252112e-103</td>
#       <td>5.218734e-25</td>
#     </tr>
#   </tbody>
# </table style="display:inline" cellpadding=100></td><td>Anderson-Darling:<br/><table style="display:inline" cellpadding=100 border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>statistic</th>
#       <th>critical</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>residuals</th>
#       <td>21.33943</td>
#       <td>0.78</td>
#     </tr>
#   </tbody>
# </table style="display:inline" cellpadding=100></td><td>Jarque-Bera:<br/><table style="display:inline" cellpadding=100 border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>residuals</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Statistic</th>
#       <td>10314.478435</td>
#     </tr>
#     <tr>
#       <th>p-value</th>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>0.776899</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>26.507976</td>
#     </tr>
#   </tbody>
# </table style="display:inline" cellpadding=100></td></table style="display:inline" cellpadding=100></body>
# Skew: 0.7768986063454224
# Kurtosis: 23.507975508990057

# %%
# We've run into the problem that with all of these categorical variables, there are far more
# features than there are observations. We can use dimensionality reducting when this becomes
# an issue. It is also appropriate to scale a dataset before modeling to compare feature
# importances, and this is also necessary for some dimensionality reduction techniques

# %% [markdown]
# ### Imputing Data

# %% [markdown]
# Apparently, [PCA is only really meaningful using continuous data](https://stackoverflow.com/questions/40795141/pca-for-categorical-features), which we don't have now that we've created all of these categorical variables to make up for the missing data rows.

# %% [markdown]
# To solve this problem, imputing data may help greatly. One of the reasons that we've had to do all of these gymnastics with creating categorical variables is because there are missing data values mixed up between many rows (as we recall there were only 77 rows which had all the data available, but on average there were not that many rows missing from any particular feature).
#
# Scikit-learn has imputing capabilities, I will now try to implement some of them.

# %%
# First, let's rewind our data transformations to before we started making everything
# categorical
X.info(max_cols=200)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 501 entries, A to ZTS
# Data columns (total 53 columns):
# % Held by Institutions                               495 non-null float64
# 5yr Avg Return                                       501 non-null float64
# Annual Dividend %                                    394 non-null float64
# Beta                                                 488 non-null float64
# Change in Debt/Total Capital Quarter over Quarter    473 non-null float64
# Days to Cover                                        495 non-null float64
# Dividend Change %                                    405 non-null float64
# Dividend Growth 5yr                                  354 non-null float64
# Dividend Growth Rate, 3 Years                        392 non-null float64
# EPS (TTM, GAAP)                                      490 non-null float64
# EPS Growth (MRQ)                                     487 non-null float64
# EPS Growth (TTM)                                     489 non-null float64
# EPS Growth 5yr                                       438 non-null float64
# FCF Growth 5yr                                       485 non-null float64
# Float                                                495 non-null float64
# Gross Profit Margin (TTM)                            422 non-null float64
# Growth 1yr Consensus Est                             475 non-null float64
# Growth 1yr High Est                                  475 non-null float64
# Growth 1yr Low Est                                   475 non-null float64
# Growth 2yr Consensus Est                             497 non-null float64
# Growth 2yr High Est                                  497 non-null float64
# Growth 2yr Low Est                                   497 non-null float64
# Growth 3yr Historic                                  497 non-null float64
# Growth 5yr Actual/Est                                497 non-null float64
# Growth 5yr Consensus Est                             497 non-null float64
# Growth 5yr High Est                                  497 non-null float64
# Growth 5yr Low Est                                   497 non-null float64
# Growth Analysts                                      497 non-null float64
# Historical Volatility                                501 non-null float64
# Institutions Holding Shares                          495 non-null float64
# Interest Coverage (MRQ)                              389 non-null float64
# Market Cap                                           501 non-null object
# Net Profit Margin (TTM)                              489 non-null float64
# Operating Profit Margin (TTM)                        489 non-null float64
# Price/Book (MRQ)                                     455 non-null float64
# Price/Cash Flow (TTM)                                468 non-null float64
# Price/Earnings (TTM)                                 448 non-null float64
# Price/Sales (TTM)                                    490 non-null float64
# Quick Ratio (MRQ)                                    323 non-null float64
# Return On Assets (TTM)                               479 non-null float64
# Return On Equity (TTM)                               453 non-null float64
# Return On Investment (TTM)                           437 non-null float64
# Revenue Growth (MRQ)                                 487 non-null float64
# Revenue Growth (TTM)                                 489 non-null float64
# Revenue Growth 5yr                                   490 non-null float64
# Revenue Per Employee (TTM)                           459 non-null float64
# Shares Outstanding                                   495 non-null float64
# Short Int Current Month                              495 non-null float64
# Short Int Pct of Float                               495 non-null float64
# Short Int Prev Month                                 495 non-null float64
# Short Interest                                       495 non-null float64
# Total Debt/Total Capital (MRQ)                       460 non-null float64
# Volume 10-day Avg                                    500 non-null float64
# dtypes: float64(52), object(1)
# memory usage: 231.4+ KB

# %%
# Let's encode any infs as NaNs for simplicity
X = X.replace([np.inf, -np.inf], np.NaN)

# %%
# Import some regressors
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import SimpleImputer, KNNImputer, IterativeImputer
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import make_pipeline

# %%
def get_scores_for_imputer(imputer, X_missing, y_missing, regressor, scoring, scale=True):
    if scale:
        steps = [('scaler', StandardScaler()), 
                 ('imputer', imputer), 
                 ('regressor', regressor)]
    else:
        steps = [('imputer', imputer), 
                 ('regressor', regressor)]
        
    estimator = Pipeline(steps=steps)
    impute_scores = cross_val_score(estimator, X_missing, y_missing,
                                    scoring=scoring,
                                    cv=N_SPLITS)
    return impute_scores

def get_impute_zero_score(X_missing, y_missing, regressor, scoring):

    imputer = SimpleImputer(missing_values=np.nan, add_indicator=True,
                            strategy='constant', fill_value=0)
    zero_impute_scores = get_scores_for_imputer(imputer, X_missing, y_missing, regressor, scoring)
    return zero_impute_scores.mean(), zero_impute_scores.std()

def get_impute_knn_score(X_missing, y_missing, regressor, scoring):
    imputer = KNNImputer(missing_values=np.nan, add_indicator=True, weights='distance')
    knn_impute_scores = get_scores_for_imputer(imputer, X_missing, y_missing, regressor, scoring)
    return knn_impute_scores.mean(), knn_impute_scores.std()

def get_impute_mean(X_missing, y_missing, regressor, scoring):
    imputer = SimpleImputer(missing_values=np.nan, strategy="mean",
                            add_indicator=True)
    mean_impute_scores = get_scores_for_imputer(imputer, X_missing, y_missing, regressor, scoring)
    return mean_impute_scores.mean(), mean_impute_scores.std()

def get_impute_iterative(X_missing, y_missing, regressor, scoring, estimator=None):
    if estimator is None:
        n_nearest_features = 5
        sample_posterior = True
    elif estimator == BayesianRidge():
        n_nearest_features= None
        sample_posterior = True
    else:
        n_nearest_features= None
        sample_posterior = False
    imputer = IterativeImputer(estimator=estimator,
                               missing_values=np.nan, 
                               add_indicator=True,
                               random_state=0, 
                               n_nearest_features=n_nearest_features,
                               sample_posterior=sample_posterior
                              )
    iterative_impute_scores = get_scores_for_imputer(imputer,
                                                     X_missing,
                                                     y_missing,
                                                     regressor,
                                                     scoring
                                                    )
    return iterative_impute_scores.mean(), iterative_impute_scores.std()

# %%
scaler = StandardScaler()
y = log_close.iloc[0].T.loc[X.index]
X_train, X_test, y_train, y_test = train_test_split(X, y)
scaled_X_train = scaler.fit_transform(X_train)
scaled_X_test = scaler.transform(X_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-103-6009634d3721> in <module>
#       2 y = log_close.iloc[0].T.loc[X.index]
#       3 X_train, X_test, y_train, y_test = train_test_split(X, y)
# ----> 4 scaled_X_train = scaler.fit_transform(X_train)
#       5 scaled_X_test = scaler.transform(X_test)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     688         if y is None:
#     689             # fit method of arity 1 (unsupervised transformation)
# --> 690             return self.fit(X, **fit_params).transform(X)
#     691         else:
#     692             # fit method of arity 2 (supervised transformation)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y)
#     665         # Reset internal state before fitting
#     666         self._reset()
# --> 667         return self.partial_fit(X, y)
#     668
#     669     def partial_fit(self, X, y=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in partial_fit(self, X, y)
#     696         X = self._validate_data(X, accept_sparse=('csr', 'csc'),
#     697                                 estimator=self, dtype=FLOAT_DTYPES,
# --> 698                                 force_all_finite='allow-nan')
#     699
#     700         # Even in the case of `with_mean=False`, we update the mean anyway
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     418                     f"requires y to be passed, but the target y is None."
#     419                 )
# --> 420             X = check_array(X, **check_params)
#     421             out = X
#     422         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     596                     array = array.astype(dtype, casting="unsafe", copy=False)
#     597                 else:
# --> 598                     array = np.asarray(array, order=order, dtype=dtype)
#     599             except ComplexWarning:
#     600                 raise ValueError("Complex data not supported\n"
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# ValueError: could not convert string to float: '3.7B'

# %%
# The market cap column is causing trouble because it is in string format. Let's look at it.
X['Market Cap'].head()
# Out:
# A        24.7B
# AAL       4.3B
# AAP       8.6B
# AAPL      1.3T
# ABBV    124.0B
# Name: Market Cap, dtype: object

# %%
# We can see that the last character is a letter representing a multiple
X['Market Cap'].map(lambda x: x[-1]).unique()
# Out:
# array(['B', 'T', 'M'], dtype=object)

# %%
# We can then make a function to turn this into a numerical feature
def fix_market_cap(x):
    if x[-1] == 'M':
        x = x.strip('M')
        x = float(x) * 1e6
    elif x[-1] == 'B':
        x = x.strip('B')
        x = float(x) * 1e9
    elif x[-1] == 'T':
        x = x.strip('T')
        x = float(x) * 1e12
    else:
        raise ValueError('Invalid input')
        
    return x

# %%
X['marketCap'] = X['Market Cap'].map(fix_market_cap)
X['marketCap'].head()
# Out:
# A       2.470000e+10
# AAL     4.300000e+09
# AAP     8.600000e+09
# AAPL    1.300000e+12
# ABBV    1.240000e+11
# Name: marketCap, dtype: float64

# %%
# There, that's fixed, now to drop original column
X.drop(columns=['Market Cap'], inplace=True)

# %%
[colname for colname in X.index if colname not in log_close.columns]
# Out:
# ['AGN', 'ETFC']

# %%
X_new = X.drop(index=['AGN', 'ETFC'])

# %%
# Now we need to deal with the Price ratios, which need to have the prices factored back out
# to avoid having information about the price in the training features
to_fix = ['Price/Book (MRQ)',
          'Price/Cash Flow (TTM)',
          'Price/Earnings (TTM)',
          'Price/Sales (TTM)'
         ]

# %%
for col in to_fix:
    X_new[col.replace('Price/','')] = sp500_close.iloc[0].T.loc[X2.index] / X2[col]

X_new = X_new.drop(columns=to_fix)
X_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 499 entries, A to ZTS
# Data columns (total 53 columns):
# % Held by Institutions                               493 non-null float64
# 5yr Avg Return                                       499 non-null float64
# Annual Dividend %                                    392 non-null float64
# Beta                                                 486 non-null float64
# Change in Debt/Total Capital Quarter over Quarter    471 non-null float64
# Days to Cover                                        493 non-null float64
# Dividend Change %                                    403 non-null float64
# Dividend Growth 5yr                                  354 non-null float64
# Dividend Growth Rate, 3 Years                        392 non-null float64
# EPS (TTM, GAAP)                                      488 non-null float64
# EPS Growth (MRQ)                                     485 non-null float64
# EPS Growth (TTM)                                     487 non-null float64
# EPS Growth 5yr                                       437 non-null float64
# FCF Growth 5yr                                       483 non-null float64
# Float                                                493 non-null float64
# Gross Profit Margin (TTM)                            420 non-null float64
# Growth 1yr Consensus Est                             473 non-null float64
# Growth 1yr High Est                                  473 non-null float64
# Growth 1yr Low Est                                   473 non-null float64
# Growth 2yr Consensus Est                             494 non-null float64
# Growth 2yr High Est                                  495 non-null float64
# Growth 2yr Low Est                                   494 non-null float64
# Growth 3yr Historic                                  495 non-null float64
# Growth 5yr Actual/Est                                495 non-null float64
# Growth 5yr Consensus Est                             494 non-null float64
# Growth 5yr High Est                                  495 non-null float64
# Growth 5yr Low Est                                   494 non-null float64
# Growth Analysts                                      495 non-null float64
# Historical Volatility                                499 non-null float64
# Institutions Holding Shares                          493 non-null float64
# Interest Coverage (MRQ)                              388 non-null float64
# Net Profit Margin (TTM)                              487 non-null float64
# Operating Profit Margin (TTM)                        487 non-null float64
# Quick Ratio (MRQ)                                    322 non-null float64
# Return On Assets (TTM)                               477 non-null float64
# Return On Equity (TTM)                               451 non-null float64
# Return On Investment (TTM)                           435 non-null float64
# Revenue Growth (MRQ)                                 485 non-null float64
# Revenue Growth (TTM)                                 487 non-null float64
# Revenue Growth 5yr                                   488 non-null float64
# Revenue Per Employee (TTM)                           457 non-null float64
# Shares Outstanding                                   493 non-null float64
# Short Int Current Month                              493 non-null float64
# Short Int Pct of Float                               493 non-null float64
# Short Int Prev Month                                 493 non-null float64
# Short Interest                                       493 non-null float64
# Total Debt/Total Capital (MRQ)                       458 non-null float64
# Volume 10-day Avg                                    498 non-null float64
# marketCap                                            499 non-null float64
# Book (MRQ)                                           453 non-null float64
# Cash Flow (TTM)                                      466 non-null float64
# Earnings (TTM)                                       447 non-null float64
# Sales (TTM)                                          488 non-null float64
# dtypes: float64(53)
# memory usage: 210.5+ KB

# %%
scaler = StandardScaler()
y = log_close.iloc[0].T.loc[X_new.index]
X_train, X_test, y_train, y_test = train_test_split(X_new, y)
scaled_X_train = scaler.fit_transform(X_train)
scaled_X_test = scaler.transform(X_test)

# %%
regressor = LinearRegression()

# %%
import sklearn
sklearn.metrics.SCORERS.keys()
# Out:
# dict_keys(['explained_variance', 'r2', 'max_error', 'neg_median_absolute_error', 'neg_mean_absolute_error', 'neg_mean_squared_error', 'neg_mean_squared_log_error', 'neg_root_mean_squared_error', 'neg_mean_poisson_deviance', 'neg_mean_gamma_deviance', 'accuracy', 'roc_auc', 'roc_auc_ovr', 'roc_auc_ovo', 'roc_auc_ovr_weighted', 'roc_auc_ovo_weighted', 'balanced_accuracy', 'average_precision', 'neg_log_loss', 'neg_brier_score', 'adjusted_rand_score', 'homogeneity_score', 'completeness_score', 'v_measure_score', 'mutual_info_score', 'adjusted_mutual_info_score', 'normalized_mutual_info_score', 'fowlkes_mallows_score', 'precision', 'precision_macro', 'precision_micro', 'precision_samples', 'precision_weighted', 'recall', 'recall_macro', 'recall_micro', 'recall_samples', 'recall_weighted', 'f1', 'f1_macro', 'f1_micro', 'f1_samples', 'f1_weighted', 'jaccard', 'jaccard_macro', 'jaccard_micro', 'jaccard_samples', 'jaccard_weighted'])

# %%
N_SPLITS = 5
scoring = 'r2'

zero_scores = get_impute_zero_score(X_new, y, regressor, scoring)
mean_scores = get_impute_mean(X_new, y, regressor, scoring)
knn_scores = get_impute_knn_score(X_new, y, regressor, scoring)
iter_scores = get_impute_iterative(X_new, y, regressor, scoring)

# %%
X_new_scaled = StandardScaler().fit_transform(X_new)
N_SPLITS = 5
scoring = 'r2'

zero_scores = get_impute_zero_score(X_new_scaled, y, regressor, scoring)
mean_scores = get_impute_mean(X_new_scaled, y, regressor, scoring)
knn_scores = get_impute_knn_score(X_new_scaled, y, regressor, scoring)
iter_scores = get_impute_iterative(X_new_scaled, y, regressor, scoring)

# %%
scores = [zero_scores[0], mean_scores[0], knn_scores[0], iter_scores[0]]
stds = [zero_scores[1], mean_scores[1], knn_scores[1], iter_scores[1]]

# %%
n_bars = len(scores)
xval = np.arange(n_bars)

x_labels = ['Zero imputation',
            'Mean Imputation',
            'KNN Imputation',
            'Iterative Imputation']
colors = ['r', 'g', 'b', 'orange', 'black']

# plot diabetes results
plt.figure(figsize=(12, 6))
ax1 = plt.subplot(111)
for j in xval:
    ax1.barh(j, scores[j], xerr=stds[j],
             color=colors[j], alpha=0.6, align='center')

ax1.set_title('Imputation Techniques Comparison with Linear Regressor')
ax1.set_xlim(left=np.min(scores*2) * 0.9,
             right=np.max(scores*2) * 1.1)
ax1.set_yticks(xval)
ax1.set_xlabel('R Squared')
ax1.invert_yaxis()
ax1.set_yticklabels(x_labels)

plt.show()

# %%
# We can see that old fashioned linear regression has performed dismally here, let's try another
# type of regressor
regressor = RandomForestRegressor()

# %%
N_SPLITS = 5
scoring = 'r2'

zero_scores = get_impute_zero_score(X_new, y, regressor, scoring)
mean_scores = get_impute_mean(X_new, y, regressor, scoring)
knn_scores = get_impute_knn_score(X_new, y, regressor, scoring)
iter_scores = get_impute_iterative(X_new, y, regressor, scoring)

# %%
scores = [zero_scores[0], mean_scores[0], knn_scores[0], iter_scores[0]]
stds = [zero_scores[1], mean_scores[1], knn_scores[1], iter_scores[1]]

# %%
n_bars = len(scores)
xval = np.arange(n_bars)

x_labels = ['Zero imputation',
            'Mean Imputation',
            'KNN Imputation',
            'Iterative Imputation']
colors = ['r', 'g', 'b', 'orange', 'black']

# plot diabetes results
plt.figure(figsize=(12, 6))
ax1 = plt.subplot(111)
for j in xval:
    ax1.barh(j, scores[j], xerr=stds[j],
             color=colors[j], alpha=0.6, align='center')

ax1.set_title('Imputation Techniques Comparison with RandomForest Regressor')
ax1.set_xlim(left=np.min(scores*2) * 0.9,
             right=np.max(scores*2) * 1.1)
ax1.set_yticks(xval)
ax1.set_xlabel('R Squared')
ax1.invert_yaxis()
ax1.set_yticklabels(x_labels)

plt.show()

# %%
# We can see that the RandomForestRegressor has performed much better than the LinearRegression,
# with r2 scores btw .78 and .80, which is pretty good for not having any parameter tuning done
# Running the above using both 'uniform' and 'distance' weights in the KNNImputer revealed that
# the 'distance' weigting method had better results

# %%
# Let's try this one more time with another regressor
from sklearn.ensemble import GradientBoostingRegressor
regressor = GradientBoostingRegressor()

# %%
N_SPLITS = 5
scoring = 'r2'

zero_scores = get_impute_zero_score(X_new, y, regressor, scoring)
mean_scores = get_impute_mean(X_new, y, regressor, scoring)
knn_scores = get_impute_knn_score(X_new, y, regressor, scoring)
iter_scores = get_impute_iterative(X_new, y, regressor, scoring)

# %%
scores = [zero_scores[0], mean_scores[0], knn_scores[0], iter_scores[0]]
stds = [zero_scores[1], mean_scores[1], knn_scores[1], iter_scores[1]]

# %%
n_bars = len(scores)
xval = np.arange(n_bars)

x_labels = ['Zero imputation',
            'Mean Imputation',
            'KNN Imputation',
            'Iterative Imputation']
colors = ['r', 'g', 'b', 'orange', 'black']

# plot diabetes results
plt.figure(figsize=(12, 6))
ax1 = plt.subplot(111)
for j in xval:
    ax1.barh(j, scores[j], xerr=stds[j],
             color=colors[j], alpha=0.6, align='center')

ax1.set_title('Imputation Techniques Comparison')
ax1.set_xlim(left=np.min(scores*2) * 0.9,
             right=np.max(scores*2) * 1.1)
ax1.set_yticks(xval)
ax1.set_xlabel('R Squared')
ax1.invert_yaxis()
ax1.set_yticklabels(x_labels)

plt.show()

# %%
# These scores are fairly impressive for having started with a dataset full of missing values,
# some of them are appropaching .90. Surprisingly, Zero Imputation seems to be the winner here
# This may indicate that companies that had missing values for companies were missing them
# because they do not make earnings/profit

# %%
# There are some options for IterativeImputer that have not been explored yet. Let's take a look
from sklearn.linear_model import BayesianRidge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
estimators = [
    BayesianRidge(),
    DecisionTreeRegressor(max_features='auto', random_state=0),
    RandomForestRegressor(random_state=0),
    ExtraTreesRegressor(n_estimators=10, random_state=0),
    KNeighborsRegressor(n_neighbors=15)
]

# %%
results = []

for estimator in estimators:
    results.append(get_impute_iterative(X_new,
                                       y,
                                       regressor,
                                       scoring,
                                       estimator
                                      )
                 )

print(results)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# [(0.8868224331465804, 0.03133865018785526), (0.8872289734241479, 0.04039785077133326), (0.8843981463953092, 0.03550400126203757), (0.882308488853252, 0.03434727872167207), (0.8794276546910782, 0.043175112333565316)]

# %%
# A note that adding the RandomForest has made this problem take a long time, if they aren't
# much better performing, then it is safe to say they are not worth the extra fitting time

# %%
scores = [results[i][0] for i in range(len(results))]
stds = [results[i][1] for i in range(len(results))]

# %%
n_bars = len(scores)
xval = np.arange(n_bars)

x_labels = ['BayesianRidge', 
            'DecisionTree',
            'RandomForest',
            'ExtraTrees', 
            'KNeighbors']
colors = ['r', 'g', 'b', 'orange', 'black']

# plot diabetes results
plt.figure(figsize=(12, 6))
ax1 = plt.subplot(111)
for j in xval:
    ax1.barh(j, scores[j], xerr=stds[j],
             color=colors[j], alpha=0.6, align='center')

ax1.set_title('Iterative Imputation Techniques Comparison')
ax1.set_xlim(left=np.min(scores*2) * 0.9,
             right=np.max(scores*2) * 1.1)
ax1.set_yticks(xval)
ax1.set_xlabel('R Squared')
ax1.invert_yaxis()
ax1.set_yticklabels(x_labels)

plt.show()

# %%
# A note that adding the RandomForest has made this problem take a long time, if they aren't
# much better performing, then it is safe to say they are not worth the extra fitting time
# The results show that RandomForest is not appreciably better than the others, so it should
# not be used in this context, as it took forever. Let's try tuning other params

# %%
estimators = [
    BayesianRidge(),
    DecisionTreeRegressor(max_features='sqrt', random_state=0),
    ExtraTreesRegressor(n_estimators=10, max_features='sqrt', random_state=0),
    KNeighborsRegressor(n_neighbors=5)
]

# %%
results = []

for estimator in estimators:
    results.append(get_impute_iterative(X_new,
                                       y,
                                       regressor,
                                       scoring,
                                       estimator
                                      )
                 )

print(results)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# [(0.8878541350047413, 0.03744741027111327), (0.8699328276695564, 0.04875677988447163), (0.8727525370057532, 0.050528269509559985), (0.8748959130603138, 0.0417579469557101)]

# %%
scores = [results[i][0] for i in range(len(results))]
stds = [results[i][1] for i in range(len(results))]

# %%
n_bars = len(scores)
xval = np.arange(n_bars)

x_labels = ['BayesianRidge', 
            'DecisionTree',
            'ExtraTrees', 
            'KNeighbors']
colors = ['r', 'g', 'b', 'orange', 'black']

# plot diabetes results
plt.figure(figsize=(12, 6))
ax1 = plt.subplot(111)
for j in xval:
    ax1.barh(j, scores[j], xerr=stds[j],
             color=colors[j], alpha=0.6, align='center')

ax1.set_title('Iterative Imputation Techniques Comparison')
ax1.set_xlim(left=np.min(scores*2) * 0.9,
             right=np.max(scores*2) * 1.1)
ax1.set_yticks(xval)
ax1.set_xlabel('R Squared')
ax1.invert_yaxis()
ax1.set_yticklabels(x_labels)

plt.show()

# %%
# We can see the best results so far are coming from the IterativeImputer using 
# the BayesianRidge estimator, with an r2 between .875 and .9
# Let's change some hyperparameters and see how things differ

# %%
estimators = [
    BayesianRidge(),
    DecisionTreeRegressor(max_features='sqrt', random_state=123),
    ExtraTreesRegressor(n_estimators=10, max_features='sqrt', random_state=123),
    KNeighborsRegressor(n_neighbors=30)
]

# %%
results = []

for estimator in estimators:
    results.append(get_impute_iterative(X_new,
                                       y,
                                       regressor,
                                       scoring,
                                       estimator
                                      )
                 )

print(results)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# [(0.8881849774835489, 0.03782769687860059), (0.869591037334615, 0.04870331489613106), (0.8719300153371554, 0.051331319526268786), (0.8676473248998342, 0.04501638160061904)]

# %%
scores = [results[i][0] for i in range(len(results))]
stds = [results[i][1] for i in range(len(results))]

# %%
n_bars = len(scores)
xval = np.arange(n_bars)

x_labels = ['BayesianRidge', 
            'DecisionTree',
            'ExtraTrees', 
            'KNeighbors']
colors = ['r', 'g', 'b', 'orange', 'black']

# plot diabetes results
plt.figure(figsize=(12, 6))
ax1 = plt.subplot(111)
for j in xval:
    ax1.barh(j, scores[j], xerr=stds[j],
             color=colors[j], alpha=0.6, align='center')

ax1.set_title('Iterative Imputation Techniques Comparison')
ax1.set_xlim(left=np.min(scores*2) * 0.9,
             right=np.max(scores*2) * 1.1)
ax1.set_yticks(xval)
ax1.set_xlabel('R Squared')
ax1.invert_yaxis()
ax1.set_yticklabels(x_labels)

plt.show()

# %%
# These results are basically the same as before. A bit of lost performance in KNeighbors by
# increasing the number of neighbors in the KNeighbors estimator.

# %%
# The best results so far have been attained with a BayesianRidge estimator in IterativeImputer,
# and using a Gradient Boosted Tree

# %% [markdown]
# ## Modeling the data
# Now that we have evaluated methods of imputing missing data, it is time to model the prices using our features.

# %%
# Let's do some grid searching to tune the hyperparameters of the model
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.pipeline import Pipeline

# %%
imputer_estimator = BayesianRidge()
#n_nearest_features = None
sample_posterior = True

scaler = StandardScaler()

imputer = IterativeImputer(estimator=imputer_estimator,
                           missing_values=np.nan, 
                           add_indicator=True,
                           random_state=123,
                           sample_posterior=sample_posterior
                          )

regressor = GradientBoostingRegressor(loss='huber', random_state=0)

steps = [('scaler', scaler),
         ('imputer', imputer),
         ('regressor', regressor)
        ]
estimator = Pipeline(steps=steps)

param_grid = {'imputer__n_nearest_features': [5, 10, 20, None],
              #'regressor__loss': ['ls', 'lad', 'huber'],
              'regressor__learning_rate': [.001, .01, .1, .5],
              'regressor__n_estimators': [100, 200, 300, 500],
              'regressor__subsample': [0.5, 0.7, 1.0],
              'regressor__max_depth': [2, 3, 5, 7]
             }

grid_search = GridSearchCV(estimator, param_grid=param_grid, scoring='r2', cv=5)
grid_fit = grid_search.fit(X_new, y)

# %%
grid_fit.best_params_
# Out:
# {'imputer__n_nearest_features': 20,
#  'regressor__learning_rate': 0.1,
#  'regressor__max_depth': 2,
#  'regressor__n_estimators': 500,
#  'regressor__subsample': 0.7}

# %%
grid_fit.best_score_
# Out:
# 0.9076299097923837

# %%
# This looks good, after a long time we have our optimal parameters and a good r2 of .90
# The whole idea in generating this model was to use the residuals from it to see if they have
# a relationship with the actual returns, hopefully a nice linear relationship, let's generate
# residuals and have a look
preds = grid_fit.best_estimator_.predict(X_new)
resids = y - preds
sns.distplot(resids)

# %%
# We can see a nice tight, symmetrical distribution of residuals

# %%
# Let's look again at our log returns over the period of study
sns.distplot(log_returns.log_return)

# %%
# Let's plot them together and see if there is a visual relationship
plt.scatter(resids, log_returns.log_return)

# %%
# We would have been hoping to see a negative linear relationship here, since higher residual
# values would correspond possibly to overvalued securities, as their current trading price
# would have been higher than what the model figured. The range of the residuals is very narrow,
# so right now I'm not seeing the kind of relation I was hoping for. Let's run a linreg anyways
# and see what we get
test_df = pd.DataFrame(zip(resids, log_returns.log_return))
test_df.columns = ['resids', 'log_returns']
test_df.head()
# Out:
#      resids  log_returns
# 0 -0.007954     0.250673
# 1 -0.035211     0.095848
# 2  0.027050     0.161577
# 3 -0.035499     0.398815
# 4 -0.054987    -0.014316

# %%
mf.do_a_linreg(test_df, ['resids'], 'log_returns')
# Out:
# Linear Regression for log_returns~resids
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log_returns   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.2208
# Date:                Tue, 03 Nov 2020   Prob (F-statistic):              0.639
# Time:                        18:12:40   Log-Likelihood:                 57.078
# No. Observations:                 499   AIC:                            -110.2
# Df Residuals:                     497   BIC:                            -101.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.1066      0.010     11.005      0.000       0.088       0.126
# resids        -0.0310      0.066     -0.470      0.639      -0.161       0.099
# ==============================================================================
# Omnibus:                       29.738   Durbin-Watson:                   1.929
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               88.568
# Skew:                          -0.178   Prob(JB):                     5.86e-20
# Kurtosis:                       5.033   Cond. No.                         6.81
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
# Test for homoscedasticity of residuals:
#                 F_statistic    p_value
# Goldfeld-Quandt    0.768781  0.0501257
# Normality Test Results for ['residuals']:
# -------------------------------------------------------------------------------------------
# <table style="display:inline" cellpadding=100><td>K-S and Shapiro-Wilk:<br/><table style="display:inline" cellpadding=100 border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>K-S</th>
#       <th>Shapiro-Wilk</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">residuals</th>
#       <th>Statistic</th>
#       <td>3.347984e-01</td>
#       <td>9.752842e-01</td>
#     </tr>
#     <tr>
#       <th>p-value</th>
#       <td>2.251110e-50</td>
#       <td>1.824088e-07</td>
#     </tr>
#   </tbody>
# </table style="display:inline" cellpadding=100></td><td>Anderson-Darling:<br/><table style="display:inline" cellpadding=100 border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>statistic</th>
#       <th>critical</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>residuals</th>
#       <td>2.370295</td>
#       <td>0.781</td>
#     </tr>
#   </tbody>
# </table style="display:inline" cellpadding=100></td><td>Jarque-Bera:<br/><table style="display:inline" cellpadding=100 border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>residuals</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Statistic</th>
#       <td>8.856762e+01</td>
#     </tr>
#     <tr>
#       <th>p-value</th>
#       <td>5.858478e-20</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-1.784606e-01</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>5.032824e+00</td>
#     </tr>
#   </tbody>
# </table style="display:inline" cellpadding=100></td></table style="display:inline" cellpadding=100></body>
# Skew: -0.17846056337574667
# Kurtosis: 2.0328238491570216

# %% [markdown]
# The results of this investigation have been interesting. The hypothesis was that if a model could be developed to regress the current trading price of a security with accuracy, then deviations of individual prices from model predictions expressed in the residuals may indicate current overvaluing or undervaluing in the market which could then be used as signals for future price movement. While a great model for regressing trading price was developed using Decision Tree Imputation and a Gradient Boosting Classifier, the relationship between the model residuals and price movements over the time period studied was not found. Future work may determine a more tangible use for modeling current trading price with fundamental data, or perhaps a different/longer time period of consideration may show a relationship between returns and residuals from such a model, but in this instance the research is inconclusive, and it will be necessary to find other ways to utilize the database for business purposes.

# %%
# A quick check to make sure our indexes were consistent
print("Number of discrepancies between indexes")
sum(X_new.index == log_returns.index) - len(X_new)
# Out:
# Number of discrepancies between indexes
# 0

# %%
# Thankfully, no error was made with inconsistent indexes. The hypothesis has failed to be
# proven, though a nice model was achieved for regressing price. I'd like to try another way

# %% [markdown]
# I have just realized a major issue with the predictors. Both Market Cap and Float are in the features, which together relate to the price of a security. Float is the number of shares available for trading, and Market Cap is the total number of shares multiplied by the price of a stock. This may have contributed to the high r-squared we were getting, as the regressor may have found this relationship. We need to try the whole thing again without having Market Cap present in the data.

# %%
# For fun, let's divide the market cap by price, and plot with Float
float_calc = X_new.marketCap / sp500_close.iloc[0].T.loc[X_new.index]
plt.scatter(X_new.Float, float_calc)

# %%
# We can see that this relationship is not perfect but is highly linear along the 1 line
# We need to now drop Market Cap, and repeat the process of creating a model (bummer)
X_new = X_new.drop('marketCap', axis=1)
X_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 499 entries, A to ZTS
# Data columns (total 52 columns):
# % Held by Institutions                               493 non-null float64
# 5yr Avg Return                                       499 non-null float64
# Annual Dividend %                                    392 non-null float64
# Beta                                                 486 non-null float64
# Change in Debt/Total Capital Quarter over Quarter    471 non-null float64
# Days to Cover                                        493 non-null float64
# Dividend Change %                                    403 non-null float64
# Dividend Growth 5yr                                  354 non-null float64
# Dividend Growth Rate, 3 Years                        392 non-null float64
# EPS (TTM, GAAP)                                      488 non-null float64
# EPS Growth (MRQ)                                     485 non-null float64
# EPS Growth (TTM)                                     487 non-null float64
# EPS Growth 5yr                                       437 non-null float64
# FCF Growth 5yr                                       483 non-null float64
# Float                                                493 non-null float64
# Gross Profit Margin (TTM)                            420 non-null float64
# Growth 1yr Consensus Est                             473 non-null float64
# Growth 1yr High Est                                  473 non-null float64
# Growth 1yr Low Est                                   473 non-null float64
# Growth 2yr Consensus Est                             494 non-null float64
# Growth 2yr High Est                                  495 non-null float64
# Growth 2yr Low Est                                   494 non-null float64
# Growth 3yr Historic                                  495 non-null float64
# Growth 5yr Actual/Est                                495 non-null float64
# Growth 5yr Consensus Est                             494 non-null float64
# Growth 5yr High Est                                  495 non-null float64
# Growth 5yr Low Est                                   494 non-null float64
# Growth Analysts                                      495 non-null float64
# Historical Volatility                                499 non-null float64
# Institutions Holding Shares                          493 non-null float64
# Interest Coverage (MRQ)                              388 non-null float64
# Net Profit Margin (TTM)                              487 non-null float64
# Operating Profit Margin (TTM)                        487 non-null float64
# Quick Ratio (MRQ)                                    322 non-null float64
# Return On Assets (TTM)                               477 non-null float64
# Return On Equity (TTM)                               451 non-null float64
# Return On Investment (TTM)                           435 non-null float64
# Revenue Growth (MRQ)                                 485 non-null float64
# Revenue Growth (TTM)                                 487 non-null float64
# Revenue Growth 5yr                                   488 non-null float64
# Revenue Per Employee (TTM)                           457 non-null float64
# Shares Outstanding                                   493 non-null float64
# Short Int Current Month                              493 non-null float64
# Short Int Pct of Float                               493 non-null float64
# Short Int Prev Month                                 493 non-null float64
# Short Interest                                       493 non-null float64
# Total Debt/Total Capital (MRQ)                       458 non-null float64
# Volume 10-day Avg                                    498 non-null float64
# Book (MRQ)                                           453 non-null float64
# Cash Flow (TTM)                                      466 non-null float64
# Earnings (TTM)                                       447 non-null float64
# Sales (TTM)                                          488 non-null float64
# dtypes: float64(52)
# memory usage: 226.6+ KB

# %%
estimators = [
    BayesianRidge(),
    DecisionTreeRegressor(max_features='sqrt', random_state=0),
    ExtraTreesRegressor(n_estimators=10, max_features='sqrt', random_state=0),
    KNeighborsRegressor(n_neighbors=5)
]

# %%
results = []

for estimator in estimators:
    results.append(get_impute_iterative(X_new,
                                       y,
                                       regressor,
                                       scoring,
                                       estimator
                                      )
                 )

print(results)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# [(0.8312089092017629, 0.03549240837937197), (0.8444744305147653, 0.03943827267008089), (0.8398783436695189, 0.03444951873687246), (0.8408560817231461, 0.03460472388342569)]

# %%
scores = [results[i][0] for i in range(len(results))]
stds = [results[i][1] for i in range(len(results))]

# %%
n_bars = len(scores)
xval = np.arange(n_bars)

x_labels = ['BayesianRidge', 
            'DecisionTree',
            'ExtraTrees', 
            'KNeighbors']
colors = ['r', 'g', 'b', 'orange', 'black']

# plot diabetes results
plt.figure(figsize=(12, 6))
ax1 = plt.subplot(111)
for j in xval:
    ax1.barh(j, scores[j], xerr=stds[j],
             color=colors[j], alpha=0.6, align='center')

ax1.set_title('Iterative Imputation Techniques Comparison')
ax1.set_xlim(left=np.min(scores*2) * 0.9,
             right=np.max(scores*2) * 1.1)
ax1.set_yticks(xval)
ax1.set_xlabel('R Squared')
ax1.invert_yaxis()
ax1.set_yticklabels(x_labels)

plt.show()

# %%
# We can see these scores have dropped considerably from before we cut marketCap from the
# features, which is a good thing. We were cheating before.

# %%
estimators = [
    BayesianRidge(),
    DecisionTreeRegressor(max_features='sqrt', random_state=123),
    ExtraTreesRegressor(n_estimators=10, max_features='sqrt', random_state=123),
    KNeighborsRegressor(n_neighbors=30)
]

# %%
results = []

for estimator in estimators:
    results.append(get_impute_iterative(X_new,
                                       y,
                                       regressor,
                                       scoring,
                                       estimator
                                      )
                 )

print(results)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:670: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# [(0.8312089092017629, 0.03549240837937197), (0.8444744305147653, 0.03943827267008089), (0.8398783436695189, 0.03444951873687246), (0.8432853186717658, 0.0352001732324478)]

# %%
scores = [results[i][0] for i in range(len(results))]
stds = [results[i][1] for i in range(len(results))]

# %%
n_bars = len(scores)
xval = np.arange(n_bars)

x_labels = ['BayesianRidge', 
            'DecisionTree',
            'ExtraTrees', 
            'KNeighbors']
colors = ['r', 'g', 'b', 'orange', 'black']

# plot diabetes results
plt.figure(figsize=(12, 6))
ax1 = plt.subplot(111)
for j in xval:
    ax1.barh(j, scores[j], xerr=stds[j],
             color=colors[j], alpha=0.6, align='center')

ax1.set_title('Iterative Imputation Techniques Comparison')
ax1.set_xlim(left=np.min(scores*2) * 0.9,
             right=np.max(scores*2) * 1.1)
ax1.set_yticks(xval)
ax1.set_xlabel('R Squared')
ax1.invert_yaxis()
ax1.set_yticklabels(x_labels)

plt.show()

# %%
# We can see that the DecisionTree is performing the best this time, with the KNeighbors just
# behind, but with less variance. Further tuning these may provide better performance, but first
# let's compare these scores with the other methods of imputation

# %%
N_SPLITS = 5
scoring = 'r2'

zero_scores = get_impute_zero_score(X_new, y, regressor, scoring)
mean_scores = get_impute_mean(X_new, y, regressor, scoring)
knn_scores = get_impute_knn_score(X_new, y, regressor, scoring)
iter_scores = get_impute_iterative(X_new, y, regressor, scoring)

# %%
scores = [zero_scores[0], mean_scores[0], knn_scores[0], iter_scores[0]]
stds = [zero_scores[1], mean_scores[1], knn_scores[1], iter_scores[1]]

# %%
n_bars = len(scores)
xval = np.arange(n_bars)

x_labels = ['Zero imputation',
            'Mean Imputation',
            'KNN Imputation',
            'Iterative Imputation']
colors = ['r', 'g', 'b', 'orange', 'black']

# plot diabetes results
plt.figure(figsize=(12, 6))
ax1 = plt.subplot(111)
for j in xval:
    ax1.barh(j, scores[j], xerr=stds[j],
             color=colors[j], alpha=0.6, align='center')

ax1.set_title('Imputation Techniques Comparison')
ax1.set_xlim(left=np.min(scores*2) * 0.9,
             right=np.max(scores*2) * 1.1)
ax1.set_yticks(xval)
ax1.set_xlabel('R Squared')
ax1.invert_yaxis()
ax1.set_yticklabels(x_labels)

plt.show()

# %%
# It looks as though the KNN Imputer may be the best choice this time around. Let's build a
# pipeline and train a model.

# %%
scaler = StandardScaler()

imputer = KNNImputer(weights='distance', add_indicator=True)

regressor = GradientBoostingRegressor(loss='huber', random_state=0)

steps = [('scaler', scaler),
         ('imputer', imputer),
         ('regressor', regressor)
        ]
estimator = Pipeline(steps=steps)

param_grid = {'imputer__n_neighbors': [5, 10, 20, 30],
              #'regressor__loss': ['ls', 'lad', 'huber'],
              'regressor__learning_rate': [.01, .1, .5],
              'regressor__n_estimators': [300, 500, 1000],
              'regressor__subsample': [0.7, 0.8, 1.0],
              'regressor__max_depth': [2, 3, 5]
             }

grid_search = GridSearchCV(estimator, param_grid=param_grid, scoring='r2', cv=5)
grid_fit = grid_search.fit(X_new, y)

# %%
grid_fit.best_params_
# Out:
# {'imputer__n_neighbors': 5,
#  'regressor__learning_rate': 0.1,
#  'regressor__max_depth': 2,
#  'regressor__n_estimators': 1000,
#  'regressor__subsample': 0.7}

# %%
grid_fit.best_score_
# Out:
# 0.8715783910502225

# %%
# This looks good, after a long time we have our optimal parameters and a good r2 of .90
# The whole idea in generating this model was to use the residuals from it to see if they have
# a relationship with the actual returns, hopefully a nice linear relationship, let's generate
# residuals and have a look
preds = grid_fit.best_estimator_.predict(X_new)
resids = y - preds
sns.distplot(resids)

# %%
# We can see a nice tight, symmetrical distribution of residuals

# %%
# Let's look again at our log returns over the period of study
sns.distplot(log_returns.log_return)

# %%
# Let's plot them together and see if there is a visual relationship
plt.scatter(resids, log_returns.log_return)

# %%
# We would have been hoping to see a negative linear relationship here, since higher residual
# values would correspond possibly to overvalued securities, as their current trading price
# would have been higher than what the model figured. The range of the residuals is very narrow,
# so right now I'm not seeing the kind of relation I was hoping for. Let's run a linreg anyways
# and see what we get
test_df = pd.DataFrame(zip(resids, log_returns.log_return))
test_df.columns = ['resids', 'log_returns']
test_df.head()
# Out:
#      resids  log_returns
# 0 -0.063232     0.250673
# 1 -0.020330     0.095848
# 2  0.010000     0.161577
# 3  0.001415     0.398815
# 4 -0.004952    -0.014316

# %%
mf.do_a_linreg(test_df, ['resids'], 'log_returns')
# Out:
# Linear Regression for log_returns~resids
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log_returns   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.516
# Date:                Tue, 03 Nov 2020   Prob (F-statistic):              0.219
# Time:                        20:50:54   Log-Likelihood:                 57.727
# No. Observations:                 499   AIC:                            -111.5
# Df Residuals:                     497   BIC:                            -103.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.1065      0.010     11.019      0.000       0.088       0.126
# resids        -0.2481      0.202     -1.231      0.219      -0.644       0.148
# ==============================================================================
# Omnibus:                       30.229   Durbin-Watson:                   1.939
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               90.817
# Skew:                          -0.183   Prob(JB):                     1.90e-20
# Kurtosis:                       5.058   Cond. No.                         20.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
# Test for homoscedasticity of residuals:
#                 F_statistic    p_value
# Goldfeld-Quandt    0.769046  0.0504271
# Normality Test Results for ['residuals']:
# -------------------------------------------------------------------------------------------
# <table style="display:inline" cellpadding=100><td>K-S and Shapiro-Wilk:<br/><table style="display:inline" cellpadding=100 border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>K-S</th>
#       <th>Shapiro-Wilk</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">residuals</th>
#       <th>Statistic</th>
#       <td>3.365026e-01</td>
#       <td>9.750816e-01</td>
#     </tr>
#     <tr>
#       <th>p-value</th>
#       <td>6.743933e-51</td>
#       <td>1.644556e-07</td>
#     </tr>
#   </tbody>
# </table style="display:inline" cellpadding=100></td><td>Anderson-Darling:<br/><table style="display:inline" cellpadding=100 border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>statistic</th>
#       <th>critical</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>residuals</th>
#       <td>2.32996</td>
#       <td>0.781</td>
#     </tr>
#   </tbody>
# </table style="display:inline" cellpadding=100></td><td>Jarque-Bera:<br/><table style="display:inline" cellpadding=100 border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>residuals</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Statistic</th>
#       <td>9.081662e+01</td>
#     </tr>
#     <tr>
#       <th>p-value</th>
#       <td>1.902924e-20</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-1.827116e-01</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>5.057766e+00</td>
#     </tr>
#   </tbody>
# </table style="display:inline" cellpadding=100></td></table style="display:inline" cellpadding=100></body>
# Skew: -0.18271164146159305
# Kurtosis: 2.057765646345996

# %%
# Let's see how this is affected if we remove outliers
from scipy import stats
df_trim = test_df[(np.abs(stats.zscore(test_df)) < 3).all(axis=1)]

mf.do_a_linreg(df_trim, ['resids'], 'log_returns')
# Out:
# Linear Regression for log_returns~resids
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log_returns   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.5804
# Date:                Tue, 03 Nov 2020   Prob (F-statistic):              0.447
# Time:                        21:43:57   Log-Likelihood:                 100.02
# No. Observations:                 485   AIC:                            -196.0
# Df Residuals:                     483   BIC:                            -187.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.1040      0.009     11.608      0.000       0.086       0.122
# resids        -0.2879      0.378     -0.762      0.447      -1.030       0.455
# ==============================================================================
# Omnibus:                       18.464   Durbin-Watson:                   1.933
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               21.157
# Skew:                          -0.407   Prob(JB):                     2.55e-05
# Kurtosis:                       3.620   Cond. No.                         42.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
# Test for homoscedasticity of residuals:
#                 F_statistic      p_value
# Goldfeld-Quandt     0.55134  1.39451e-05
# Normality Test Results for ['residuals']:
# -------------------------------------------------------------------------------------------
# <table style="display:inline" cellpadding=100><td>K-S and Shapiro-Wilk:<br/><table style="display:inline" cellpadding=100 border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>K-S</th>
#       <th>Shapiro-Wilk</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">residuals</th>
#       <th>Statistic</th>
#       <td>3.448875e-01</td>
#       <td>0.987026</td>
#     </tr>
#     <tr>
#       <th>p-value</th>
#       <td>4.981573e-52</td>
#       <td>0.000259</td>
#     </tr>
#   </tbody>
# </table style="display:inline" cellpadding=100></td><td>Anderson-Darling:<br/><table style="display:inline" cellpadding=100 border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>statistic</th>
#       <th>critical</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>residuals</th>
#       <td>1.416065</td>
#       <td>0.781</td>
#     </tr>
#   </tbody>
# </table style="display:inline" cellpadding=100></td><td>Jarque-Bera:<br/><table style="display:inline" cellpadding=100 border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>residuals</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Statistic</th>
#       <td>21.156964</td>
#     </tr>
#     <tr>
#       <th>p-value</th>
#       <td>0.000025</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.406834</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>3.620392</td>
#     </tr>
#   </tbody>
# </table style="display:inline" cellpadding=100></td></table style="display:inline" cellpadding=100></body>
# Skew: -0.40683429430259765
# Kurtosis: 0.6203918013462424

# %% [markdown]
# ## Trying things another way
# The richness in features of the scraped dataset is nice, but the last model we made was trained using a lot of features, some of which were not necessarily related to the fundamentals of the companies. The model performed very well with cross-validation, with an r-squared of .90, but it is possible that using a more limited feature set and sacrificing model accuracy may actually help reveal fundamental under/over pricing in the market. The goal was to find a new way to calculate intrinsic value of the securities, based on fundamental data, so using this large amount of features may have made the model great at predicting market price, but not necessarily at modeling the fundamental intrinsic value of the securities, which really is a hidden target. Markets track value very well, so using the market prices as a target to train the model is sensible, but using more than just the fundamental information about a company may be compromising the value of the information represented in the residuals, since model accuracy is measing ability to predict market price, but what we are trying to model is actually the hidden intrinsic price. To test this hypothesis, the first step will be to trim the feature set much smaller, to only fundamental information.

# %%
X_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 499 entries, A to ZTS
# Data columns (total 52 columns):
# % Held by Institutions                               493 non-null float64
# 5yr Avg Return                                       499 non-null float64
# Annual Dividend %                                    392 non-null float64
# Beta                                                 486 non-null float64
# Change in Debt/Total Capital Quarter over Quarter    471 non-null float64
# Days to Cover                                        493 non-null float64
# Dividend Change %                                    403 non-null float64
# Dividend Growth 5yr                                  354 non-null float64
# Dividend Growth Rate, 3 Years                        392 non-null float64
# EPS (TTM, GAAP)                                      488 non-null float64
# EPS Growth (MRQ)                                     485 non-null float64
# EPS Growth (TTM)                                     487 non-null float64
# EPS Growth 5yr                                       437 non-null float64
# FCF Growth 5yr                                       483 non-null float64
# Float                                                493 non-null float64
# Gross Profit Margin (TTM)                            420 non-null float64
# Growth 1yr Consensus Est                             473 non-null float64
# Growth 1yr High Est                                  473 non-null float64
# Growth 1yr Low Est                                   473 non-null float64
# Growth 2yr Consensus Est                             494 non-null float64
# Growth 2yr High Est                                  495 non-null float64
# Growth 2yr Low Est                                   494 non-null float64
# Growth 3yr Historic                                  495 non-null float64
# Growth 5yr Actual/Est                                495 non-null float64
# Growth 5yr Consensus Est                             494 non-null float64
# Growth 5yr High Est                                  495 non-null float64
# Growth 5yr Low Est                                   494 non-null float64
# Growth Analysts                                      495 non-null float64
# Historical Volatility                                499 non-null float64
# Institutions Holding Shares                          493 non-null float64
# Interest Coverage (MRQ)                              388 non-null float64
# Net Profit Margin (TTM)                              487 non-null float64
# Operating Profit Margin (TTM)                        487 non-null float64
# Quick Ratio (MRQ)                                    322 non-null float64
# Return On Assets (TTM)                               477 non-null float64
# Return On Equity (TTM)                               451 non-null float64
# Return On Investment (TTM)                           435 non-null float64
# Revenue Growth (MRQ)                                 485 non-null float64
# Revenue Growth (TTM)                                 487 non-null float64
# Revenue Growth 5yr                                   488 non-null float64
# Revenue Per Employee (TTM)                           457 non-null float64
# Shares Outstanding                                   493 non-null float64
# Short Int Current Month                              493 non-null float64
# Short Int Pct of Float                               493 non-null float64
# Short Int Prev Month                                 493 non-null float64
# Short Interest                                       493 non-null float64
# Total Debt/Total Capital (MRQ)                       458 non-null float64
# Volume 10-day Avg                                    498 non-null float64
# Book (MRQ)                                           453 non-null float64
# Cash Flow (TTM)                                      466 non-null float64
# Earnings (TTM)                                       447 non-null float64
# Sales (TTM)                                          488 non-null float64
# dtypes: float64(52)
# memory usage: 226.6+ KB

# %%
est = Pipeline(steps=[('scaler', StandardScaler()),
                ('imputer', KNNImputer(add_indicator=False, weights='distance')),
                ('regressor',
                 GradientBoostingRegressor(loss='huber', max_depth=2,
                                           n_estimators=1000, random_state=0,
                                           subsample=0.7))])

# %%
cv_scores = cross_val_score(est, X_new, y, scoring='r2', cv=5)
cv_scores.mean()
# Out:
# 0.867723137804532

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, y, random_state=42)
est.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('imputer', KNNImputer(weights='distance')),
#                 ('regressor',
#                  GradientBoostingRegressor(loss='huber', max_depth=2,
#                                            n_estimators=1000, random_state=0,
#                                            subsample=0.7))])

# %%
feature_importance = est.steps[2][1].feature_importances_

# %%
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + .5
fig = plt.figure(figsize=(8, 12))
plt.subplot(1, 1, 1)
plt.barh(pos, feature_importance[sorted_idx], align='center')
plt.yticks(pos, np.array(X_new.columns)[sorted_idx])
plt.title('Feature Importance (MDI)')
# Out:
# Text(0.5, 1.0, 'Feature Importance (MDI)')

# %%
from sklearn.inspection import permutation_importance

# %%
result = permutation_importance(est, X_test, y_test, n_repeats=10,
                                random_state=42, n_jobs=2)
sorted_idx = result.importances_mean.argsort()
fig = plt.figure(figsize=(8,12))
plt.subplot(1, 1, 1)
plt.boxplot(result.importances[sorted_idx].T,
            vert=False, labels=np.array(X_new.columns)[sorted_idx])
plt.title("Permutation Importance (test set)")
fig.tight_layout()
plt.show()

# %%
# First, I'd like to simply add some PCA for dimensionality reduction, and see what kind of an
# impact on the residuals this could have. In this case, a bit less accuracy in the model might
# be helpful in spreading out the residuals, but it doesn't mean that a correlation to returns
# will appear.
from sklearn.decomposition import PCA

# %%
scaler = StandardScaler()
imputer = KNNImputer(weights='distance')
X_scaled = scaler.fit_transform(X_new)
X_imputed = imputer.fit_transform(X_scaled)
pca = PCA(n_components=len(X_new.columns), whiten=True)
X_pca = pca.fit_transform(X_imputed)

# %%
plt.plot(range(len(X_new.columns)), pca.explained_variance_ratio_.cumsum())
plt.title('Total Variance Explained by Varying Number of Principle Components');

# %%
from sklearn.metrics import r2_score

# %%
steps = [('scaler', StandardScaler()),
         ('imputer', KNNImputer()),
         ('pca', PCA(10)),
         ('regressor', GradientBoostingRegressor())
        ]

est = Pipeline(steps=steps)
est.fit(X_train, y_train)
preds = est.predict(X_test)
print("R2 Score:", r2_score(y_test, preds))
# Out:
# R2 Score: 0.7437335675980772

# %%
preds = est.predict(X_new)
resids = y - preds
sns.distplot(resids)

# %%
plt.scatter(resids, log_returns.log_return)

# %%
# We do not see a linear relationship here
test_df = pd.DataFrame(zip(resids, log_returns.log_return), columns=['resids', 
                                                                                   'log_return'
                                                                                  ])
mf.do_a_linreg(test_df, ['resids'], 'log_return')
# Out:
# Linear Regression for log_return~resids
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             log_return   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                   0.02987
# Date:                Tue, 03 Nov 2020   Prob (F-statistic):              0.863
# Time:                        23:14:31   Log-Likelihood:                 56.982
# No. Observations:                 499   AIC:                            -110.0
# Df Residuals:                     497   BIC:                            -101.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.1065      0.010     10.997      0.000       0.087       0.126
# resids         0.0052      0.030      0.173      0.863      -0.054       0.065
# ==============================================================================
# Omnibus:                       29.443   Durbin-Watson:                   1.930
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               87.346
# Skew:                          -0.175   Prob(JB):                     1.08e-19
# Kurtosis:                       5.020   Cond. No.                         3.12
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
# Test for homoscedasticity of residuals:
#                 F_statistic    p_value
# Goldfeld-Quandt    0.768948  0.0503151
# Normality Test Results for ['residuals']:
# -------------------------------------------------------------------------------------------
# <table style="display:inline" cellpadding=100><td>K-S and Shapiro-Wilk:<br/><table style="display:inline" cellpadding=100 border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>K-S</th>
#       <th>Shapiro-Wilk</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">residuals</th>
#       <th>Statistic</th>
#       <td>3.339817e-01</td>
#       <td>9.752457e-01</td>
#     </tr>
#     <tr>
#       <th>p-value</th>
#       <td>4.001398e-50</td>
#       <td>1.788426e-07</td>
#     </tr>
#   </tbody>
# </table style="display:inline" cellpadding=100></td><td>Anderson-Darling:<br/><table style="display:inline" cellpadding=100 border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>statistic</th>
#       <th>critical</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>residuals</th>
#       <td>2.410807</td>
#       <td>0.781</td>
#     </tr>
#   </tbody>
# </table style="display:inline" cellpadding=100></td><td>Jarque-Bera:<br/><table style="display:inline" cellpadding=100 border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>residuals</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Statistic</th>
#       <td>8.734630e+01</td>
#     </tr>
#     <tr>
#       <th>p-value</th>
#       <td>1.078927e-19</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-1.750462e-01</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>5.019520e+00</td>
#     </tr>
#   </tbody>
# </table style="display:inline" cellpadding=100></td></table style="display:inline" cellpadding=100></body>
# Skew: -0.17504623361348673
# Kurtosis: 2.0195196786731735

# %%
# No linear relationsip is present between the residuals of the pricing model and the returns
# since May 8th.
# The last thing to try and do is build a model with very restricted fundamental inputs, and
# see if this has any benefit.
X_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 499 entries, A to ZTS
# Data columns (total 52 columns):
# % Held by Institutions                               493 non-null float64
# 5yr Avg Return                                       499 non-null float64
# Annual Dividend %                                    392 non-null float64
# Beta                                                 486 non-null float64
# Change in Debt/Total Capital Quarter over Quarter    471 non-null float64
# Days to Cover                                        493 non-null float64
# Dividend Change %                                    403 non-null float64
# Dividend Growth 5yr                                  354 non-null float64
# Dividend Growth Rate, 3 Years                        392 non-null float64
# EPS (TTM, GAAP)                                      488 non-null float64
# EPS Growth (MRQ)                                     485 non-null float64
# EPS Growth (TTM)                                     487 non-null float64
# EPS Growth 5yr                                       437 non-null float64
# FCF Growth 5yr                                       483 non-null float64
# Float                                                493 non-null float64
# Gross Profit Margin (TTM)                            420 non-null float64
# Growth 1yr Consensus Est                             473 non-null float64
# Growth 1yr High Est                                  473 non-null float64
# Growth 1yr Low Est                                   473 non-null float64
# Growth 2yr Consensus Est                             494 non-null float64
# Growth 2yr High Est                                  495 non-null float64
# Growth 2yr Low Est                                   494 non-null float64
# Growth 3yr Historic                                  495 non-null float64
# Growth 5yr Actual/Est                                495 non-null float64
# Growth 5yr Consensus Est                             494 non-null float64
# Growth 5yr High Est                                  495 non-null float64
# Growth 5yr Low Est                                   494 non-null float64
# Growth Analysts                                      495 non-null float64
# Historical Volatility                                499 non-null float64
# Institutions Holding Shares                          493 non-null float64
# Interest Coverage (MRQ)                              388 non-null float64
# Net Profit Margin (TTM)                              487 non-null float64
# Operating Profit Margin (TTM)                        487 non-null float64
# Quick Ratio (MRQ)                                    322 non-null float64
# Return On Assets (TTM)                               477 non-null float64
# Return On Equity (TTM)                               451 non-null float64
# Return On Investment (TTM)                           435 non-null float64
# Revenue Growth (MRQ)                                 485 non-null float64
# Revenue Growth (TTM)                                 487 non-null float64
# Revenue Growth 5yr                                   488 non-null float64
# Revenue Per Employee (TTM)                           457 non-null float64
# Shares Outstanding                                   493 non-null float64
# Short Int Current Month                              493 non-null float64
# Short Int Pct of Float                               493 non-null float64
# Short Int Prev Month                                 493 non-null float64
# Short Interest                                       493 non-null float64
# Total Debt/Total Capital (MRQ)                       458 non-null float64
# Volume 10-day Avg                                    498 non-null float64
# Book (MRQ)                                           453 non-null float64
# Cash Flow (TTM)                                      466 non-null float64
# Earnings (TTM)                                       447 non-null float64
# Sales (TTM)                                          488 non-null float64
# dtypes: float64(52)
# memory usage: 226.6+ KB

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 5yr Avg Return is very predictive, which makes sense because after 5 solid years of good
# returns, you would expect a price would be pretty high. I will leave this feature out, to
# try and focus on fundamentals.
# I will also leave out Volume and Historical Volatility, which have more to do with price than
# fundamentals.
fundamental_features = ['Cash Flow (TTM)',
                        'Earnings (TTM)',
                        'EPS (TTM, GAAP)',
                        'Gross Profit Margin (TTM)',
                        'Revenue Growth 5yr',
                        'Sales (TTM)',
                        'Book (MRQ)',
                        'EPS Growth (MRQ)',
                        'Return On Equity (TTM)',
                        'EPS Growth 5yr',
                        'Return On Assets (TTM)',
                        'Revenue Per Employee (TTM)',
                        'Return On Investment (TTM)',
                        'Beta',
                        'Revenue Growth (TTM)',
                        'Operating Profit Margin (TTM)',
                        'EPS Growth (TTM)',
                        'Revenue Growth (MRQ)',
                        'FCF Growth 5yr',
                        'Total Debt/Total Capital (MRQ)',
                        'Interest Coverage (MRQ)',
                        'Change in Debt/Total Capital Quarter over Quarter',
                        'Quick Ratio (MRQ)',
                        'Net Profit Margin (TTM)'
                       ]

X_fundies = X_new[fundamental_features].copy()

# %%
scaler = StandardScaler()

imputer = KNNImputer(weights='distance', add_indicator=False)

regressor = GradientBoostingRegressor(loss='huber', random_state=0)

steps = [('scaler', scaler),
         ('imputer', imputer),
         ('regressor', regressor)
        ]
estimator = Pipeline(steps=steps)

param_grid = {'imputer__n_neighbors': [5, 10, 20],
              #'regressor__loss': ['ls', 'lad', 'huber'],
              'regressor__learning_rate': [.01, .1, .5],
              'regressor__n_estimators': [500, 1000],
              'regressor__subsample': [0.7, 1.0],
              'regressor__max_depth': [2, 3, 5]
             }

grid_search = GridSearchCV(estimator, param_grid=param_grid, scoring='r2', cv=5)
grid_fit = grid_search.fit(X_fundies, y)

# %%
grid_fit.best_params_
# Out:
# {'imputer__n_neighbors': 5,
#  'regressor__learning_rate': 0.01,
#  'regressor__max_depth': 5,
#  'regressor__n_estimators': 1000,
#  'regressor__subsample': 0.7}

# %%
grid_fit.best_score_
# Out:
# 0.6794544449000117

# %%
# This looks good, after a long time we have our optimal parameters and a good r2 of .90
# The whole idea in generating this model was to use the residuals from it to see if they have
# a relationship with the actual returns, hopefully a nice linear relationship, let's generate
# residuals and have a look
preds = grid_fit.best_estimator_.predict(X_fundies)
resids = y - preds
sns.distplot(resids)

# %%
# We can see a nice tight, symmetrical distribution of residuals

# %%
# Let's look again at our log returns over the period of study
sns.distplot(log_returns.log_return)

# %%
# Let's plot them together and see if there is a visual relationship
plt.scatter(resids, log_returns.log_return)

# %%
# We would have been hoping to see a negative linear relationship here, since higher residual
# values would correspond possibly to overvalued securities, as their current trading price
# would have been higher than what the model figured. The range of the residuals is very narrow,
# so right now I'm not seeing the kind of relation I was hoping for. Let's run a linreg anyways
# and see what we get
test_df = pd.DataFrame(zip(resids, log_returns.log_return))
test_df.columns = ['resids', 'log_returns']
test_df.head()
# Out:
#      resids  log_returns
# 0 -0.054049     0.250673
# 1 -0.035543     0.095848
# 2  0.053406     0.161577
# 3  0.045790     0.398815
# 4 -0.164961    -0.014316

# %%
mf.do_a_linreg(test_df, ['resids'], 'log_returns')
# Out:
# Linear Regression for log_returns~resids
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log_returns   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.4599
# Date:                Wed, 04 Nov 2020   Prob (F-statistic):              0.498
# Time:                        00:08:01   Log-Likelihood:                 57.198
# No. Observations:                 499   AIC:                            -110.4
# Df Residuals:                     497   BIC:                            -102.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.1067      0.010     11.019      0.000       0.088       0.126
# resids         0.0744      0.110      0.678      0.498      -0.141       0.290
# ==============================================================================
# Omnibus:                       29.810   Durbin-Watson:                   1.927
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               90.189
# Skew:                          -0.170   Prob(JB):                     2.60e-20
# Kurtosis:                       5.055   Cond. No.                         11.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
# Test for homoscedasticity of residuals:
#                 F_statistic   p_value
# Goldfeld-Quandt    0.765916  0.046964
# Normality Test Results for ['residuals']:
# -------------------------------------------------------------------------------------------
# <table style="display:inline" cellpadding=100><td>K-S and Shapiro-Wilk:<br/><table style="display:inline" cellpadding=100 border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>K-S</th>
#       <th>Shapiro-Wilk</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">residuals</th>
#       <th>Statistic</th>
#       <td>3.347954e-01</td>
#       <td>9.746253e-01</td>
#     </tr>
#     <tr>
#       <th>p-value</th>
#       <td>2.255912e-50</td>
#       <td>1.304526e-07</td>
#     </tr>
#   </tbody>
# </table style="display:inline" cellpadding=100></td><td>Anderson-Darling:<br/><table style="display:inline" cellpadding=100 border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>statistic</th>
#       <th>critical</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>residuals</th>
#       <td>2.501837</td>
#       <td>0.781</td>
#     </tr>
#   </tbody>
# </table style="display:inline" cellpadding=100></td><td>Jarque-Bera:<br/><table style="display:inline" cellpadding=100 border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>residuals</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Statistic</th>
#       <td>9.018858e+01</td>
#     </tr>
#     <tr>
#       <th>p-value</th>
#       <td>2.604951e-20</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-1.698574e-01</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>5.054829e+00</td>
#     </tr>
#   </tbody>
# </table style="display:inline" cellpadding=100></td></table style="display:inline" cellpadding=100></body>
# Skew: -0.1698573948542619
# Kurtosis: 2.0548286906849658

# %%
# Let's see how this is affected if we remove outliers
from scipy import stats
df_trim = test_df[(np.abs(stats.zscore(test_df)) < 3).all(axis=1)]

mf.do_a_linreg(df_trim, ['resids'], 'log_returns')
# Out:
# Linear Regression for log_returns~resids
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log_returns   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     4.141
# Date:                Wed, 04 Nov 2020   Prob (F-statistic):             0.0424
# Time:                        00:08:14   Log-Likelihood:                 101.96
# No. Observations:                 485   AIC:                            -199.9
# Df Residuals:                     483   BIC:                            -191.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.1039      0.009     11.647      0.000       0.086       0.121
# resids         0.2854      0.140      2.035      0.042       0.010       0.561
# ==============================================================================
# Omnibus:                       18.995   Durbin-Watson:                   1.938
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.564
# Skew:                          -0.381   Prob(JB):                     7.64e-06
# Kurtosis:                       3.764   Cond. No.                         15.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
# Test for homoscedasticity of residuals:
#                 F_statistic      p_value
# Goldfeld-Quandt    0.574676  5.20848e-05
# Normality Test Results for ['residuals']:
# -------------------------------------------------------------------------------------------
# <table style="display:inline" cellpadding=100><td>K-S and Shapiro-Wilk:<br/><table style="display:inline" cellpadding=100 border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>K-S</th>
#       <th>Shapiro-Wilk</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">residuals</th>
#       <th>Statistic</th>
#       <td>3.425563e-01</td>
#       <td>0.985712</td>
#     </tr>
#     <tr>
#       <th>p-value</th>
#       <td>2.582822e-51</td>
#       <td>0.000107</td>
#     </tr>
#   </tbody>
# </table style="display:inline" cellpadding=100></td><td>Anderson-Darling:<br/><table style="display:inline" cellpadding=100 border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>statistic</th>
#       <th>critical</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>residuals</th>
#       <td>1.657885</td>
#       <td>0.781</td>
#     </tr>
#   </tbody>
# </table style="display:inline" cellpadding=100></td><td>Jarque-Bera:<br/><table style="display:inline" cellpadding=100 border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>residuals</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Statistic</th>
#       <td>23.564347</td>
#     </tr>
#     <tr>
#       <th>p-value</th>
#       <td>0.000008</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.381486</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>3.764164</td>
#     </tr>
#   </tbody>
# </table style="display:inline" cellpadding=100></td></table style="display:inline" cellpadding=100></body>
# Skew: -0.3814855371364886
# Kurtosis: 0.7641635565284317

# %% [markdown]
# ## Conclusions
# After trying this multiple ways, I am concluding that the residuals from models trained to regress the current trading price of stocks using fundamental data as exogenous features are not showing a significant relationship with returns since the date of the scrape. As mentioned before, the idea behind value investing is to calculate the intrinsic, hidden value of a stock, and then expect the market to move toward it. These models have done a good job modeling the current trading price using the fundamental features, but since the trading price, and not the intrinsic value, was the target variable, we cannot be sure that such models are reflective of anything other than the current trading price. Further, value investors typically expect to invest over long time horizons, often over a year, so the shorter time period observed in this study may not be long enough for the markets to adjust toward intrinsic value in the way that value investors intend, and the returns over this period may be more noise than they are purposeful movements.

# %%
import bot_functions as bf
import numpy as np
import pandas as pd

# %%
# %load_ext autoreload
# %autoreload 1
# %aimport bot_functions

# %%
# Get a list of ticker symbols
sp500_tickers = pd.read_csv('sp500.csv').set_index('Unnamed: 0')['Symbol']

# %%
# Get keys from json file. Returns dictionary to pass into start_bot()
# You can also make a dictionary with keys "user" and "pass"
my_keys = bf.get_keys("/your/TDA/login/info.json")
# or
# my_keys = {'user':'your_td_username', 'pass':'your_td_password'}

# Get API key:
keys = bf.get_keys("/your/API/key/location.json")
api_key = keys["consumer_key"]
# Set directory to save/load access token to
token_path = "/your/chosen/token/directory"
# Redirect URL of your app, do not change unless you have a remotely hosted app
redirect_url = "https://localhost"

# %%
# Establish a webdriver and start up the bot
driver = bf.start_bot(my_keys)

# %%
# The next three cells all run the same code, but they show an actual workflow day of mine
# where errors occurred because my screen went dark during the process. Remember to turn off
# your power saving settings, as well as adjust your TD Ameritrade account settings to not log
# you off while this is running.
# I left all the cells in to show how the scraper can be run in chunks without having to worry
# about duplicate files, and that if errors are encountered one can just restart the kernel and
# then pick up where they left off. 

# I highly recommend preserving your output cells so that you can look back and see what might
# need fixing, or any other details that may come in handly later when you are trying to use
# the data.

# %%
# First attempt at a big scrape. At FIS, the computer screen went black, so in the next cell,
# run the same code and it will skip all the tickers that were already done.
big_df, skipped = bf.scrape_watchlist(driver, 
                                      sp500_tickers, 
                                      'sp500_close', 
                                      root_dir='', # If none passed will use current directory
                                      skip_finished=True,
                                      errors='ignore',
                                      return_skipped=True
                                     )
# Out:
# 10 tickers scraped
# 20 tickers scraped
# 30 tickers scraped
# 40 tickers scraped
# Failed to gather earnings for ARNC on attempt 1
# Failed to gather earnings for ARNC on attempt 2
# Failed to gather earnings for ARNC on attempt 3
# Failed to gather earnings for ARNC on attempt 4
# Failed to gather earnings for ARNC on attempt 5
# Too many failed attempts for earnings of ARNC, skipping to next df.
# Historic Growth not available for ARNC
# 50 tickers scraped
# 60 tickers scraped
# Short Interest info not available for BIIB
# Failed to gather valuation for BIIB on attempt 1
# Failed to gather valuation for BIIB on attempt 2
# Failed to gather valuation for BIIB on attempt 3
# Failed to gather valuation for BIIB on attempt 4
# Failed to gather valuation for BIIB on attempt 5
# Too many failed attempts for valuation of BIIB, skipping to next df.
# 70 tickers scraped
# Short Interest info not available for BRK.B
# Failed to gather valuation for BRK.B on attempt 1
# Failed to gather valuation for BRK.B on attempt 2
# Failed to gather valuation for BRK.B on attempt 3
# Failed to gather valuation for BRK.B on attempt 4
# Failed to gather valuation for BRK.B on attempt 5
# Too many failed attempts for valuation of BRK.B, skipping to next df.
# 80 tickers scraped
# 90 tickers scraped
# 100 tickers scraped
# 110 tickers scraped
# 120 tickers scraped
# Historic Growth not available for CTVA
# Historic Growth not available for DD
# 130 tickers scraped
# Short Interest info not available for DISCK
# 140 tickers scraped
# Historic Growth not available for DOW
# 150 tickers scraped
# 160 tickers scraped
# Failed to gather valuation for EQR on attempt 1
# 170 tickers scraped
# 180 tickers scraped
# Failed to gather earnings for FIS on attempt 1
# Failed to gather earnings for FIS on attempt 2
# Failed to gather earnings for FIS on attempt 3
# Failed to gather earnings for FIS on attempt 4
# Failed to gather earnings for FIS on attempt 5
# Too many failed attempts for earnings of FIS, skipping to next df.
# Failed to gather fundamentals for FIS on attempt 1
# Failed to gather fundamentals for FIS on attempt 2
# Failed to gather fundamentals for FIS on attempt 3
# Failed to gather fundamentals for FIS on attempt 4
# Failed to gather fundamentals for FIS on attempt 5
# Too many failed attempts for fundamentals of FIS, skipping to next df.
# Failed to gather valuation for FIS on attempt 1
# Failed to gather valuation for FIS on attempt 2
# Failed to gather valuation for FIS on attempt 3
# Failed to gather valuation for FIS on attempt 4
# Failed to gather valuation for FIS on attempt 5
# Too many failed attempts for valuation of FIS, skipping to next df.
# Failed to gather analysts for FIS on attempt 1
# Failed to gather analysts for FIS on attempt 2
# Failed to gather analysts for FIS on attempt 3
# Failed to gather analysts for FIS on attempt 4
# Failed to gather analysts for FIS on attempt 5
# Too many failed attempts for analysts of FIS, skipping to next df.
# Failed to gather summary for FISV on attempt 1
# Failed to gather summary for FISV on attempt 2
# Failed to gather summary for FISV on attempt 3
# Failed to gather summary for FISV on attempt 4
# Failed to gather summary for FISV on attempt 5
# Too many failed attempts for summary of FISV, skipping to next df.
# Did not successfully scrape FISV
# Failed to gather summary for FITB on attempt 1
# Failed to gather summary for FITB on attempt 2
# Failed to gather summary for FITB on attempt 3
# Failed to gather summary for FITB on attempt 4
# Failed to gather summary for FITB on attempt 5
# Too many failed attempts for summary of FITB, skipping to next df.
# Did not successfully scrape FITB
# Failed to gather summary for FLIR on attempt 1
# Failed to gather summary for FLIR on attempt 2
# Failed to gather summary for FLIR on attempt 3
# Failed to gather summary for FLIR on attempt 4
# Failed to gather summary for FLIR on attempt 5
# Too many failed attempts for summary of FLIR, skipping to next df.
# Did not successfully scrape FLIR
# Failed to gather summary for FLS on attempt 1
# Failed to gather summary for FLS on attempt 2
# Failed to gather summary for FLS on attempt 3
# Failed to gather summary for FLS on attempt 4
# Failed to gather summary for FLS on attempt 5
# Too many failed attempts for summary of FLS, skipping to next df.
# Did not successfully scrape FLS
# Failed to gather summary for FLT on attempt 1
# Failed to gather summary for FLT on attempt 2
# Failed to gather summary for FLT on attempt 3
# Failed to gather summary for FLT on attempt 4
# Failed to gather summary for FLT on attempt 5
# Too many failed attempts for summary of FLT, skipping to next df.
# Did not successfully scrape FLT
# Failed to gather summary for FMC on attempt 1
# Failed to gather summary for FMC on attempt 2
# Failed to gather summary for FMC on attempt 3
# Failed to gather summary for FMC on attempt 4
# Failed to gather summary for FMC on attempt 5
# Too many failed attempts for summary of FMC, skipping to next df.
# Did not successfully scrape FMC
# Failed to gather summary for FOX on attempt 1
# Failed to gather summary for FOX on attempt 2
# Failed to gather summary for FOX on attempt 3
# Failed to gather summary for FOX on attempt 4
# Failed to gather summary for FOX on attempt 5
# Too many failed attempts for summary of FOX, skipping to next df.
# Did not successfully scrape FOX
# Failed to gather summary for FOXA on attempt 1
# Failed to gather summary for FOXA on attempt 2
# Failed to gather summary for FOXA on attempt 3
# Failed to gather summary for FOXA on attempt 4
# Failed to gather summary for FOXA on attempt 5
# Too many failed attempts for summary of FOXA, skipping to next df.
# Did not successfully scrape FOXA
# Failed to gather summary for FRC on attempt 1
# Failed to gather summary for FRC on attempt 2
# Failed to gather summary for FRC on attempt 3
# Failed to gather summary for FRC on attempt 4
# Failed to gather summary for FRC on attempt 5
# Too many failed attempts for summary of FRC, skipping to next df.
# Did not successfully scrape FRC
# Failed to gather summary for FRT on attempt 1
# Failed to gather summary for FRT on attempt 2
# Failed to gather summary for FRT on attempt 3
# Failed to gather summary for FRT on attempt 4
# Failed to gather summary for FRT on attempt 5
# Too many failed attempts for summary of FRT, skipping to next df.
# Did not successfully scrape FRT
# Failed to gather summary for FTI on attempt 1
# Failed to gather summary for FTI on attempt 2
# Failed to gather summary for FTI on attempt 3
# Failed to gather summary for FTI on attempt 4
# Failed to gather summary for FTI on attempt 5
# Too many failed attempts for summary of FTI, skipping to next df.
# Did not successfully scrape FTI
# Failed to gather summary for FTNT on attempt 1
# Failed to gather summary for FTNT on attempt 2
# Failed to gather summary for FTNT on attempt 3
# Failed to gather summary for FTNT on attempt 4
# Failed to gather summary for FTNT on attempt 5
# Too many failed attempts for summary of FTNT, skipping to next df.
# Did not successfully scrape FTNT
# Failed to gather summary for FTV on attempt 1
# Failed to gather summary for FTV on attempt 2
# Failed to gather summary for FTV on attempt 3
# Failed to gather summary for FTV on attempt 4
# Failed to gather summary for FTV on attempt 5
# Too many failed attempts for summary of FTV, skipping to next df.
# Did not successfully scrape FTV
# Failed to gather summary for GD on attempt 1
# Failed to gather summary for GD on attempt 2
# Failed to gather summary for GD on attempt 3
# Failed to gather summary for GD on attempt 4
# Failed to gather summary for GD on attempt 5
# Too many failed attempts for summary of GD, skipping to next df.
# Did not successfully scrape GD
# Failed to gather summary for GE on attempt 1
# Failed to gather summary for GE on attempt 2
# Failed to gather summary for GE on attempt 3
# Failed to gather summary for GE on attempt 4
# Failed to gather summary for GE on attempt 5
# Too many failed attempts for summary of GE, skipping to next df.
# Did not successfully scrape GE
# Failed to gather summary for GILD on attempt 1
# Failed to gather summary for GILD on attempt 2
# Failed to gather summary for GILD on attempt 3
# Failed to gather summary for GILD on attempt 4
# Failed to gather summary for GILD on attempt 5
# Too many failed attempts for summary of GILD, skipping to next df.
# Did not successfully scrape GILD
# Failed to gather summary for GIS on attempt 1
# Failed to gather summary for GIS on attempt 2
# Failed to gather summary for GIS on attempt 3
# Failed to gather summary for GIS on attempt 4
# Failed to gather summary for GIS on attempt 5
# Too many failed attempts for summary of GIS, skipping to next df.
# Did not successfully scrape GIS
# Failed to gather summary for GL on attempt 1
# Failed to gather summary for GL on attempt 2
# Failed to gather summary for GL on attempt 3
# Failed to gather summary for GL on attempt 4
# Failed to gather summary for GL on attempt 5
# Too many failed attempts for summary of GL, skipping to next df.
# Did not successfully scrape GL
# Failed to gather summary for GLW on attempt 1
# Failed to gather summary for GLW on attempt 2
# Failed to gather summary for GLW on attempt 3
# Failed to gather summary for GLW on attempt 4
# Failed to gather summary for GLW on attempt 5
# Too many failed attempts for summary of GLW, skipping to next df.
# Did not successfully scrape GLW
# Failed to gather summary for GM on attempt 1
# Failed to gather summary for GM on attempt 2
# Failed to gather summary for GM on attempt 3
# Failed to gather summary for GM on attempt 4
# Failed to gather summary for GM on attempt 5
# Too many failed attempts for summary of GM, skipping to next df.
# Did not successfully scrape GM
# Failed to gather summary for GOOG on attempt 1
# Failed to gather summary for GOOG on attempt 2
# Failed to gather summary for GOOG on attempt 3
# Failed to gather summary for GOOG on attempt 4
# Failed to gather summary for GOOG on attempt 5
# Too many failed attempts for summary of GOOG, skipping to next df.
# Did not successfully scrape GOOG
# Failed to gather summary for GOOGL on attempt 1
# Failed to gather summary for GOOGL on attempt 2
# Failed to gather summary for GOOGL on attempt 3
# Failed to gather summary for GOOGL on attempt 4
# Failed to gather summary for GOOGL on attempt 5
# Too many failed attempts for summary of GOOGL, skipping to next df.
# Did not successfully scrape GOOGL
# Failed to gather summary for GPC on attempt 1
# Failed to gather summary for GPC on attempt 2
# Failed to gather summary for GPC on attempt 3
# Failed to gather summary for GPC on attempt 4
# Failed to gather summary for GPC on attempt 5
# Too many failed attempts for summary of GPC, skipping to next df.
# Did not successfully scrape GPC
# Failed to gather summary for GPN on attempt 1
# Failed to gather summary for GPN on attempt 2
# Failed to gather summary for GPN on attempt 3
# Failed to gather summary for GPN on attempt 4
# Failed to gather summary for GPN on attempt 5
# Too many failed attempts for summary of GPN, skipping to next df.
# Did not successfully scrape GPN
# Failed to gather summary for GPS on attempt 1
# Failed to gather summary for GPS on attempt 2
# Failed to gather summary for GPS on attempt 3
# Failed to gather summary for GPS on attempt 4
# Failed to gather summary for GPS on attempt 5
# Too many failed attempts for summary of GPS, skipping to next df.
# Did not successfully scrape GPS
# Failed to gather summary for GRMN on attempt 1
# Failed to gather summary for GRMN on attempt 2
# Failed to gather summary for GRMN on attempt 3
# Failed to gather summary for GRMN on attempt 4
# Failed to gather summary for GRMN on attempt 5
# Too many failed attempts for summary of GRMN, skipping to next df.
# Did not successfully scrape GRMN
# Failed to gather summary for GS on attempt 1
# Failed to gather summary for GS on attempt 2
# Failed to gather summary for GS on attempt 3
# Failed to gather summary for GS on attempt 4
# Failed to gather summary for GS on attempt 5
# Too many failed attempts for summary of GS, skipping to next df.
# Did not successfully scrape GS
# Failed to gather summary for GWW on attempt 1
# Failed to gather summary for GWW on attempt 2
# Failed to gather summary for GWW on attempt 3
# Failed to gather summary for GWW on attempt 4
# Failed to gather summary for GWW on attempt 5
# Too many failed attempts for summary of GWW, skipping to next df.
# Did not successfully scrape GWW
# Failed to gather summary for HAL on attempt 1
# Failed to gather summary for HAL on attempt 2
# Failed to gather summary for HAL on attempt 3
# Failed to gather summary for HAL on attempt 4
# Failed to gather summary for HAL on attempt 5
# Too many failed attempts for summary of HAL, skipping to next df.
# Did not successfully scrape HAL
# Failed to gather summary for HAS on attempt 1
# Failed to gather summary for HAS on attempt 2
# Failed to gather summary for HAS on attempt 3
# Failed to gather summary for HAS on attempt 4
# Failed to gather summary for HAS on attempt 5
# Too many failed attempts for summary of HAS, skipping to next df.
# Did not successfully scrape HAS
# Failed to gather summary for HBAN on attempt 1
# Failed to gather summary for HBAN on attempt 2
# Failed to gather summary for HBAN on attempt 3
# Failed to gather summary for HBAN on attempt 4
# Failed to gather summary for HBAN on attempt 5
# Too many failed attempts for summary of HBAN, skipping to next df.
# Did not successfully scrape HBAN
# Failed to gather summary for HBI on attempt 1
# Failed to gather summary for HBI on attempt 2
# Failed to gather summary for HBI on attempt 3
# Failed to gather summary for HBI on attempt 4
# Failed to gather summary for HBI on attempt 5
# Too many failed attempts for summary of HBI, skipping to next df.
# Did not successfully scrape HBI
# Failed to gather summary for HCA on attempt 1
# Failed to gather summary for HCA on attempt 2
# Failed to gather summary for HCA on attempt 3
# Failed to gather summary for HCA on attempt 4
# Failed to gather summary for HCA on attempt 5
# Too many failed attempts for summary of HCA, skipping to next df.
# Did not successfully scrape HCA
# Failed to gather summary for HD on attempt 1
# Failed to gather summary for HD on attempt 2
# Failed to gather summary for HD on attempt 3
# Failed to gather summary for HD on attempt 4
# Failed to gather summary for HD on attempt 5
# Too many failed attempts for summary of HD, skipping to next df.
# Did not successfully scrape HD
# Failed to gather summary for HES on attempt 1
# Failed to gather summary for HES on attempt 2
# Failed to gather summary for HES on attempt 3
# Failed to gather summary for HES on attempt 4
# Failed to gather summary for HES on attempt 5
# Too many failed attempts for summary of HES, skipping to next df.
# Did not successfully scrape HES
# Failed to gather summary for HFC on attempt 1
# Failed to gather summary for HFC on attempt 2
# Failed to gather summary for HFC on attempt 3
# Failed to gather summary for HFC on attempt 4
# Failed to gather summary for HFC on attempt 5
# Too many failed attempts for summary of HFC, skipping to next df.
# Did not successfully scrape HFC
# Failed to gather summary for HIG on attempt 1
# Failed to gather summary for HIG on attempt 2
# Failed to gather summary for HIG on attempt 3
# Failed to gather summary for HIG on attempt 4
# Failed to gather summary for HIG on attempt 5
# Too many failed attempts for summary of HIG, skipping to next df.
# Did not successfully scrape HIG
# Failed to gather summary for HII on attempt 1
# Failed to gather summary for HII on attempt 2
# Failed to gather summary for HII on attempt 3
# Failed to gather summary for HII on attempt 4
# Failed to gather summary for HII on attempt 5
# Too many failed attempts for summary of HII, skipping to next df.
# Did not successfully scrape HII
# Failed to gather summary for HLT on attempt 1
# Failed to gather summary for HLT on attempt 2
# Failed to gather summary for HLT on attempt 3
# Failed to gather summary for HLT on attempt 4
# Failed to gather summary for HLT on attempt 5
# Too many failed attempts for summary of HLT, skipping to next df.
# Did not successfully scrape HLT
# Failed to gather summary for HOG on attempt 1
# Failed to gather summary for HOG on attempt 2
# Failed to gather summary for HOG on attempt 3
# Failed to gather summary for HOG on attempt 4
# Failed to gather summary for HOG on attempt 5
# Too many failed attempts for summary of HOG, skipping to next df.
# Did not successfully scrape HOG
# Failed to gather summary for HOLX on attempt 1
# Failed to gather summary for HOLX on attempt 2
# Failed to gather summary for HOLX on attempt 3
# Failed to gather summary for HOLX on attempt 4
# Failed to gather summary for HOLX on attempt 5
# Too many failed attempts for summary of HOLX, skipping to next df.
# Did not successfully scrape HOLX
# Failed to gather summary for HON on attempt 1
# Failed to gather summary for HON on attempt 2
# Failed to gather summary for HON on attempt 3
# Failed to gather summary for HON on attempt 4
# Failed to gather summary for HON on attempt 5
# Too many failed attempts for summary of HON, skipping to next df.
# Did not successfully scrape HON
# Failed to gather summary for HP on attempt 1
# Failed to gather summary for HP on attempt 2
# Failed to gather summary for HP on attempt 3
# Failed to gather summary for HP on attempt 4
# Failed to gather summary for HP on attempt 5
# Too many failed attempts for summary of HP, skipping to next df.
# Did not successfully scrape HP
# Failed to gather summary for HPE on attempt 1
# Failed to gather summary for HPE on attempt 2
# Failed to gather summary for HPE on attempt 3
# Failed to gather summary for HPE on attempt 4
# Failed to gather summary for HPE on attempt 5
# Too many failed attempts for summary of HPE, skipping to next df.
# Did not successfully scrape HPE
# Failed to gather summary for HPQ on attempt 1
# Failed to gather summary for HPQ on attempt 2
# Failed to gather summary for HPQ on attempt 3
# Failed to gather summary for HPQ on attempt 4
# Failed to gather summary for HPQ on attempt 5
# Too many failed attempts for summary of HPQ, skipping to next df.
# Did not successfully scrape HPQ
# Failed to gather summary for HRB on attempt 1
# Failed to gather summary for HRB on attempt 2
# Failed to gather summary for HRB on attempt 3
# Failed to gather summary for HRB on attempt 4
# Failed to gather summary for HRB on attempt 5
# Too many failed attempts for summary of HRB, skipping to next df.
# Did not successfully scrape HRB
# Failed to gather summary for HRL on attempt 1
# Failed to gather summary for HRL on attempt 2
# Failed to gather summary for HRL on attempt 3
# Failed to gather summary for HRL on attempt 4
# Failed to gather summary for HRL on attempt 5
# Too many failed attempts for summary of HRL, skipping to next df.
# Did not successfully scrape HRL
# Failed to gather summary for HSIC on attempt 1
# Failed to gather summary for HSIC on attempt 2
# Failed to gather summary for HSIC on attempt 3
# Failed to gather summary for HSIC on attempt 4
# Failed to gather summary for HSIC on attempt 5
# Too many failed attempts for summary of HSIC, skipping to next df.
# Did not successfully scrape HSIC
# Failed to gather summary for HST on attempt 1
# Failed to gather summary for HST on attempt 2
# Failed to gather summary for HST on attempt 3
# Failed to gather summary for HST on attempt 4
# Failed to gather summary for HST on attempt 5
# Too many failed attempts for summary of HST, skipping to next df.
# Did not successfully scrape HST
# Failed to gather summary for HSY on attempt 1
# Failed to gather summary for HSY on attempt 2
# Failed to gather summary for HSY on attempt 3
# Failed to gather summary for HSY on attempt 4
# Failed to gather summary for HSY on attempt 5
# Too many failed attempts for summary of HSY, skipping to next df.
# Did not successfully scrape HSY
# Failed to gather summary for HUM on attempt 1
# Failed to gather summary for HUM on attempt 2
# Failed to gather summary for HUM on attempt 3
# Failed to gather summary for HUM on attempt 4
# Failed to gather summary for HUM on attempt 5
# Too many failed attempts for summary of HUM, skipping to next df.
# Did not successfully scrape HUM
# Failed to gather summary for IBM on attempt 1
# Failed to gather summary for IBM on attempt 2
# Failed to gather summary for IBM on attempt 3
# Failed to gather summary for IBM on attempt 4
# Failed to gather summary for IBM on attempt 5
# Too many failed attempts for summary of IBM, skipping to next df.
# Did not successfully scrape IBM
# Failed to gather summary for ICE on attempt 1
# Failed to gather summary for ICE on attempt 2
# Failed to gather summary for ICE on attempt 3
# Failed to gather summary for ICE on attempt 4
# Failed to gather summary for ICE on attempt 5
# Too many failed attempts for summary of ICE, skipping to next df.
# Did not successfully scrape ICE
# Failed to gather summary for IDXX on attempt 1
# Failed to gather summary for IDXX on attempt 2
# Failed to gather summary for IDXX on attempt 3
# Failed to gather summary for IDXX on attempt 4
# Failed to gather summary for IDXX on attempt 5
# Too many failed attempts for summary of IDXX, skipping to next df.
# Did not successfully scrape IDXX
# Failed to gather summary for IEX on attempt 1
# Failed to gather summary for IEX on attempt 2
# Failed to gather summary for IEX on attempt 3
# Failed to gather summary for IEX on attempt 4
# Failed to gather summary for IEX on attempt 5
# Too many failed attempts for summary of IEX, skipping to next df.
# Did not successfully scrape IEX
# Failed to gather summary for IFF on attempt 1
# Failed to gather summary for IFF on attempt 2
# Failed to gather summary for IFF on attempt 3
# Failed to gather summary for IFF on attempt 4
# Failed to gather summary for IFF on attempt 5
# Too many failed attempts for summary of IFF, skipping to next df.
# Did not successfully scrape IFF
# Failed to gather summary for ILMN on attempt 1
# Failed to gather summary for ILMN on attempt 2
# Failed to gather summary for ILMN on attempt 3
# Failed to gather summary for ILMN on attempt 4
# Failed to gather summary for ILMN on attempt 5
# Too many failed attempts for summary of ILMN, skipping to next df.
# Did not successfully scrape ILMN
# Failed to gather summary for INCY on attempt 1
# Failed to gather summary for INCY on attempt 2
# Failed to gather summary for INCY on attempt 3
# Failed to gather summary for INCY on attempt 4
# Failed to gather summary for INCY on attempt 5
# Too many failed attempts for summary of INCY, skipping to next df.
# Did not successfully scrape INCY
# Failed to gather summary for INFO on attempt 1
# Failed to gather summary for INFO on attempt 2
# Failed to gather summary for INFO on attempt 3
# Failed to gather summary for INFO on attempt 4
# Failed to gather summary for INFO on attempt 5
# Too many failed attempts for summary of INFO, skipping to next df.
# Did not successfully scrape INFO
# Failed to gather summary for INTC on attempt 1
# Failed to gather summary for INTC on attempt 2
# Failed to gather summary for INTC on attempt 3
# Failed to gather summary for INTC on attempt 4
# Failed to gather summary for INTC on attempt 5
# Too many failed attempts for summary of INTC, skipping to next df.
# Did not successfully scrape INTC
# Failed to gather summary for INTU on attempt 1
# Failed to gather summary for INTU on attempt 2
# Failed to gather summary for INTU on attempt 3
# Failed to gather summary for INTU on attempt 4
# Failed to gather summary for INTU on attempt 5
# Too many failed attempts for summary of INTU, skipping to next df.
# Did not successfully scrape INTU
# Failed to gather summary for IP on attempt 1
# Failed to gather summary for IP on attempt 2
# Failed to gather summary for IP on attempt 3
# Failed to gather summary for IP on attempt 4
# Failed to gather summary for IP on attempt 5
# Too many failed attempts for summary of IP, skipping to next df.
# Did not successfully scrape IP
# Failed to gather summary for IPG on attempt 1
# Failed to gather summary for IPG on attempt 2
# Failed to gather summary for IPG on attempt 3
# Failed to gather summary for IPG on attempt 4
# Failed to gather summary for IPG on attempt 5
# Too many failed attempts for summary of IPG, skipping to next df.
# Did not successfully scrape IPG
# Failed to gather summary for IPGP on attempt 1
# Failed to gather summary for IPGP on attempt 2
# Failed to gather summary for IPGP on attempt 3
# Failed to gather summary for IPGP on attempt 4
# Failed to gather summary for IPGP on attempt 5
# Too many failed attempts for summary of IPGP, skipping to next df.
# Did not successfully scrape IPGP
# Failed to gather summary for IQV on attempt 1
# Failed to gather summary for IQV on attempt 2
# Failed to gather summary for IQV on attempt 3
# Failed to gather summary for IQV on attempt 4
# Failed to gather summary for IQV on attempt 5
# Too many failed attempts for summary of IQV, skipping to next df.
# Did not successfully scrape IQV
# Failed to gather summary for IR on attempt 1
# Failed to gather summary for IR on attempt 2
# Failed to gather summary for IR on attempt 3
# Failed to gather summary for IR on attempt 4
# Failed to gather summary for IR on attempt 5
# Too many failed attempts for summary of IR, skipping to next df.
# Did not successfully scrape IR
# Failed to gather summary for IRM on attempt 1
# Failed to gather summary for IRM on attempt 2
# Failed to gather summary for IRM on attempt 3
# Failed to gather summary for IRM on attempt 4
# Failed to gather summary for IRM on attempt 5
# Too many failed attempts for summary of IRM, skipping to next df.
# Did not successfully scrape IRM
# Failed to gather summary for ISRG on attempt 1
# Failed to gather summary for ISRG on attempt 2
# Failed to gather summary for ISRG on attempt 3
# Failed to gather summary for ISRG on attempt 4
# Failed to gather summary for ISRG on attempt 5
# Too many failed attempts for summary of ISRG, skipping to next df.
# Did not successfully scrape ISRG
# Failed to gather summary for IT on attempt 1
# Failed to gather summary for IT on attempt 2
# Failed to gather summary for IT on attempt 3
# Failed to gather summary for IT on attempt 4
# Failed to gather summary for IT on attempt 5
# Too many failed attempts for summary of IT, skipping to next df.
# Did not successfully scrape IT
# Failed to gather summary for ITW on attempt 1
# Failed to gather summary for ITW on attempt 2
# Failed to gather summary for ITW on attempt 3
# Failed to gather summary for ITW on attempt 4
# Failed to gather summary for ITW on attempt 5
# Too many failed attempts for summary of ITW, skipping to next df.
# Did not successfully scrape ITW
# Failed to gather summary for IVZ on attempt 1
# Failed to gather summary for IVZ on attempt 2
# Failed to gather summary for IVZ on attempt 3
# Failed to gather summary for IVZ on attempt 4
# Failed to gather summary for IVZ on attempt 5
# Too many failed attempts for summary of IVZ, skipping to next df.
# Did not successfully scrape IVZ
# Failed to gather summary for J on attempt 1
# Failed to gather summary for J on attempt 2
# Failed to gather summary for J on attempt 3
# Failed to gather summary for J on attempt 4
# Failed to gather summary for J on attempt 5
# Too many failed attempts for summary of J, skipping to next df.
# Did not successfully scrape J
# Failed to gather summary for JBHT on attempt 1
# Failed to gather summary for JBHT on attempt 2
# Failed to gather summary for JBHT on attempt 3
# Failed to gather summary for JBHT on attempt 4
# Failed to gather summary for JBHT on attempt 5
# Too many failed attempts for summary of JBHT, skipping to next df.
# Did not successfully scrape JBHT
# Failed to gather summary for JCI on attempt 1
# Failed to gather summary for JCI on attempt 2
# Failed to gather summary for JCI on attempt 3
# Failed to gather summary for JCI on attempt 4
# Failed to gather summary for JCI on attempt 5
# Too many failed attempts for summary of JCI, skipping to next df.
# Did not successfully scrape JCI
# Failed to gather summary for JKHY on attempt 1
# Failed to gather summary for JKHY on attempt 2
# Failed to gather summary for JKHY on attempt 3
# Failed to gather summary for JKHY on attempt 4
# Failed to gather summary for JKHY on attempt 5
# Too many failed attempts for summary of JKHY, skipping to next df.
# Did not successfully scrape JKHY
# Failed to gather summary for JNJ on attempt 1
# Failed to gather summary for JNJ on attempt 2
# Failed to gather summary for JNJ on attempt 3
# Failed to gather summary for JNJ on attempt 4
# Failed to gather summary for JNJ on attempt 5
# Too many failed attempts for summary of JNJ, skipping to next df.
# Did not successfully scrape JNJ
# Failed to gather summary for JNPR on attempt 1
# Failed to gather summary for JNPR on attempt 2
# Failed to gather summary for JNPR on attempt 3
# Failed to gather summary for JNPR on attempt 4
# Failed to gather summary for JNPR on attempt 5
# Too many failed attempts for summary of JNPR, skipping to next df.
# Did not successfully scrape JNPR
# Failed to gather summary for JPM on attempt 1
# Failed to gather summary for JPM on attempt 2
# Failed to gather summary for JPM on attempt 3
# Failed to gather summary for JPM on attempt 4
# Failed to gather summary for JPM on attempt 5
# Too many failed attempts for summary of JPM, skipping to next df.
# Did not successfully scrape JPM
# Failed to gather summary for JWN on attempt 1
# Failed to gather summary for JWN on attempt 2
# Failed to gather summary for JWN on attempt 3
# Failed to gather summary for JWN on attempt 4
# Failed to gather summary for JWN on attempt 5
# Too many failed attempts for summary of JWN, skipping to next df.
# Did not successfully scrape JWN
# Failed to gather summary for K on attempt 1
# Failed to gather summary for K on attempt 2
# Failed to gather summary for K on attempt 3
# Failed to gather summary for K on attempt 4
# Failed to gather summary for K on attempt 5
# Too many failed attempts for summary of K, skipping to next df.
# Did not successfully scrape K
# Failed to gather summary for KEY on attempt 1
# Failed to gather summary for KEY on attempt 2
# Failed to gather summary for KEY on attempt 3
# Failed to gather summary for KEY on attempt 4
# Failed to gather summary for KEY on attempt 5
# Too many failed attempts for summary of KEY, skipping to next df.
# Did not successfully scrape KEY
# Failed to gather summary for KEYS on attempt 1
# Failed to gather summary for KEYS on attempt 2
# Failed to gather summary for KEYS on attempt 3
# Failed to gather summary for KEYS on attempt 4
# Failed to gather summary for KEYS on attempt 5
# Too many failed attempts for summary of KEYS, skipping to next df.
# Did not successfully scrape KEYS
# Failed to gather summary for KHC on attempt 1
# Failed to gather summary for KHC on attempt 2
# Failed to gather summary for KHC on attempt 3
# Failed to gather summary for KHC on attempt 4
# Failed to gather summary for KHC on attempt 5
# Too many failed attempts for summary of KHC, skipping to next df.
# Did not successfully scrape KHC
# Failed to gather summary for KIM on attempt 1
# Failed to gather summary for KIM on attempt 2
# Failed to gather summary for KIM on attempt 3
# Failed to gather summary for KIM on attempt 4
# Failed to gather summary for KIM on attempt 5
# Too many failed attempts for summary of KIM, skipping to next df.
# Did not successfully scrape KIM
# Failed to gather summary for KLAC on attempt 1
# Failed to gather summary for KLAC on attempt 2
# Failed to gather summary for KLAC on attempt 3
# Failed to gather summary for KLAC on attempt 4
# Failed to gather summary for KLAC on attempt 5
# Too many failed attempts for summary of KLAC, skipping to next df.
# Did not successfully scrape KLAC
# Failed to gather summary for KMB on attempt 1
# Failed to gather summary for KMB on attempt 2
# Failed to gather summary for KMB on attempt 3
# Failed to gather summary for KMB on attempt 4
# Failed to gather summary for KMB on attempt 5
# Too many failed attempts for summary of KMB, skipping to next df.
# Did not successfully scrape KMB
# Failed to gather summary for KMI on attempt 1
# Failed to gather summary for KMI on attempt 2
# Failed to gather summary for KMI on attempt 3
# Failed to gather summary for KMI on attempt 4
# Failed to gather summary for KMI on attempt 5
# Too many failed attempts for summary of KMI, skipping to next df.
# Did not successfully scrape KMI
# Failed to gather summary for KMX on attempt 1
# Failed to gather summary for KMX on attempt 2
# Failed to gather summary for KMX on attempt 3
# Failed to gather summary for KMX on attempt 4
# Failed to gather summary for KMX on attempt 5
# Too many failed attempts for summary of KMX, skipping to next df.
# Did not successfully scrape KMX
# Failed to gather summary for KO on attempt 1
# Failed to gather summary for KO on attempt 2
# Failed to gather summary for KO on attempt 3
# Failed to gather summary for KO on attempt 4
# Failed to gather summary for KO on attempt 5
# Too many failed attempts for summary of KO, skipping to next df.
# Did not successfully scrape KO
# Failed to gather summary for KR on attempt 1
# Failed to gather summary for KR on attempt 2
# Failed to gather summary for KR on attempt 3
# Failed to gather summary for KR on attempt 4
# Failed to gather summary for KR on attempt 5
# Too many failed attempts for summary of KR, skipping to next df.
# Did not successfully scrape KR
# Failed to gather summary for KSS on attempt 1
# Failed to gather summary for KSS on attempt 2
# Failed to gather summary for KSS on attempt 3
# Failed to gather summary for KSS on attempt 4
# Failed to gather summary for KSS on attempt 5
# Too many failed attempts for summary of KSS, skipping to next df.
# Did not successfully scrape KSS
# Failed to gather summary for KSU on attempt 1
# Failed to gather summary for KSU on attempt 2
# Failed to gather summary for KSU on attempt 3
# Failed to gather summary for KSU on attempt 4
# Failed to gather summary for KSU on attempt 5
# Too many failed attempts for summary of KSU, skipping to next df.
# Did not successfully scrape KSU
# Failed to gather summary for L on attempt 1
# Failed to gather summary for L on attempt 2
# Failed to gather summary for L on attempt 3
# Failed to gather summary for L on attempt 4
# Failed to gather summary for L on attempt 5
# Too many failed attempts for summary of L, skipping to next df.
# Did not successfully scrape L
# Failed to gather summary for LB on attempt 1
# Failed to gather summary for LB on attempt 2
# Failed to gather summary for LB on attempt 3
# Failed to gather summary for LB on attempt 4
# Failed to gather summary for LB on attempt 5
# Too many failed attempts for summary of LB, skipping to next df.
# Did not successfully scrape LB
# Failed to gather summary for LDOS on attempt 1
# Failed to gather summary for LDOS on attempt 2
# Failed to gather summary for LDOS on attempt 3
# Failed to gather summary for LDOS on attempt 4
# Failed to gather summary for LDOS on attempt 5
# Too many failed attempts for summary of LDOS, skipping to next df.
# Did not successfully scrape LDOS
# Failed to gather summary for LEG on attempt 1
# Failed to gather summary for LEG on attempt 2
# Failed to gather summary for LEG on attempt 3
# Failed to gather summary for LEG on attempt 4
# Failed to gather summary for LEG on attempt 5
# Too many failed attempts for summary of LEG, skipping to next df.
# Did not successfully scrape LEG
# Failed to gather summary for LEN on attempt 1
# Failed to gather summary for LEN on attempt 2
# Failed to gather summary for LEN on attempt 3
# Failed to gather summary for LEN on attempt 4
# Failed to gather summary for LEN on attempt 5
# Too many failed attempts for summary of LEN, skipping to next df.
# Did not successfully scrape LEN
# Failed to gather summary for LH on attempt 1
# Failed to gather summary for LH on attempt 2
# Failed to gather summary for LH on attempt 3
# Failed to gather summary for LH on attempt 4
# Failed to gather summary for LH on attempt 5
# Too many failed attempts for summary of LH, skipping to next df.
# Did not successfully scrape LH
# Failed to gather summary for LHX on attempt 1
# Failed to gather summary for LHX on attempt 2
# Failed to gather summary for LHX on attempt 3
# Failed to gather summary for LHX on attempt 4
# Failed to gather summary for LHX on attempt 5
# Too many failed attempts for summary of LHX, skipping to next df.
# Did not successfully scrape LHX
# Failed to gather summary for LIN on attempt 1
# Failed to gather summary for LIN on attempt 2
# Failed to gather summary for LIN on attempt 3
# Failed to gather summary for LIN on attempt 4
# Failed to gather summary for LIN on attempt 5
# Too many failed attempts for summary of LIN, skipping to next df.
# Did not successfully scrape LIN
# Failed to gather summary for LKQ on attempt 1
# Failed to gather summary for LKQ on attempt 2
# Failed to gather summary for LKQ on attempt 3
# Failed to gather summary for LKQ on attempt 4
# Failed to gather summary for LKQ on attempt 5
# Too many failed attempts for summary of LKQ, skipping to next df.
# Did not successfully scrape LKQ
# Failed to gather summary for LLY on attempt 1
# Failed to gather summary for LLY on attempt 2
# Failed to gather summary for LLY on attempt 3
# Failed to gather summary for LLY on attempt 4
# Failed to gather summary for LLY on attempt 5
# Too many failed attempts for summary of LLY, skipping to next df.
# Did not successfully scrape LLY
# Failed to gather summary for LMT on attempt 1
# Failed to gather summary for LMT on attempt 2
# Failed to gather summary for LMT on attempt 3
# Failed to gather summary for LMT on attempt 4
# Failed to gather summary for LMT on attempt 5
# Too many failed attempts for summary of LMT, skipping to next df.
# Did not successfully scrape LMT
# Failed to gather summary for LNC on attempt 1
# Failed to gather summary for LNC on attempt 2
# Failed to gather summary for LNC on attempt 3
# Failed to gather summary for LNC on attempt 4
# Failed to gather summary for LNC on attempt 5
# Too many failed attempts for summary of LNC, skipping to next df.
# Did not successfully scrape LNC
# Failed to gather summary for LNT on attempt 1
# Failed to gather summary for LNT on attempt 2
# Failed to gather summary for LNT on attempt 3
# Failed to gather summary for LNT on attempt 4
# Failed to gather summary for LNT on attempt 5
# Too many failed attempts for summary of LNT, skipping to next df.
# Did not successfully scrape LNT
# Failed to gather summary for LOW on attempt 1
# Failed to gather summary for LOW on attempt 2
# Failed to gather summary for LOW on attempt 3
# Failed to gather summary for LOW on attempt 4
# Failed to gather summary for LOW on attempt 5
# Too many failed attempts for summary of LOW, skipping to next df.
# Did not successfully scrape LOW
# Failed to gather summary for LRCX on attempt 1
# Failed to gather summary for LRCX on attempt 2
# Failed to gather summary for LRCX on attempt 3
# Failed to gather summary for LRCX on attempt 4
# Failed to gather summary for LRCX on attempt 5
# Too many failed attempts for summary of LRCX, skipping to next df.
# Did not successfully scrape LRCX
# Failed to gather summary for LUV on attempt 1
# Failed to gather summary for LUV on attempt 2
# Failed to gather summary for LUV on attempt 3
# Failed to gather summary for LUV on attempt 4
# Failed to gather summary for LUV on attempt 5
# Too many failed attempts for summary of LUV, skipping to next df.
# Did not successfully scrape LUV
# Failed to gather summary for LVS on attempt 1
# Failed to gather summary for LVS on attempt 2
# Failed to gather summary for LVS on attempt 3
# Failed to gather summary for LVS on attempt 4
# Failed to gather summary for LVS on attempt 5
# Too many failed attempts for summary of LVS, skipping to next df.
# Did not successfully scrape LVS
# Failed to gather summary for LW on attempt 1
# Failed to gather summary for LW on attempt 2
# Failed to gather summary for LW on attempt 3
# Failed to gather summary for LW on attempt 4
# Failed to gather summary for LW on attempt 5
# Too many failed attempts for summary of LW, skipping to next df.
# Did not successfully scrape LW
# Failed to gather summary for LYB on attempt 1
# Failed to gather summary for LYB on attempt 2
# Failed to gather summary for LYB on attempt 3
# Failed to gather summary for LYB on attempt 4
# Failed to gather summary for LYB on attempt 5
# Too many failed attempts for summary of LYB, skipping to next df.
# Did not successfully scrape LYB
# Failed to gather summary for LYV on attempt 1
# Failed to gather summary for LYV on attempt 2
# Failed to gather summary for LYV on attempt 3
# Failed to gather summary for LYV on attempt 4
# Failed to gather summary for LYV on attempt 5
# Too many failed attempts for summary of LYV, skipping to next df.
# Did not successfully scrape LYV
# Failed to gather summary for M on attempt 1
# Failed to gather summary for M on attempt 2
# Failed to gather summary for M on attempt 3
# Failed to gather summary for M on attempt 4
# Failed to gather summary for M on attempt 5
# Too many failed attempts for summary of M, skipping to next df.
# Did not successfully scrape M
# Failed to gather summary for MA on attempt 1
# Failed to gather summary for MA on attempt 2
# Failed to gather summary for MA on attempt 3
# Failed to gather summary for MA on attempt 4
# Failed to gather summary for MA on attempt 5
# Too many failed attempts for summary of MA, skipping to next df.
# Did not successfully scrape MA
# Failed to gather summary for MAA on attempt 1
# Failed to gather summary for MAA on attempt 2
# Failed to gather summary for MAA on attempt 3
# Failed to gather summary for MAA on attempt 4
# Failed to gather summary for MAA on attempt 5
# Too many failed attempts for summary of MAA, skipping to next df.
# Did not successfully scrape MAA
# Failed to gather summary for MAR on attempt 1
# Failed to gather summary for MAR on attempt 2
# Failed to gather summary for MAR on attempt 3
# Failed to gather summary for MAR on attempt 4
# Failed to gather summary for MAR on attempt 5
# Too many failed attempts for summary of MAR, skipping to next df.
# Did not successfully scrape MAR
# Failed to gather summary for MAS on attempt 1
# Failed to gather summary for MAS on attempt 2
# Failed to gather summary for MAS on attempt 3
# Failed to gather summary for MAS on attempt 4
# Failed to gather summary for MAS on attempt 5
# Too many failed attempts for summary of MAS, skipping to next df.
# Did not successfully scrape MAS
# Failed to gather summary for MCD on attempt 1
# Failed to gather summary for MCD on attempt 2
# Failed to gather summary for MCD on attempt 3
# Failed to gather summary for MCD on attempt 4
# Failed to gather summary for MCD on attempt 5
# Too many failed attempts for summary of MCD, skipping to next df.
# Did not successfully scrape MCD
# Failed to gather summary for MCHP on attempt 1
# Failed to gather summary for MCHP on attempt 2
# Failed to gather summary for MCHP on attempt 3
# Failed to gather summary for MCHP on attempt 4
# Failed to gather summary for MCHP on attempt 5
# Too many failed attempts for summary of MCHP, skipping to next df.
# Did not successfully scrape MCHP
# Failed to gather summary for MCK on attempt 1
# Failed to gather summary for MCK on attempt 2
# Failed to gather summary for MCK on attempt 3
# Failed to gather summary for MCK on attempt 4
# Failed to gather summary for MCK on attempt 5
# Too many failed attempts for summary of MCK, skipping to next df.
# Did not successfully scrape MCK
# Failed to gather summary for MCO on attempt 1
# Failed to gather summary for MCO on attempt 2
# Failed to gather summary for MCO on attempt 3
# Failed to gather summary for MCO on attempt 4
# Failed to gather summary for MCO on attempt 5
# Too many failed attempts for summary of MCO, skipping to next df.
# Did not successfully scrape MCO
# Failed to gather summary for MDLZ on attempt 1
# Failed to gather summary for MDLZ on attempt 2
# Failed to gather summary for MDLZ on attempt 3
# Failed to gather summary for MDLZ on attempt 4
# Failed to gather summary for MDLZ on attempt 5
# Too many failed attempts for summary of MDLZ, skipping to next df.
# Did not successfully scrape MDLZ
# Failed to gather summary for MDT on attempt 1
# Failed to gather summary for MDT on attempt 2
# Failed to gather summary for MDT on attempt 3
# Failed to gather summary for MDT on attempt 4
# Failed to gather summary for MDT on attempt 5
# Too many failed attempts for summary of MDT, skipping to next df.
# Did not successfully scrape MDT
# Failed to gather summary for MET on attempt 1
# Failed to gather summary for MET on attempt 2
# Failed to gather summary for MET on attempt 3
# Failed to gather summary for MET on attempt 4
# Failed to gather summary for MET on attempt 5
# Too many failed attempts for summary of MET, skipping to next df.
# Did not successfully scrape MET
# Failed to gather summary for MGM on attempt 1
# Failed to gather summary for MGM on attempt 2
# Failed to gather summary for MGM on attempt 3
# Failed to gather summary for MGM on attempt 4
# Failed to gather summary for MGM on attempt 5
# Too many failed attempts for summary of MGM, skipping to next df.
# Did not successfully scrape MGM
# Failed to gather summary for MHK on attempt 1
# Failed to gather summary for MHK on attempt 2
# Failed to gather summary for MHK on attempt 3
# Failed to gather summary for MHK on attempt 4
# Failed to gather summary for MHK on attempt 5
# Too many failed attempts for summary of MHK, skipping to next df.
# Did not successfully scrape MHK
# Failed to gather summary for MKC on attempt 1
# Failed to gather summary for MKC on attempt 2
# Failed to gather summary for MKC on attempt 3
# Failed to gather summary for MKC on attempt 4
# Failed to gather summary for MKC on attempt 5
# Too many failed attempts for summary of MKC, skipping to next df.
# Did not successfully scrape MKC
# Failed to gather summary for MKTX on attempt 1
# Failed to gather summary for MKTX on attempt 2
# Failed to gather summary for MKTX on attempt 3
# Failed to gather summary for MKTX on attempt 4
# Failed to gather summary for MKTX on attempt 5
# Too many failed attempts for summary of MKTX, skipping to next df.
# Did not successfully scrape MKTX
# Failed to gather summary for MLM on attempt 1
# Failed to gather summary for MLM on attempt 2
# Failed to gather summary for MLM on attempt 3
# Failed to gather summary for MLM on attempt 4
# Failed to gather summary for MLM on attempt 5
# Too many failed attempts for summary of MLM, skipping to next df.
# Did not successfully scrape MLM
# Failed to gather summary for MMC on attempt 1
# Failed to gather summary for MMC on attempt 2
# Failed to gather summary for MMC on attempt 3
# Failed to gather summary for MMC on attempt 4
# Failed to gather summary for MMC on attempt 5
# Too many failed attempts for summary of MMC, skipping to next df.
# Did not successfully scrape MMC
# Failed to gather summary for MMM on attempt 1
# Failed to gather summary for MMM on attempt 2
# Failed to gather summary for MMM on attempt 3
# Failed to gather summary for MMM on attempt 4
# Failed to gather summary for MMM on attempt 5
# Too many failed attempts for summary of MMM, skipping to next df.
# Did not successfully scrape MMM
# Failed to gather summary for MNST on attempt 1
# Failed to gather summary for MNST on attempt 2
# Failed to gather summary for MNST on attempt 3
# Failed to gather summary for MNST on attempt 4
# Failed to gather summary for MNST on attempt 5
# Too many failed attempts for summary of MNST, skipping to next df.
# Did not successfully scrape MNST
# Failed to gather summary for MO on attempt 1
# Failed to gather summary for MO on attempt 2
# Failed to gather summary for MO on attempt 3
# Failed to gather summary for MO on attempt 4
# Failed to gather summary for MO on attempt 5
# Too many failed attempts for summary of MO, skipping to next df.
# Did not successfully scrape MO
# Failed to gather summary for MOS on attempt 1
# Failed to gather summary for MOS on attempt 2
# Failed to gather summary for MOS on attempt 3
# Failed to gather summary for MOS on attempt 4
# Failed to gather summary for MOS on attempt 5
# Too many failed attempts for summary of MOS, skipping to next df.
# Did not successfully scrape MOS
# Failed to gather summary for MPC on attempt 1
# Failed to gather summary for MPC on attempt 2
# Failed to gather summary for MPC on attempt 3
# Failed to gather summary for MPC on attempt 4
# Failed to gather summary for MPC on attempt 5
# Too many failed attempts for summary of MPC, skipping to next df.
# Did not successfully scrape MPC
# Failed to gather summary for MRK on attempt 1
# Failed to gather summary for MRK on attempt 2
# Failed to gather summary for MRK on attempt 3
# Failed to gather summary for MRK on attempt 4
# Failed to gather summary for MRK on attempt 5
# Too many failed attempts for summary of MRK, skipping to next df.
# Did not successfully scrape MRK
# Failed to gather summary for MRO on attempt 1
# Failed to gather summary for MRO on attempt 2
# Failed to gather summary for MRO on attempt 3
# Failed to gather summary for MRO on attempt 4
# Failed to gather summary for MRO on attempt 5
# Too many failed attempts for summary of MRO, skipping to next df.
# Did not successfully scrape MRO
# Failed to gather summary for MS on attempt 1
# Failed to gather summary for MS on attempt 2
# Failed to gather summary for MS on attempt 3
# ...
# Failed to gather summary for UDR on attempt 4
# Failed to gather summary for UDR on attempt 5
# Too many failed attempts for summary of UDR, skipping to next df.
# Did not successfully scrape UDR
# Failed to gather summary for UHS on attempt 1
# Failed to gather summary for UHS on attempt 2
# Failed to gather summary for UHS on attempt 3
# Failed to gather summary for UHS on attempt 4
# Failed to gather summary for UHS on attempt 5
# Too many failed attempts for summary of UHS, skipping to next df.
# Did not successfully scrape UHS
# Failed to gather summary for ULTA on attempt 1
# Failed to gather summary for ULTA on attempt 2
# Failed to gather summary for ULTA on attempt 3
# Failed to gather summary for ULTA on attempt 4
# Failed to gather summary for ULTA on attempt 5
# Too many failed attempts for summary of ULTA, skipping to next df.
# Did not successfully scrape ULTA
# Failed to gather summary for UNH on attempt 1
# Failed to gather summary for UNH on attempt 2
# Failed to gather summary for UNH on attempt 3
# Failed to gather summary for UNH on attempt 4
# Failed to gather summary for UNH on attempt 5
# Too many failed attempts for summary of UNH, skipping to next df.
# Did not successfully scrape UNH
# Failed to gather summary for UNM on attempt 1
# Failed to gather summary for UNM on attempt 2
# Failed to gather summary for UNM on attempt 3
# Failed to gather summary for UNM on attempt 4
# Failed to gather summary for UNM on attempt 5
# Too many failed attempts for summary of UNM, skipping to next df.
# Did not successfully scrape UNM
# Failed to gather summary for UNP on attempt 1
# Failed to gather summary for UNP on attempt 2
# Failed to gather summary for UNP on attempt 3
# Failed to gather summary for UNP on attempt 4
# Failed to gather summary for UNP on attempt 5
# Too many failed attempts for summary of UNP, skipping to next df.
# Did not successfully scrape UNP
# Failed to gather summary for UPS on attempt 1
# Failed to gather summary for UPS on attempt 2
# Failed to gather summary for UPS on attempt 3
# Failed to gather summary for UPS on attempt 4
# Failed to gather summary for UPS on attempt 5
# Too many failed attempts for summary of UPS, skipping to next df.
# Did not successfully scrape UPS
# Failed to gather summary for URI on attempt 1
# Failed to gather summary for URI on attempt 2
# Failed to gather summary for URI on attempt 3
# Failed to gather summary for URI on attempt 4
# Failed to gather summary for URI on attempt 5
# Too many failed attempts for summary of URI, skipping to next df.
# Did not successfully scrape URI
# Failed to gather summary for USB on attempt 1
# Failed to gather summary for USB on attempt 2
# Failed to gather summary for USB on attempt 3
# Failed to gather summary for USB on attempt 4
# Failed to gather summary for USB on attempt 5
# Too many failed attempts for summary of USB, skipping to next df.
# Did not successfully scrape USB
# Failed to gather summary for V on attempt 1
# Failed to gather summary for V on attempt 2
# Failed to gather summary for V on attempt 3
# Failed to gather summary for V on attempt 4
# Failed to gather summary for V on attempt 5
# Too many failed attempts for summary of V, skipping to next df.
# Did not successfully scrape V
# Failed to gather summary for VAR on attempt 1
# Failed to gather summary for VAR on attempt 2
# Failed to gather summary for VAR on attempt 3
# Failed to gather summary for VAR on attempt 4
# Failed to gather summary for VAR on attempt 5
# Too many failed attempts for summary of VAR, skipping to next df.
# Did not successfully scrape VAR
# Failed to gather summary for VFC on attempt 1
# Failed to gather summary for VFC on attempt 2
# Failed to gather summary for VFC on attempt 3
# Failed to gather summary for VFC on attempt 4
# Failed to gather summary for VFC on attempt 5
# Too many failed attempts for summary of VFC, skipping to next df.
# Did not successfully scrape VFC
# Failed to gather summary for VIAC on attempt 1
# Failed to gather summary for VIAC on attempt 2
# Failed to gather summary for VIAC on attempt 3
# Failed to gather summary for VIAC on attempt 4
# Failed to gather summary for VIAC on attempt 5
# Too many failed attempts for summary of VIAC, skipping to next df.
# Did not successfully scrape VIAC
# Failed to gather summary for VLO on attempt 1
# Failed to gather summary for VLO on attempt 2
# Failed to gather summary for VLO on attempt 3
# Failed to gather summary for VLO on attempt 4
# Failed to gather summary for VLO on attempt 5
# Too many failed attempts for summary of VLO, skipping to next df.
# Did not successfully scrape VLO
# Failed to gather summary for VMC on attempt 1
# Failed to gather summary for VMC on attempt 2
# Failed to gather summary for VMC on attempt 3
# Failed to gather summary for VMC on attempt 4
# Failed to gather summary for VMC on attempt 5
# Too many failed attempts for summary of VMC, skipping to next df.
# Did not successfully scrape VMC
# Failed to gather summary for VNO on attempt 1
# Failed to gather summary for VNO on attempt 2
# Failed to gather summary for VNO on attempt 3
# Failed to gather summary for VNO on attempt 4
# Failed to gather summary for VNO on attempt 5
# Too many failed attempts for summary of VNO, skipping to next df.
# Did not successfully scrape VNO
# Failed to gather summary for VRSK on attempt 1
# Failed to gather summary for VRSK on attempt 2
# Failed to gather summary for VRSK on attempt 3
# Failed to gather summary for VRSK on attempt 4
# Failed to gather summary for VRSK on attempt 5
# Too many failed attempts for summary of VRSK, skipping to next df.
# Did not successfully scrape VRSK
# Failed to gather summary for VRSN on attempt 1
# Failed to gather summary for VRSN on attempt 2
# Failed to gather summary for VRSN on attempt 3
# Failed to gather summary for VRSN on attempt 4
# Failed to gather summary for VRSN on attempt 5
# Too many failed attempts for summary of VRSN, skipping to next df.
# Did not successfully scrape VRSN
# Failed to gather summary for VRTX on attempt 1
# Failed to gather summary for VRTX on attempt 2
# Failed to gather summary for VRTX on attempt 3
# Failed to gather summary for VRTX on attempt 4
# Failed to gather summary for VRTX on attempt 5
# Too many failed attempts for summary of VRTX, skipping to next df.
# Did not successfully scrape VRTX
# Failed to gather summary for VTR on attempt 1
# Failed to gather summary for VTR on attempt 2
# Failed to gather summary for VTR on attempt 3
# Failed to gather summary for VTR on attempt 4
# Failed to gather summary for VTR on attempt 5
# Too many failed attempts for summary of VTR, skipping to next df.
# Did not successfully scrape VTR
# Failed to gather summary for VZ on attempt 1
# Failed to gather summary for VZ on attempt 2
# Failed to gather summary for VZ on attempt 3
# Failed to gather summary for VZ on attempt 4
# Failed to gather summary for VZ on attempt 5
# Too many failed attempts for summary of VZ, skipping to next df.
# Did not successfully scrape VZ
# Failed to gather summary for WAB on attempt 1
# Failed to gather summary for WAB on attempt 2
# Failed to gather summary for WAB on attempt 3
# Failed to gather summary for WAB on attempt 4
# Failed to gather summary for WAB on attempt 5
# Too many failed attempts for summary of WAB, skipping to next df.
# Did not successfully scrape WAB
# Failed to gather summary for WAT on attempt 1
# Failed to gather summary for WAT on attempt 2
# Failed to gather summary for WAT on attempt 3
# Failed to gather summary for WAT on attempt 4
# Failed to gather summary for WAT on attempt 5
# Too many failed attempts for summary of WAT, skipping to next df.
# Did not successfully scrape WAT
# Failed to gather summary for WBA on attempt 1
# Failed to gather summary for WBA on attempt 2
# Failed to gather summary for WBA on attempt 3
# Failed to gather summary for WBA on attempt 4
# Failed to gather summary for WBA on attempt 5
# Too many failed attempts for summary of WBA, skipping to next df.
# Did not successfully scrape WBA
# Failed to gather summary for WDC on attempt 1
# Failed to gather summary for WDC on attempt 2
# Failed to gather summary for WDC on attempt 3
# Failed to gather summary for WDC on attempt 4
# Failed to gather summary for WDC on attempt 5
# Too many failed attempts for summary of WDC, skipping to next df.
# Did not successfully scrape WDC
# Failed to gather summary for WEC on attempt 1
# Failed to gather summary for WEC on attempt 2
# Failed to gather summary for WEC on attempt 3
# Failed to gather summary for WEC on attempt 4
# Failed to gather summary for WEC on attempt 5
# Too many failed attempts for summary of WEC, skipping to next df.
# Did not successfully scrape WEC
# Failed to gather summary for WELL on attempt 1
# Failed to gather summary for WELL on attempt 2
# Failed to gather summary for WELL on attempt 3
# Failed to gather summary for WELL on attempt 4
# Failed to gather summary for WELL on attempt 5
# Too many failed attempts for summary of WELL, skipping to next df.
# Did not successfully scrape WELL
# Failed to gather summary for WFC on attempt 1
# Failed to gather summary for WFC on attempt 2
# Failed to gather summary for WFC on attempt 3
# Failed to gather summary for WFC on attempt 4
# Failed to gather summary for WFC on attempt 5
# Too many failed attempts for summary of WFC, skipping to next df.
# Did not successfully scrape WFC
# Failed to gather summary for WHR on attempt 1
# Failed to gather summary for WHR on attempt 2
# Failed to gather summary for WHR on attempt 3
# Failed to gather summary for WHR on attempt 4
# Failed to gather summary for WHR on attempt 5
# Too many failed attempts for summary of WHR, skipping to next df.
# Did not successfully scrape WHR
# Failed to gather summary for WLTW on attempt 1
# Failed to gather summary for WLTW on attempt 2
# Failed to gather summary for WLTW on attempt 3
# Failed to gather summary for WLTW on attempt 4
# Failed to gather summary for WLTW on attempt 5
# Too many failed attempts for summary of WLTW, skipping to next df.
# Did not successfully scrape WLTW
# Failed to gather summary for WM on attempt 1
# Failed to gather summary for WM on attempt 2
# Failed to gather summary for WM on attempt 3
# Failed to gather summary for WM on attempt 4
# Failed to gather summary for WM on attempt 5
# Too many failed attempts for summary of WM, skipping to next df.
# Did not successfully scrape WM
# Failed to gather summary for WMB on attempt 1
# Failed to gather summary for WMB on attempt 2
# Failed to gather summary for WMB on attempt 3
# Failed to gather summary for WMB on attempt 4
# Failed to gather summary for WMB on attempt 5
# Too many failed attempts for summary of WMB, skipping to next df.
# Did not successfully scrape WMB
# Failed to gather summary for WMT on attempt 1
# Failed to gather summary for WMT on attempt 2
# Failed to gather summary for WMT on attempt 3
# Failed to gather summary for WMT on attempt 4
# Failed to gather summary for WMT on attempt 5
# Too many failed attempts for summary of WMT, skipping to next df.
# Did not successfully scrape WMT
# Failed to gather summary for WRB on attempt 1
# Failed to gather summary for WRB on attempt 2
# Failed to gather summary for WRB on attempt 3
# Failed to gather summary for WRB on attempt 4
# Failed to gather summary for WRB on attempt 5
# Too many failed attempts for summary of WRB, skipping to next df.
# Did not successfully scrape WRB
# Failed to gather summary for WRK on attempt 1
# Failed to gather summary for WRK on attempt 2
# Failed to gather summary for WRK on attempt 3
# Failed to gather summary for WRK on attempt 4
# Failed to gather summary for WRK on attempt 5
# Too many failed attempts for summary of WRK, skipping to next df.
# Did not successfully scrape WRK
# Failed to gather summary for WU on attempt 1
# Failed to gather summary for WU on attempt 2
# Failed to gather summary for WU on attempt 3
# Failed to gather summary for WU on attempt 4
# Failed to gather summary for WU on attempt 5
# Too many failed attempts for summary of WU, skipping to next df.
# Did not successfully scrape WU
# Failed to gather summary for WY on attempt 1
# Failed to gather summary for WY on attempt 2
# Failed to gather summary for WY on attempt 3
# Failed to gather summary for WY on attempt 4
# Failed to gather summary for WY on attempt 5
# Too many failed attempts for summary of WY, skipping to next df.
# Did not successfully scrape WY
# Failed to gather summary for WYNN on attempt 1
# Failed to gather summary for WYNN on attempt 2
# Failed to gather summary for WYNN on attempt 3
# Failed to gather summary for WYNN on attempt 4
# Failed to gather summary for WYNN on attempt 5
# Too many failed attempts for summary of WYNN, skipping to next df.
# Did not successfully scrape WYNN
# Failed to gather summary for XEL on attempt 1
# Failed to gather summary for XEL on attempt 2
# Failed to gather summary for XEL on attempt 3
# Failed to gather summary for XEL on attempt 4
# Failed to gather summary for XEL on attempt 5
# Too many failed attempts for summary of XEL, skipping to next df.
# Did not successfully scrape XEL
# Failed to gather summary for XLNX on attempt 1
# Failed to gather summary for XLNX on attempt 2
# Failed to gather summary for XLNX on attempt 3
# Failed to gather summary for XLNX on attempt 4
# Failed to gather summary for XLNX on attempt 5
# Too many failed attempts for summary of XLNX, skipping to next df.
# Did not successfully scrape XLNX
# Failed to gather summary for XOM on attempt 1
# Failed to gather summary for XOM on attempt 2
# Failed to gather summary for XOM on attempt 3
# Failed to gather summary for XOM on attempt 4
# Failed to gather summary for XOM on attempt 5
# Too many failed attempts for summary of XOM, skipping to next df.
# Did not successfully scrape XOM
# Failed to gather summary for XRAY on attempt 1
# Failed to gather summary for XRAY on attempt 2
# Failed to gather summary for XRAY on attempt 3
# Failed to gather summary for XRAY on attempt 4
# Failed to gather summary for XRAY on attempt 5
# Too many failed attempts for summary of XRAY, skipping to next df.
# Did not successfully scrape XRAY
# Failed to gather summary for XRX on attempt 1
# Failed to gather summary for XRX on attempt 2
# Failed to gather summary for XRX on attempt 3
# Failed to gather summary for XRX on attempt 4
# Failed to gather summary for XRX on attempt 5
# Too many failed attempts for summary of XRX, skipping to next df.
# Did not successfully scrape XRX
# Failed to gather summary for XYL on attempt 1
# Failed to gather summary for XYL on attempt 2
# Failed to gather summary for XYL on attempt 3
# Failed to gather summary for XYL on attempt 4
# Failed to gather summary for XYL on attempt 5
# Too many failed attempts for summary of XYL, skipping to next df.
# Did not successfully scrape XYL
# Failed to gather summary for YUM on attempt 1
# Failed to gather summary for YUM on attempt 2
# Failed to gather summary for YUM on attempt 3
# Failed to gather summary for YUM on attempt 4
# Failed to gather summary for YUM on attempt 5
# Too many failed attempts for summary of YUM, skipping to next df.
# Did not successfully scrape YUM
# Failed to gather summary for ZBH on attempt 1
# Failed to gather summary for ZBH on attempt 2
# Failed to gather summary for ZBH on attempt 3
# Failed to gather summary for ZBH on attempt 4
# Failed to gather summary for ZBH on attempt 5
# Too many failed attempts for summary of ZBH, skipping to next df.
# Did not successfully scrape ZBH
# Failed to gather summary for ZBRA on attempt 1
# Failed to gather summary for ZBRA on attempt 2
# Failed to gather summary for ZBRA on attempt 3
# Failed to gather summary for ZBRA on attempt 4
# Failed to gather summary for ZBRA on attempt 5
# Too many failed attempts for summary of ZBRA, skipping to next df.
# Did not successfully scrape ZBRA
# Failed to gather summary for ZION on attempt 1
# Failed to gather summary for ZION on attempt 2
# Failed to gather summary for ZION on attempt 3
# Failed to gather summary for ZION on attempt 4
# Failed to gather summary for ZION on attempt 5
# Too many failed attempts for summary of ZION, skipping to next df.
# Did not successfully scrape ZION
# Failed to gather summary for ZTS on attempt 1
# Failed to gather summary for ZTS on attempt 2
# Failed to gather summary for ZTS on attempt 3
# Failed to gather summary for ZTS on attempt 4
# Failed to gather summary for ZTS on attempt 5
# Too many failed attempts for summary of ZTS, skipping to next df.
# Did not successfully scrape ZTS

# %%
# Second scrape, starts where the other left off based on the completed files in the directory
# At MET, TD Ameritrade logged me out, so a third scrape was needed to finish the SP500
big_df, skipped = bf.scrape_watchlist(driver, 
                                      sp500_tickers, 
                                      'sp500_close', 
                                      skip_finished=True,
                                      save_df=False,
                                      errors='ignore',
                                      return_skipped=True
                                     )
# Out:
# Failed to gather earnings for FOX on attempt 1
# Failed to gather earnings for FOX on attempt 2
# Failed to gather earnings for FOX on attempt 3
# Failed to gather earnings for FOX on attempt 4
# Failed to gather earnings for FOX on attempt 5
# Too many failed attempts for earnings of FOX, skipping to next df.
# Historic Growth not available for FOX
# Short Interest info not available for FOX
# 190 tickers scraped
# Historic Growth not available for FOXA
# Historic Growth not available for FTI
# 200 tickers scraped
# Short Interest info not available for GOOG
# Historic Growth not available for GPN
# 210 tickers scraped
# 220 tickers scraped
# 230 tickers scraped
# 240 tickers scraped
# 250 tickers scraped
# 260 tickers scraped
# 270 tickers scraped
# Failed to gather earnings for L on attempt 1
# Failed to gather earnings for L on attempt 2
# Failed to gather earnings for L on attempt 3
# Failed to gather earnings for L on attempt 4
# Failed to gather earnings for L on attempt 5
# Too many failed attempts for earnings of L, skipping to next df.
# 280 tickers scraped
# Historic Growth not available for LHX
# 290 tickers scraped
# 300 tickers scraped
# Failed to gather summary for MET on attempt 1
# Failed to gather summary for MET on attempt 2
# Failed to gather summary for MET on attempt 3
# Failed to gather summary for MET on attempt 4
# Failed to gather summary for MET on attempt 5
# Too many failed attempts for summary of MET, skipping to next df.
# Did not successfully scrape MET
# Failed to gather summary for MGM on attempt 1
# Failed to gather summary for MGM on attempt 2
# Failed to gather summary for MGM on attempt 3
# Failed to gather summary for MGM on attempt 4
# Failed to gather summary for MGM on attempt 5
# Too many failed attempts for summary of MGM, skipping to next df.
# Did not successfully scrape MGM
# Failed to gather summary for MHK on attempt 1
# Failed to gather summary for MHK on attempt 2
# Failed to gather summary for MHK on attempt 3
# Failed to gather summary for MHK on attempt 4
# Failed to gather summary for MHK on attempt 5
# Too many failed attempts for summary of MHK, skipping to next df.
# Did not successfully scrape MHK
# Failed to gather summary for MKC on attempt 1
# Failed to gather summary for MKC on attempt 2
# Failed to gather summary for MKC on attempt 3
# Failed to gather summary for MKC on attempt 4
# Failed to gather summary for MKC on attempt 5
# Too many failed attempts for summary of MKC, skipping to next df.
# Did not successfully scrape MKC
# Failed to gather summary for MKTX on attempt 1
# Failed to gather summary for MKTX on attempt 2
# Failed to gather summary for MKTX on attempt 3
# Failed to gather summary for MKTX on attempt 4
# Failed to gather summary for MKTX on attempt 5
# Too many failed attempts for summary of MKTX, skipping to next df.
# Did not successfully scrape MKTX
# Failed to gather summary for MLM on attempt 1
# Failed to gather summary for MLM on attempt 2
# Failed to gather summary for MLM on attempt 3
# Failed to gather summary for MLM on attempt 4
# Failed to gather summary for MLM on attempt 5
# Too many failed attempts for summary of MLM, skipping to next df.
# Did not successfully scrape MLM
# Failed to gather summary for MMC on attempt 1
# Failed to gather summary for MMC on attempt 2
# Failed to gather summary for MMC on attempt 3
# Failed to gather summary for MMC on attempt 4
# Failed to gather summary for MMC on attempt 5
# Too many failed attempts for summary of MMC, skipping to next df.
# Did not successfully scrape MMC
# Failed to gather summary for MMM on attempt 1
# Failed to gather summary for MMM on attempt 2
# Failed to gather summary for MMM on attempt 3
# Failed to gather summary for MMM on attempt 4
# Failed to gather summary for MMM on attempt 5
# Too many failed attempts for summary of MMM, skipping to next df.
# Did not successfully scrape MMM
# Failed to gather summary for MNST on attempt 1
# Failed to gather summary for MNST on attempt 2
# Failed to gather summary for MNST on attempt 3
# Failed to gather summary for MNST on attempt 4
# Too many failed attempts for summary of MNST, skipping to next df.
# Did not successfully scrape MNST

# %%
# Third and final scrape
fix_df, skipped = bf.scrape_watchlist(driver, 
                                      sp500_tickers, 
                                      'sp500_close', 
                                      skip_finished=True,
                                      save_df=False,
                                      errors='ignore',
                                      return_skipped=True
                                     )
# Out:
# 310 tickers scraped
# 320 tickers scraped
# 330 tickers scraped
# 340 tickers scraped
# 350 tickers scraped
# Failed to gather earnings for NWS on attempt 1
# Failed to gather earnings for NWS on attempt 2
# Failed to gather earnings for NWS on attempt 3
# Failed to gather earnings for NWS on attempt 4
# Failed to gather earnings for NWS on attempt 5
# Too many failed attempts for earnings of NWS, skipping to next df.
# Short Interest info not available for NWS
# 360 tickers scraped
# 370 tickers scraped
# 380 tickers scraped
# Historic Growth not available for PRGO
# 390 tickers scraped
# 400 tickers scraped
# 410 tickers scraped
# 420 tickers scraped
# 430 tickers scraped
# 440 tickers scraped
# 450 tickers scraped
# Short Interest info not available for UA
# 460 tickers scraped
# Historic Growth not available for VFC
# 470 tickers scraped
# 480 tickers scraped
# 490 tickers scraped
# 500 tickers scraped

# %%
# That did it. Now quit your webdriver and start the data_exploration.ipynb to investigate
driver.quit()
